# %%
import lxml.etree as ET
import xmltodict
import csv
import json
from datetime import datetime

# %%
CHAMPS_ANNEXE_DATA_EMPRUNT = "AnEncaisse, AnnuitNetDette, Champ_Editeur, CodArticle, CodNatEmpr, CodPeriodRemb, CodPeriodRembDtVote, CodPeriodRembReneg, CodProfilAmort, CodProfilAmortDtVote, CodProfilAmortReneg, CodTypEmpr, CodTypEmprGaranti, CodTypPreteur, CodTypTxCouv, CodTypTxReneg, CodTyptxDtVote, CodTyptxInit, CoutSortie, Couverture, Dt1RembInit, DtDebCouv, DtEmission, DtFinContr, DtFinCouv, DtPeriodeBonif, DtRegltCouv, DtReneg, DtSignInit, DureeAnn, DureeContratInit, DureeContratReneg, DureeRest, DureeRestInit, DureeRestReneg, IndSousJacent, IndSousJacentApresCouv, IndSousJacentAvantCouv, IndSousJacentDtVote, IndexTxVariDtVote, IndexTxVariInit, IndexTxVariReneg, IndiceCouv, IndiceEmpr, IndiceEmprDtVote, LibCpte, LibOrgCoContr, LibOrgaPreteur, MPrimeRecueCouv, MtCRDCouvert, MtCRDRefin, MtCapitalExer, MtCapitalReamenage, MtCapitalRestDu_01_01, MtCapitalRestDu_31_12, MtCharges, MtCommCouv, MtCouv, MtCouvert, MtEmprOrig, MtEmprReneg, MtICNE, MtInt778, MtIntExer, MtPrimePayeeCouv, MtProduits, MtSortie, NatCouv, NomBenefEmprGaranti, NumContrat, NumContratCouv, ObjEmpr, PartGarantie, ProfilAmort, ProfilAmortDtVote, ProvGarantiEmpr, RReelFon, Renegocie, RtAnticipe, Structure, StructureDtVote, StuctureApresCouv, StuctureAvantCouv, Tot1Annuite, TotGarEchoirExer, TxActua, TxActuaInit, TxActuaReneg, TxApresCouv, TxMargeInit, TxMaxi, TxMini, TxPaye, TxRecu, Txinit, TypCouv, TypeSortie".split(", ")
CHAMPS_ANNEXE_DATA_TRESORERIE = "Champ_Editeur, CodArticle, DtDec, IntManda, LibOrgaPret, MtMaxAutori, MtRemb, MtRembInt, MtRestDu, MtTirage, NumContrat".split(", ")
CHAMPS_ANNEXE_DATA_CHARGE = "Champ_Editeur, CodTypeCharge, DtDelib, DureeEtal, Exer, MtAmort, MtDepTransf, MtDotAmort, NatDepTransf".split(", ")
CHAMPS_ANNEXE_DATA_TIERS = "Champ_Editeur, CodChapitre, CodOper, CodOperR, CodRD, DtDelib, LibOper, MtCredOuv, MtCumulReal, MtRealCumulPrec, MtRealExer, NatTrav, RAR, TypOpDep".split(", ")
CHAMPS_ANNEXE_DATA_CREDIT_BAIL = "Champ_Editeur, CodTypContr, DureeContr, ExerContr, LibCredBail, MtCumulRest, MtRedevExer, MtRedevN_1, MtRedevN_2, MtRedevN_3, MtRedevN_4, MtRedevN_5, NatBienContr, NumContr".split(", ")
CHAMPS_ANNEXE_DATA_PPP = "AnnSignContr, Champ_Editeur, DtFinContr, DureeContr, LibContr, MtRemunCoContr, MtTotContr, NatPrestaContr, NomOrgaContr, PartInvest, PartNetteInvest".split(", ") 
CHAMPS_ANNEXE_DATA_AUTRE_ENGAGEMENT = "AnnOrig, Champ_Editeur, CodArticle, CodTypAutEng, CodTypPersoMorale, CodePeriod, DureeEng, MtAnnuit, MtDette, MtDetteOrig, NatEng, NomOrgaBenef".split(", ")
CHAMPS_ANNEXE_DATA_CONCOURS = "Champ_Editeur, CodArticle, CodInvFonc, CodNatJurBenefCA, DenomOuNumSubv, LibOrgaBenef, LibPrestaNat, MtSubv, ObjSubv, PopCommune, Siret".split(", ")
CHAMPS_ANNEXE_DATA_RECETTE_AFFECTEE = "Champ_Editeur, CodArticle, CodChapitre, CodRAffect, LibArticle, LibRAffect, MtD, MtR, MtRAE0101".split(", ")
CHAMPS_ANNEXE_DATA_FORMATION = "ActionFinanc, Champ_Editeur, NomElu".split(", ")
CHAMPS_ANNEXE_DATA_FISCALITE = "Champ_Editeur, CodSousTypContrib, CodTypContrib, CodTypeCarburant, LibTaxe, MtBaseNotif, MtProdVote, Origine, TxApplicConsMunic, TxVariBase, TxVariProd, TxVariTx, Unite".split(", ")
CHAMPS_ANNEXE_DATA_CONSOLIDATION  = "Champ_Editeur, CodBudAnnex, CodInvFonc, CodRD, CodTypBudAgreg, LibBudAnnex, MtCredOuv, MtRealMandatTitre, RAR, SiretBudAnnexe".split(", ")
CHAMPS_ANNEXE_DATA_ORGANISME_ENG = "Champ_Editeur, CodNatEng, DtEng, MtOrgEng, NatEng, NatJurOrgEng, NomOrgEng, RSOrgEng".split(", ")
CHAMPS_ANNEXE_DATA_ORGANISME_GROUP = "Champ_Editeur, CodModFinanc, CodNatOrgGroup, DtAdhGroup, MtFinancOrgGroup, NomOrgGroup".split(", ")
CHAMPS_ANNEXE_DATA_PATRIMOINE = "Champ_Editeur, CodEntreeSorti, CodModalAcqui, CodModalSorti, CodTypImmo, CodTypTitre, CodVariPatrim, DtAcquiBien, DtCessBienSorti, DtDelib, DureeAmortBien, LibBien, LibObserv, LibOrgPrisePartic, MtAmortExer, MtCumulAmortBien, MtPrixCessBienSorti, MtVNCBien0101, MtVNCBien3112, MtVNCBienSorti, MtValAcquiBien, NumInventaire".split(", ")
CHAMPS_ANNEXE_DATA_PERSONNEL = "Champ_Editeur, CodCatAgent, CodMotifContrAgent, CodSectAgentNonTitulaire, CodSectAgentTitulaire, CodTypAgent, EffectifBud, EffectifPourvu, EffectifTNC, EmploiGradeAgent, IndiceAgent, LibMotifContrAgent, LibelleNatureContrat, MtPrev6215, NatureContrat, Permanent, RemunAgent, TempsComplet".split(", ")
CHAMPS_ANNEXE_DATA_PERSONNEL_SOLDE = "Champ_Editeur, NbrCreatEmploi, NbrSupprEmploi".split(", ")
CHAMPS_ANNEXE_DATA_DETTE = "Champ_Editeur, LibTypDette, MtDExerDette, MtInitDette, MtRestDette".split(", ")
CHAMPS_ANNEXE_DATA_VENTILATION = "Champ_Editeur, CodArticle, CodChapitre, CodInvFonc, CodRD, CodRegroup, CodTypVentil, LibCpte, MtVentil, NomService, TypOpBudg".split(", ")
CHAMPS_ANNEXE_DATA_CONTRAT_COUV = "CapitalRestDu, Champ_Editeur, CodPeriodRemb, CodTypRisqFinanc, CodTypTx, DtDebContr, DtFinContrEmpr, DtFinCouv, DtReglt, DureeContr, IndSousJacentApresCouv, IndSousJacentAvantCouv, IndexTxPaye, IndexTxRecu, LibEmprCouv, LibOrgCoContr, MtChaOrig, MtChaOrigPrimeAss, MtChaOrigPrimeCommi, MtCommDiv, MtEmprCouv, MtMaxAutoriEmprEnc_N, MtMaxAutori_N, MtPert, MtPertProf, MtPrimePayee, MtPrimeRecue, MtProdOrig, MtProf, NatContrCouv, NbEmpruntCouv, NumContratCouv, StuctureApresCouv, StuctureAvantCouv, TxTxPaye, TxTxRecu, TypCouv".split(", ")
CHAMPS_ANNEXE_DATA_AMORTISSEMENT_METHODE = "Champ_Editeur, DtDelib, DureeBienAmort, LibBienAmort, ProcAmort".split(", ")
CHAMPS_ANNEXE_DATA_PROVISION = "Champ_Editeur, CodNatProv, CodSTypProv, CodTypProv, CodTypTabProv, DtConstitProv, DureeEtal, LibNatProv, LibObjProv, MtProvConstit_01_01_N, MtProvExer, MtProvRepr, MtTotalProvAConstit".split(", ")
CHAMPS_ANNEXE_DATA_APCP = "Champ_Editeur, Chapitre, CodSTypAutori, CodTypAutori, LibAutori, MtAutoriAffectee, MtAutoriAffecteeAnnulee, MtAutoriDispoAffectation, MtAutoriNonCouvParCP_01_01_N, MtAutoriPrec, MtAutoriPropose, MtAutoriVote, MtAutori_NMoins1, MtCPAnt, MtCPOuv, MtCPReal, MtCredAFinanc_NPlus1, MtCredAFinanc_Sup_N, MtCredAFinanc_Sup_NPlus1, NumAutori, RatioCouvAutoriAffect_N, RatioCouvAutoriAffect_NMoins1, RatioCouvAutoriAffect_NMoins2, RatioCouvAutoriAffect_NMoins3, TypeChapitre".split(", ")
CHAMPS_ANNEXE_DATA_SIGNATURE = "Champ_Editeur, DtConvoc, DtDelib, DtPresent, DtPub, DtTransmPrefect, DtfFin, LibDelibLieu, LibDelibPar, LibFin, LibPresentLieu, LibPresentPar, LibReuniSession, NbrMembExer, NbrMembPresent, NbrSuffExprime, NbrVoteAbstention, NbrVoteContre, NbrVotePour".split(", ")
CHAMPS_ANNEXE_DATA_SIGNATAIRE = ["Signataire"]
CHAMPS_ANNEXE_DATA_ETAB_SERVICE = "Champ_Editeur, CodNatEtab, DtCreatEtab, DtDelibEtab, IndicTVAEtab, LibCatEtab, LibEtab, LibNatActivEtab, NumDelibEtab, SiretEtab".split(", ")
CHAMPS_ANNEXE_DATA_PRET = "Champ_Editeur, CodTypPret, DtDelib, MtCapitalExer, MtCapitalRestDu_01_01, MtCapitalRestDu_31_12, MtICNE, MtIntExer, NomBenefPret".split(", ")
CHAMPS_ANNEXE_DATA_CONTRAT_COUV_REFERENCE = "Champ_Editeur, CodProfilAmort, CodTyptxInit, DtDebEcheance, DureeAnn, IndexTxVariInit, LibObserv, MtCapitalExer, MtCapitalRestDu_01_01, MtCapitalRestDu_31_12, MtEmprOrig, MtIntExer, NumContr, NumContratEmprunt, TxActuaInit".split(", ")
CHAMPS_ANNEXE_DATA_SERVICE_FERROVIAIRE_BUD = "Champ_Editeur, CodChapitre, CodInvFonc, CodRD, CodRegroupBudFerrov, MtVentil".split(", ")
CHAMPS_ANNEXE_DATA_SERVICE_FERROVIAIRE_PATRIM = "Champ_Editeur, DtFinPot, DtMiseService, LibModeFinanc, LibProprietaire, LibRame, Matricule, MtAmort, MtVNC, MtValOrig".split(", ")
CHAMPS_ANNEXE_DATA_SERVICE_FERROVIAIRE_TER = "Champ_Editeur, CodCptTER, MtCptTER".split(", ")
CHAMPS_ANNEXE_DATA_FOND_COMM_HEBERGEMENT = "Champ_Editeur, CodOper, CodRD, LibEtabHeberg, LibFondHeberg, LibObjFond, MtFond".split(", ")
CHAMPS_ANNEXE_DATA_FOND_EUROPEEN = "Champ_Editeur, CodArticle, CodDestFonds, CodRDDJust, DtAcquit, LibBenef, LibEmetteurs, LibFondsEuropeen, LibMesure, LibOper, MtFond".split(", ")
CHAMPS_ANNEXE_DATA_FOND_EUROPEEN_PROGRAMMATION = "Avances, CodRD, MontantN, MontantN_X, Programmation, RappelTotal, RegulN, TypeFonds, TypeGestion".split(", ")
CHAMPS_ANNEXE_DATA_FOND_AIDES_ECO = "Champ_Editeur, CodArticle, CodInvFon, CodRD, DtConvent, DtVers, LibAide, LibBenef, LibFormeAide, LibOrgConvent, MtDExer, MtDExerAnt, MtReliquatCPAnt, MtTotAide, MtVersExer".split(", ")
CHAMPS_ANNEXE_DATA_FORMATION_PRO_JEUNES = "Champ_Editeur, CodApprent, CodRDTot, CodRessExt, MtFormN, MtFormN_1".split(", ")
CHAMPS_ANNEXE_DATA_MEMBRESASA = "Commune, Proprietaire, Superficie".split(", ")
CHAMPS_ANNEXE_DATA_FLUX_CROISES = "CodInvFonc, CodRD, CodTypFlux, MtCredOuv, MtRAR, MtReal".split(", ")
CHAMPS_ANNEXE_DATA_SOMMAIRE = "Champ_Editeur, CodeAnnexe, Present".split(", ")

LIST_ANNEXES = "DATA_AMORTISSEMENT_METHODE, DATA_APCP, DATA_AUTRE_ENGAGEMENT, DATA_CHARGE, DATA_CONCOURS, DATA_CONSOLIDATION, DATA_CONTRAT_COUV, DATA_CONTRAT_COUV_REFERENCE, DATA_CREDIT_BAIL, DATA_DETTE, DATA_EMPRUNT, DATA_ETAB_SERVICE, DATA_FISCALITE, DATA_FOND_AIDES_ECO, DATA_FOND_COMM_HEBERGEMENT, DATA_FOND_EUROPEEN, DATA_FOND_EUROPEEN_PROGRAMMATION, DATA_FORMATION, DATA_FORMATION_PRO_JEUNES, DATA_MEMBRESASA, DATA_ORGANISME_ENG, DATA_ORGANISME_GROUP, DATA_PATRIMOINE, DATA_PERSONNEL, DATA_PERSONNEL_SOLDE, DATA_PPP, DATA_PRET, DATA_PROVISION, DATA_RECETTE_AFFECTEE, DATA_SERVICE_FERROVIAIRE_BUD, DATA_SERVICE_FERROVIAIRE_PATRIM, DATA_SERVICE_FERROVIAIRE_TER, DATA_SIGNATAIRE, DATA_SIGNATURE, DATA_SOMMAIRE, DATA_TIERS, DATA_TRESORERIE, DATA_VENTILATION, DATA_FLUX_CROISES".split(", ")

# %%
#globals()

CHAMPS_ANNEXES = {
'DATA_EMPRUNT': ['AnEncaisse',
  'AnnuitNetDette',
  'Champ_Editeur',
  'CodArticle',
  'CodNatEmpr',
  'CodPeriodRemb',
  'CodPeriodRembDtVote',
  'CodPeriodRembReneg',
  'CodProfilAmort',
  'CodProfilAmortDtVote',
  'CodProfilAmortReneg',
  'CodTypEmpr',
  'CodTypEmprGaranti',
  'CodTypPreteur',
  'CodTypTxCouv',
  'CodTypTxReneg',
  'CodTyptxDtVote',
  'CodTyptxInit',
  'CoutSortie',
  'Couverture',
  'Dt1RembInit',
  'DtDebCouv',
  'DtEmission',
  'DtFinContr',
  'DtFinCouv',
  'DtPeriodeBonif',
  'DtRegltCouv',
  'DtReneg',
  'DtSignInit',
  'DureeAnn',
  'DureeContratInit',
  'DureeContratReneg',
  'DureeRest',
  'DureeRestInit',
  'DureeRestReneg',
  'IndSousJacent',
  'IndSousJacentApresCouv',
  'IndSousJacentAvantCouv',
  'IndSousJacentDtVote',
  'IndexTxVariDtVote',
  'IndexTxVariInit',
  'IndexTxVariReneg',
  'IndiceCouv',
  'IndiceEmpr',
  'IndiceEmprDtVote',
  'LibCpte',
  'LibOrgCoContr',
  'LibOrgaPreteur',
  'MPrimeRecueCouv',
  'MtCRDCouvert',
  'MtCRDRefin',
  'MtCapitalExer',
  'MtCapitalReamenage',
  'MtCapitalRestDu_01_01',
  'MtCapitalRestDu_31_12',
  'MtCharges',
  'MtCommCouv',
  'MtCouv',
  'MtCouvert',
  'MtEmprOrig',
  'MtEmprReneg',
  'MtICNE',
  'MtInt778',
  'MtIntExer',
  'MtPrimePayeeCouv',
  'MtProduits',
  'MtSortie',
  'NatCouv',
  'NomBenefEmprGaranti',
  'NumContrat',
  'NumContratCouv',
  'ObjEmpr',
  'PartGarantie',
  'ProfilAmort',
  'ProfilAmortDtVote',
  'ProvGarantiEmpr',
  'RReelFon',
  'Renegocie',
  'RtAnticipe',
  'Structure',
  'StructureDtVote',
  'StuctureApresCouv',
  'StuctureAvantCouv',
  'Tot1Annuite',
  'TotGarEchoirExer',
  'TxActua',
  'TxActuaInit',
  'TxActuaReneg',
  'TxApresCouv',
  'TxMargeInit',
  'TxMaxi',
  'TxMini',
  'TxPaye',
  'TxRecu',
  'Txinit',
  'TypCouv',
  'TypeSortie'],
 'DATA_TRESORERIE': ['Champ_Editeur',
  'CodArticle',
  'DtDec',
  'IntManda',
  'LibOrgaPret',
  'MtMaxAutori',
  'MtRemb',
  'MtRembInt',
  'MtRestDu',
  'MtTirage',
  'NumContrat'],
 'DATA_CHARGE': ['Champ_Editeur',
  'CodTypeCharge',
  'DtDelib',
  'DureeEtal',
  'Exer',
  'MtAmort',
  'MtDepTransf',
  'MtDotAmort',
  'NatDepTransf'],
 'DATA_TIERS': ['Champ_Editeur',
  'CodChapitre',
  'CodOper',
  'CodOperR',
  'CodRD',
  'DtDelib',
  'LibOper',
  'MtCredOuv',
  'MtCumulReal',
  'MtRealCumulPrec',
  'MtRealExer',
  'NatTrav',
  'RAR',
  'TypOpDep'],
 'DATA_CREDIT_BAIL': ['Champ_Editeur',
  'CodTypContr',
  'DureeContr',
  'ExerContr',
  'LibCredBail',
  'MtCumulRest',
  'MtRedevExer',
  'MtRedevN_1',
  'MtRedevN_2',
  'MtRedevN_3',
  'MtRedevN_4',
  'MtRedevN_5',
  'NatBienContr',
  'NumContr'],
 'DATA_PPP': ['AnnSignContr',
  'Champ_Editeur',
  'DtFinContr',
  'DureeContr',
  'LibContr',
  'MtRemunCoContr',
  'MtTotContr',
  'NatPrestaContr',
  'NomOrgaContr',
  'PartInvest',
  'PartNetteInvest'],
 'DATA_AUTRE_ENGAGEMENT': ['AnnOrig',
  'Champ_Editeur',
  'CodArticle',
  'CodTypAutEng',
  'CodTypPersoMorale',
  'CodePeriod',
  'DureeEng',
  'MtAnnuit',
  'MtDette',
  'MtDetteOrig',
  'NatEng',
  'NomOrgaBenef'],
 'DATA_CONCOURS': ['Champ_Editeur',
  'CodArticle',
  'CodInvFonc',
  'CodNatJurBenefCA',
  'DenomOuNumSubv',
  'LibOrgaBenef',
  'LibPrestaNat',
  'MtSubv',
  'ObjSubv',
  'PopCommune',
  'Siret'],
 'DATA_RECETTE_AFFECTEE': ['Champ_Editeur',
  'CodArticle',
  'CodChapitre',
  'CodRAffect',
  'LibArticle',
  'LibRAffect',
  'MtD',
  'MtR',
  'MtRAE0101'],
 'DATA_FORMATION': ['ActionFinanc', 'Champ_Editeur', 'NomElu'],
 'DATA_FISCALITE': ['Champ_Editeur',
  'CodSousTypContrib',
  'CodTypContrib',
  'CodTypeCarburant',
  'LibTaxe',
  'MtBaseNotif',
  'MtProdVote',
  'Origine',
  'TxApplicConsMunic',
  'TxVariBase',
  'TxVariProd',
  'TxVariTx',
  'Unite'],
 'DATA_CONSOLIDATION': ['Champ_Editeur',
  'CodBudAnnex',
  'CodInvFonc',
  'CodRD',
  'CodTypBudAgreg',
  'LibBudAnnex',
  'MtCredOuv',
  'MtRealMandatTitre',
  'RAR',
  'SiretBudAnnexe'],
 'DATA_ORGANISME_ENG': ['Champ_Editeur',
  'CodNatEng',
  'DtEng',
  'MtOrgEng',
  'NatEng',
  'NatJurOrgEng',
  'NomOrgEng',
  'RSOrgEng'],
 'DATA_ORGANISME_GROUP': ['Champ_Editeur',
  'CodModFinanc',
  'CodNatOrgGroup',
  'DtAdhGroup',
  'MtFinancOrgGroup',
  'NomOrgGroup'],
 'DATA_PATRIMOINE': ['Champ_Editeur',
  'CodEntreeSorti',
  'CodModalAcqui',
  'CodModalSorti',
  'CodTypImmo',
  'CodTypTitre',
  'CodVariPatrim',
  'DtAcquiBien',
  'DtCessBienSorti',
  'DtDelib',
  'DureeAmortBien',
  'LibBien',
  'LibObserv',
  'LibOrgPrisePartic',
  'MtAmortExer',
  'MtCumulAmortBien',
  'MtPrixCessBienSorti',
  'MtVNCBien0101',
  'MtVNCBien3112',
  'MtVNCBienSorti',
  'MtValAcquiBien',
  'NumInventaire'],
 'DATA_PERSONNEL': ['Champ_Editeur',
  'CodCatAgent',
  'CodMotifContrAgent',
  'CodSectAgentNonTitulaire',
  'CodSectAgentTitulaire',
  'CodTypAgent',
  'EffectifBud',
  'EffectifPourvu',
  'EffectifTNC',
  'EmploiGradeAgent',
  'IndiceAgent',
  'LibMotifContrAgent',
  'LibelleNatureContrat',
  'MtPrev6215',
  'NatureContrat',
  'Permanent',
  'RemunAgent',
  'TempsComplet'],
 'DATA_PERSONNEL_SOLDE': ['Champ_Editeur',
  'NbrCreatEmploi',
  'NbrSupprEmploi'],
 'DATA_DETTE': ['Champ_Editeur',
  'LibTypDette',
  'MtDExerDette',
  'MtInitDette',
  'MtRestDette'],
 'DATA_VENTILATION': ['Champ_Editeur',
  'CodArticle',
  'CodChapitre',
  'CodInvFonc',
  'CodRD',
  'CodRegroup',
  'CodTypVentil',
  'LibCpte',
  'MtVentil',
  'NomService',
  'TypOpBudg'],
 'DATA_CONTRAT_COUV': ['CapitalRestDu',
  'Champ_Editeur',
  'CodPeriodRemb',
  'CodTypRisqFinanc',
  'CodTypTx',
  'DtDebContr',
  'DtFinContrEmpr',
  'DtFinCouv',
  'DtReglt',
  'DureeContr',
  'IndSousJacentApresCouv',
  'IndSousJacentAvantCouv',
  'IndexTxPaye',
  'IndexTxRecu',
  'LibEmprCouv',
  'LibOrgCoContr',
  'MtChaOrig',
  'MtChaOrigPrimeAss',
  'MtChaOrigPrimeCommi',
  'MtCommDiv',
  'MtEmprCouv',
  'MtMaxAutoriEmprEnc_N',
  'MtMaxAutori_N',
  'MtPert',
  'MtPertProf',
  'MtPrimePayee',
  'MtPrimeRecue',
  'MtProdOrig',
  'MtProf',
  'NatContrCouv',
  'NbEmpruntCouv',
  'NumContratCouv',
  'StuctureApresCouv',
  'StuctureAvantCouv',
  'TxTxPaye',
  'TxTxRecu',
  'TypCouv'],
 'DATA_AMORTISSEMENT_METHODE': ['Champ_Editeur',
  'DtDelib',
  'DureeBienAmort',
  'LibBienAmort',
  'ProcAmort'],
 'DATA_PROVISION': ['Champ_Editeur',
  'CodNatProv',
  'CodSTypProv',
  'CodTypProv',
  'CodTypTabProv',
  'DtConstitProv',
  'DureeEtal',
  'LibNatProv',
  'LibObjProv',
  'MtProvConstit_01_01_N',
  'MtProvExer',
  'MtProvRepr',
  'MtTotalProvAConstit'],
 'DATA_APCP': ['Champ_Editeur',
  'Chapitre',
  'CodSTypAutori',
  'CodTypAutori',
  'LibAutori',
  'MtAutoriAffectee',
  'MtAutoriAffecteeAnnulee',
  'MtAutoriDispoAffectation',
  'MtAutoriNonCouvParCP_01_01_N',
  'MtAutoriPrec',
  'MtAutoriPropose',
  'MtAutoriVote',
  'MtAutori_NMoins1',
  'MtCPAnt',
  'MtCPOuv',
  'MtCPReal',
  'MtCredAFinanc_NPlus1',
  'MtCredAFinanc_Sup_N',
  'MtCredAFinanc_Sup_NPlus1',
  'NumAutori',
  'RatioCouvAutoriAffect_N',
  'RatioCouvAutoriAffect_NMoins1',
  'RatioCouvAutoriAffect_NMoins2',
  'RatioCouvAutoriAffect_NMoins3',
  'TypeChapitre'],
 'DATA_SIGNATURE': ['Champ_Editeur',
  'DtConvoc',
  'DtDelib',
  'DtPresent',
  'DtPub',
  'DtTransmPrefect',
  'DtfFin',
  'LibDelibLieu',
  'LibDelibPar',
  'LibFin',
  'LibPresentLieu',
  'LibPresentPar',
  'LibReuniSession',
  'NbrMembExer',
  'NbrMembPresent',
  'NbrSuffExprime',
  'NbrVoteAbstention',
  'NbrVoteContre',
  'NbrVotePour'],
 'DATA_SIGNATAIRE': ['Signataire'],
 'DATA_ETAB_SERVICE': ['Champ_Editeur',
  'CodNatEtab',
  'DtCreatEtab',
  'DtDelibEtab',
  'IndicTVAEtab',
  'LibCatEtab',
  'LibEtab',
  'LibNatActivEtab',
  'NumDelibEtab',
  'SiretEtab'],
 'DATA_PRET': ['Champ_Editeur',
  'CodTypPret',
  'DtDelib',
  'MtCapitalExer',
  'MtCapitalRestDu_01_01',
  'MtCapitalRestDu_31_12',
  'MtICNE',
  'MtIntExer',
  'NomBenefPret'],
 'DATA_CONTRAT_COUV_REFERENCE': ['Champ_Editeur',
  'CodProfilAmort',
  'CodTyptxInit',
  'DtDebEcheance',
  'DureeAnn',
  'IndexTxVariInit',
  'LibObserv',
  'MtCapitalExer',
  'MtCapitalRestDu_01_01',
  'MtCapitalRestDu_31_12',
  'MtEmprOrig',
  'MtIntExer',
  'NumContr',
  'NumContratEmprunt',
  'TxActuaInit'],
 'DATA_SERVICE_FERROVIAIRE_BUD': ['Champ_Editeur',
  'CodChapitre',
  'CodInvFonc',
  'CodRD',
  'CodRegroupBudFerrov',
  'MtVentil'],
 'DATA_SERVICE_FERROVIAIRE_PATRIM': ['Champ_Editeur',
  'DtFinPot',
  'DtMiseService',
  'LibModeFinanc',
  'LibProprietaire',
  'LibRame',
  'Matricule',
  'MtAmort',
  'MtVNC',
  'MtValOrig'],
 'DATA_SERVICE_FERROVIAIRE_TER': ['Champ_Editeur',
  'CodCptTER',
  'MtCptTER'],
 'DATA_FOND_COMM_HEBERGEMENT': ['Champ_Editeur',
  'CodOper',
  'CodRD',
  'LibEtabHeberg',
  'LibFondHeberg',
  'LibObjFond',
  'MtFond'],
 'DATA_FOND_EUROPEEN': ['Champ_Editeur',
  'CodArticle',
  'CodDestFonds',
  'CodRDDJust',
  'DtAcquit',
  'LibBenef',
  'LibEmetteurs',
  'LibFondsEuropeen',
  'LibMesure',
  'LibOper',
  'MtFond'],
 'DATA_FOND_EUROPEEN_PROGRAMMATION': ['Avances',
  'CodRD',
  'MontantN',
  'MontantN_X',
  'Programmation',
  'RappelTotal',
  'RegulN',
  'TypeFonds',
  'TypeGestion'],
 'DATA_FOND_AIDES_ECO': ['Champ_Editeur',
  'CodArticle',
  'CodInvFon',
  'CodRD',
  'DtConvent',
  'DtVers',
  'LibAide',
  'LibBenef',
  'LibFormeAide',
  'LibOrgConvent',
  'MtDExer',
  'MtDExerAnt',
  'MtReliquatCPAnt',
  'MtTotAide',
  'MtVersExer'],
 'DATA_FORMATION_PRO_JEUNES': ['Champ_Editeur',
  'CodApprent',
  'CodRDTot',
  'CodRessExt',
  'MtFormN',
  'MtFormN_1'],
 'DATA_MEMBRESASA': ['Commune', 'Proprietaire', 'Superficie'],
 'DATA_FLUX_CROISES': ['CodInvFonc',
  'CodRD',
  'CodTypFlux',
  'MtCredOuv',
  'MtRAR',
  'MtReal'],
 'DATA_SOMMAIRE': ['Champ_Editeur', 'CodeAnnexe', 'Present'],
}





LIST_ANNEXES = "DATA_AMORTISSEMENT_METHODE, DATA_APCP, DATA_AUTRE_ENGAGEMENT, DATA_CHARGE, DATA_CONCOURS, DATA_CONSOLIDATION, DATA_CONTRAT_COUV, DATA_CONTRAT_COUV_REFERENCE, DATA_CREDIT_BAIL, DATA_DETTE, DATA_EMPRUNT, DATA_ETAB_SERVICE, DATA_FISCALITE, DATA_FOND_AIDES_ECO, DATA_FOND_COMM_HEBERGEMENT, DATA_FOND_EUROPEEN, DATA_FOND_EUROPEEN_PROGRAMMATION, DATA_FORMATION, DATA_FORMATION_PRO_JEUNES, DATA_MEMBRESASA, DATA_ORGANISME_ENG, DATA_ORGANISME_GROUP, DATA_PATRIMOINE, DATA_PERSONNEL, DATA_PERSONNEL_SOLDE, DATA_PPP, DATA_PRET, DATA_PROVISION, DATA_RECETTE_AFFECTEE, DATA_SERVICE_FERROVIAIRE_BUD, DATA_SERVICE_FERROVIAIRE_PATRIM, DATA_SERVICE_FERROVIAIRE_TER, DATA_SIGNATAIRE, DATA_SIGNATURE, DATA_SOMMAIRE, DATA_TIERS, DATA_TRESORERIE, DATA_VENTILATION, DATA_FLUX_CROISES".split(", ")

# %%
##Annexes
CHAMPS_ANNEXES["DATA_APCP"]
#"DATA_AMORTISSEMENT_METHODE, DATA_APCP, DATA_AUTRE_ENGAGEMENT, DATA_CHARGE, DATA_CONCOURS, DATA_CONSOLIDATION, DATA_CONTRAT_COUV, DATA_CONTRAT_COUV_REFERENCE, DATA_CREDIT_BAIL, DATA_DETTE, DATA_EMPRUNT, DATA_ETAB_SERVICE, DATA_FISCALITE, DATA_FOND_AIDES_ECO, DATA_FOND_COMM_HEBERGEMENT, DATA_FOND_EUROPEEN, DATA_FOND_EUROPEEN_PROGRAMMATION, DATA_FORMATION, DATA_FORMATION_PRO_JEUNES, DATA_MEMBRESASA, DATA_ORGANISME_ENG, DATA_ORGANISME_GROUP, DATA_PATRIMOINE, DATA_PERSONNEL, DATA_PERSONNEL_SOLDE, DATA_PPP, DATA_PRET, DATA_PROVISION, DATA_RECETTE_AFFECTEE, DATA_SERVICE_FERROVIAIRE_BUD, DATA_SERVICE_FERROVIAIRE_PATRIM, DATA_SERVICE_FERROVIAIRE_TER, DATA_SIGNATAIRE, DATA_SIGNATURE, DATA_SOMMAIRE, DATA_TIERS, DATA_TRESORERIE, DATA_VENTILATION, DATA_FLUX_CROISES".split(", ")
# Out:
# ['Champ_Editeur',
#  'Chapitre',
#  'CodSTypAutori',
#  'CodTypAutori',
#  'LibAutori',
#  'MtAutoriAffectee',
#  'MtAutoriAffecteeAnnulee',
#  'MtAutoriDispoAffectation',
#  'MtAutoriNonCouvParCP_01_01_N',
#  'MtAutoriPrec',
#  'MtAutoriPropose',
#  'MtAutoriVote',
#  'MtAutori_NMoins1',
#  'MtCPAnt',
#  'MtCPOuv',
#  'MtCPReal',
#  'MtCredAFinanc_NPlus1',
#  'MtCredAFinanc_Sup_N',
#  'MtCredAFinanc_Sup_NPlus1',
#  'NumAutori',
#  'RatioCouvAutoriAffect_N',
#  'RatioCouvAutoriAffect_NMoins1',
#  'RatioCouvAutoriAffect_NMoins2',
#  'RatioCouvAutoriAffect_NMoins3',
#  'TypeChapitre']

# %%
DocumentBudgetaires = {
    "Millesime" : {
        "2020" :
            "SIRET": {
                "9781779501127": {
                    "SIRET": "9781779501127",
                    "LibelleColl": "Haut de france",
                    "Millesime": 2020,
                    "NatCEPL": "REGION",
                    "budget": [
                        {
                            "Nature": 21828,
                            "Fonction": 900202,
                            "MtBudgPrec": 1460000.00,
                            "MTSup" : {
                                "RARPrec" : 33890.45,
                                "BudgetHorsRAR" : 1460000.00
                            }
                        },
                        {
                            "Nature": 21828,
                            "Fonction": 900202,
                            "MtBudgPrec": 1460000.00,
                            "MTSup" : {
                                "RARPrec" : 33890.45,
                                "BudgetHorsRAR" : 1460000.00
                            }
                        }
                    ]
                    "annexes" : {
                        "personnel" : [
                            {
                                "CodTypAgent" : "I",
                                "EmploiGradeAgent" : "Directeur général des services"
                                "CodCatAgent" : "A"
                                
                            }
                        ]
                    }
                }
            }
    }
}

# %% [markdown]
# DocumentBudgetaire -> Budget -> LigneBudget
# M71_2020/99_BU-031-200053791-20191219-BP2020_REG_OCC-BF-1-1_1.XML

# %% [markdown]
# # Extract Budget

# %% [markdown]
# ## Xml to dict

# %%
BUDGET_FIELDS = ["SIRET", "Nature","LibCpte","Fonction","Operation","ContNat","ArtSpe","ContFon",
                 "ContOp","CodRD","MtBudgPrec","MtRARPrec","MtPropNouv","MtPrev","CredOuv",
                 "MtReal","MtRAR3112","OpBudg","TypOpBudg","OpeCpteTiers", "MtSup" , "CaracSup"]

# %%
start_time = datetime.now()
with open("./M71_2020/99_BU-033-200053759-20210727-CA_2020_BP_1-BF-1-1_1.XML", encoding='latin-1') as fd:
    doc = xmltodict.parse(fd.read())
# Ordered dict to simple dict
doc = json.loads(json.dumps(doc))
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:00:03.360858

# %%
len(doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]["CONCOURS"])
# Out:
# 21088

# %%
def parsing_infos_collectivite(dict_from_xml: dict):
    infos_dict = dict()
    infos_dict["siret_coll"] = dict_from_xml["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["IdColl"]["@V"]
    infos_dict["libelle_collectivite"] = dict_from_xml["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["LibelleColl"]["@V"]
    infos_dict["nature_collectivite"] = dict_from_xml["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["NatCEPL"]["@V"]
    if "Departement" in dict_from_xml["DocumentBudgetaire"]["EnTeteDocBudgetaire"]:
        infos_dict["departement"] = dict_from_xml["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["Departement"]["@V"]

    return infos_dict

def parsing_infos_etablissement(dict_from_xml: dict):
    infos_dict = dict()
    infos_dict["siret_etablissement"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["EnTeteBudget"]["IdEtab"]["@V"]
    infos_dict["libelle"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["EnTeteBudget"]["LibelleEtab"]["@V"]
    if "LibelleEtab" in dict_from_xml["DocumentBudgetaire"]["Budget"]["EnTeteBudget"]:
        infos_dict["code_insee"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["EnTeteBudget"]["LibelleEtab"]["@V"]
    infos_dict["nomenclature"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["EnTeteBudget"]["Nomenclature"]["@V"]
    infos_dict["exercice"] = int(dict_from_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"]["Exer"]["@V"])
    infos_dict["nature_dec"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"]["NatDec"]["@V"]
    if "NumDec" in dict_from_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"]:
        infos_dict["NumDec"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"]["NumDec"]["@V"]
    infos_dict["nature_vote"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"]["NatFonc"]["@V"]
    infos_dict["type_budget"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"]["CodTypBud"]["@V"]
    if "IdEtabPal" in dict_from_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"]:
        infos_dict["id_etabl_princ"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"]["IdEtabPal"]["@V"]
    infos_dict["fk_id_collectivite"] = dict_from_xml["DocumentBudgetaire"]["Budget"]["EnTeteBudget"]["CodColl"]["@V"]
    
    return infos_dict

# %%
parsing_infos_etablissement(doc)
# Out:
# {'siret_etablissement': '20005340300057',
#  'libelle': 'Budget principal',
#  'code_insee': 'Budget principal',
#  'nomenclature': 'M71-M71',
#  'exercice': 2020,
#  'nature_dec': '01',
#  'nature_vote': '2',
#  'type_budget': 'P',
#  'id_etabl_princ': '20005340300057',
#  'fk_id_collectivite': '323'}

# %%
start_time = datetime.now()
with open("./M71_2020/99_BU-076-200053403-20191216-83959A-BF-1-1_1.xml", encoding='latin-1') as fd:
    doc = xmltodict.parse(fd.read(), dict_constructor=dict)
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:00:00.443630

# %%
if "DATA_DETTE" in doc["DocumentBudgetaire"]["Budget"]["Annexes"].keys():
    print("ok")

# %%
data = doc["DocumentBudgetaire"]["Budget"]["LigneBudget"]
dict_doc = dict()

for idx, row in enumerate(data):
        for field in BUDGET_FIELDS:
            if field in row:
                if "@V" in row[field]:
                    dict_doc[idx][field] = row[field]['@V']

# %%
#doc["DocumentBudgetaire"]["Budget"]["LigneBudget"]
annexes = set(doc["DocumentBudgetaire"]["Budget"]["Annexes"].keys())

# %%
import copy
temp_doc = copy.deepcopy(doc["DocumentBudgetaire"]["Budget"]["LigneBudget"])

for idx, row in enumerate(temp_doc):
    for field in BUDGET_FIELDS:
        if field in row:
            if "@V" in row[field]:
                temp_doc[idx][field] = row[field]['@V']

# %% [markdown]
# ## Dict to csv

# %%
data = doc["DocumentBudgetaire"]["Budget"]["LigneBudget"]

with open("./M71_2020_csv/99_BU-033-200053759-20210727-CA_2020_BP_1-BF-1-1_1.csv", "w") as csv_file:
    dict_writer = csv.DictWriter(csv_file, fieldnames=BUDGET_FIELDS)
    dict_writer.writeheader()
    dict_writer.writerows(data)

# %% [markdown]
# ## csv concours

# %%
CONCOURS_FIELDS = "SIRET_etablissement, Champ_Editeur, CodArticle, CodInvFonc, CodNatJurBenefCA, DenomOuNumSubv, LibOrgaBenef, LibPrestaNat, MtSubv, ObjSubv, PopCommune, Siret".split(", ")

# %%
data = doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS']

temp_doc = doc
for idx, row in enumerate(data):
    for field in CONCOURS_FIELDS:
        if field in row:
            if "@V" in row[field]:
                temp_doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS'][idx][field] = row[field]['@V']
    temp_doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS'][idx]["SIRET"] = temp_doc["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["IdColl"]["@V"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7513/2541958557.py in <module>
# ----> 1 data = doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS']
#       2
#       3 temp_doc = doc
#       4 for idx, row in enumerate(data):
#       5     for field in CONCOURS_FIELDS:
#
# NameError: name 'doc' is not defined

# %%
[doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS']] 
if isinstance(doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS'], dict) else 
doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS']
# Out:
# {'CodArticle': {'@V': '65821'},
#  'CodInvFonc': {'@V': 'F'},
#  'CodNatJurBenefCA': {'@V': 'U1'},
#  'LibOrgaBenef': {'@V': 'Budget Annexe de la Restauration Administrative'},
#  'MtSubv': {'@V': '446786.0'},
#  'DenomOuNumSubv': {'@V': 'BP 2020 - Subvention au Budget de la Restauration Administrative'},
#  'ObjSubv': {'@V': "Subvention d'Equilibre"}}

# %%
import copy

def generate_dict_annexe_concours(doc_xml):
    temp_doc =  copy.deepcopy(doc_xml["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS'])
    
    temp_doc = [temp_doc] if isinstance(temp_doc, dict) else temp_doc
    for idx, row in enumerate(temp_doc):
        for field in CONCOURS_FIELDS:
            if field in row:
                if "@V" in row[field]:
                    temp_doc[idx][field] = row[field]['@V']
        temp_doc[idx]["SIRET_etablissement"] = doc_xml["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["IdColl"]["@V"]
    return temp_doc

# %%
def generate_dict_annexe(dict_from_xml: dict, nom_annexe: str, liste_champs_annexe: list) -> dict:
    annexe_dict = copy.deepcopy(dict_from_xml["DocumentBudgetaire"]["Budget"]["Annexes"]
                                [nom_annexe][nom_annexe.split("_", 1)[1]])
    annexe_dict = [annexe_dict] if isinstance(
        annexe_dict, dict) else annexe_dict
    for idx, row in enumerate(annexe_dict):
        for field in liste_champs_annexe:
            if field in row:
                if "@V" in row[field]:
                    annexe_dict[idx][field] = row[field]['@V']
    return annexe_dict

# %%
# Out:
# dict_keys(['DATA_EMPRUNT', 'DATA_TRESORERIE', 'DATA_TIERS', 'DATA_CONCOURS', 'DATA_RECETTE_AFFECTEE', 'DATA_FISCALITE', 'DATA_ORGANISME_ENG', 'DATA_ORGANISME_GROUP', 'DATA_PERSONNEL', 'DATA_AMORTISSEMENT_METHODE', 'DATA_PROVISION', 'DATA_APCP', 'DATA_SIGNATURE', 'DATA_ETAB_SERVICE', 'DATA_PRET', 'DATA_SERVICE_FERROVIAIRE_BUD', 'DATA_SOMMAIRE'])

# %%
def create_annexes(dict_from_xml: dict):
    #quand est-ce qu'on append l'annexe au doc budgetaire ?
    liste_annexe = doc["DocumentBudgetaire"]["Budget"]["Annexes"].keys()
    dict_annexes = dict()
    for annexe in liste_annexe:
        dict_annexes[annexe] = generate_dict_annexe(dict_from_xml, annexe, CHAMPS_ANNEXES[annexe])
    return dict_annexes

# %%
dict_annexes = create_annexes(doc)

# %%
dict_annexes =  {"DATA_FORMATION": [
        {
            "NomElu": "ABELIN V\u00e9ronique",
            "ActionFinanc": "Budget primitif 2021 de la R\u00e9gion"
        },
        {
            "NomElu": "ABELIN V\u00e9ronique",
            "ActionFinanc": "Budget r\u00e9gional : budget primitif, d\u00e9cisions modificatives"
        },
        {
            "NomElu": "ABELIN V\u00e9ronique",
            "ActionFinanc": "D\u00e9bat d'orientation budg\u00e9taire dans le cadre d'une crise \u00e9conomique et sanitaire"
        },
        {
            "NomElu": "AGUERRE Barth\u00e9l\u00e9my",
            "ActionFinanc": "Finances R\u00e9gionales : enjeux et perspectives"
        },
        {
            "NomElu": "AGUERRE Barth\u00e9l\u00e9my",
            "ActionFinanc": "La R\u00e9gion face aux enjeux financiers et les cons\u00e9quences de la Covid-19"
        },
        {
            "NomElu": "AMMOUCHE Soraya",
            "ActionFinanc": "Prise de parole en public"
        },
        {
            "NomElu": "ARGENTON Xavier",
            "ActionFinanc": "Budget primitif 2021 de la R\u00e9gion"
        },
        {
            "NomElu": "ARGENTON Xavier",
            "ActionFinanc": "D\u00e9bat d'orientation budg\u00e9taire dans le cadre d'une crise \u00e9conomique et sanitaire"
        },
        {
            "NomElu": "BERROYER Jean-Paul",
            "ActionFinanc": "Bilan carri\u00e8re-\u00e9volution professionnelle/Panorama des forces politiques nationales conservatrices"
        },
        {
            "NomElu": "BOURDIN Katia",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "BOURDIN Katia",
            "ActionFinanc": "Les r\u00e9gions aujourd'hui et demain : concevoir des politiques r\u00e9gionales r\u00e9silientes et soutenables"
        },
        {
            "NomElu": "BOURDIN Katia",
            "ActionFinanc": "Les R\u00e9gions et l'Europe"
        },
        {
            "NomElu": "BOUSQUET-CASSAGNE Etienne",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "BOUSQUET-CASSAGNE Etienne",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "BROUILLE Andr\u00e9a",
            "ActionFinanc": "Les collectivit\u00e9s territoriales garantes du mieux-vivre ensemble et du progr\u00e8s"
        },
        {
            "NomElu": "BRUN Yveline",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "BRUN Yveline",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "CATHUS Christophe",
            "ActionFinanc": "Les collectivit\u00e9s territoriales garantes du mieux-vivre ensemble et du progr\u00e8s"
        },
        {
            "NomElu": "CHADJAA Sally",
            "ActionFinanc": "Budget primitif 2021 de la R\u00e9gion"
        },
        {
            "NomElu": "CHADJAA Sally",
            "ActionFinanc": "D\u00e9bat d'orientation budg\u00e9taire dans le cadre d'une crise \u00e9conomique et sanitaire"
        },
        {
            "NomElu": "CHADOURNE Sandrine",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "CHARBONNEAU Jean-Rom\u00e9e",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "CHARBONNEAU Jean-Rom\u00e9e",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "CHASSAGNE Christelle",
            "ActionFinanc": "Finances R\u00e9gionales : enjeux et perspectives"
        },
        {
            "NomElu": "CHAUMERON Lucie",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "CHAUMERON Lucie",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "COLOMBIER Jacques",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "COMBRES Maryse",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "COMBRES Maryse",
            "ActionFinanc": "Les r\u00e9gions aujourd'hui et demain : concevoir des politiques r\u00e9gionales r\u00e9silientes et soutenables"
        },
        {
            "NomElu": "COMBRES Maryse",
            "ActionFinanc": "Les R\u00e9gions et l'Europe"
        },
        {
            "NomElu": "COUTANT Fran\u00e7oise",
            "ActionFinanc": "Les r\u00e9gions aujourd'hui et demain : concevoir des politiques r\u00e9gionales r\u00e9silientes et soutenables"
        },
        {
            "NomElu": "DE AZEVEDO Aur\u00e9lie",
            "ActionFinanc": "Bilan carri\u00e8re-\u00e9volution professionnelle/Panorama des forces politiques nationales conservatrices"
        },
        {
            "NomElu": "DE LACOSTE-LAREYMONDIE Jean-Marc",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "DIAZ Edwige",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "DIAZ Edwige",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "DIONIS DU SEJOUR Jean",
            "ActionFinanc": "Finances R\u00e9gionales : enjeux et perspectives"
        },
        {
            "NomElu": "DIONIS DU SEJOUR Jean",
            "ActionFinanc": "La R\u00e9gion face aux enjeux financiers et les cons\u00e9quences de la Covid-19"
        },
        {
            "NomElu": "DRAPRON Bruno",
            "ActionFinanc": "Budget primitif 2021 de la R\u00e9gion"
        },
        {
            "NomElu": "DRAPRON Bruno",
            "ActionFinanc": "D\u00e9bat d'orientation budg\u00e9taire dans le cadre d'une crise \u00e9conomique et sanitaire"
        },
        {
            "NomElu": "DUBOIS Robert",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "DUBOIS Robert",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "FERREIRA Otilia",
            "ActionFinanc": "La R\u00e9gion face aux enjeux financiers et les cons\u00e9quences de la Covid-19"
        },
        {
            "NomElu": "FREL Lionel",
            "ActionFinanc": "Analyser l'impact de la crise sur les finances des r\u00e9gions"
        },
        {
            "NomElu": "FROPOS Sabine",
            "ActionFinanc": "Bilan carri\u00e8re-\u00e9volution professionnelle/Panorama des forces politiques nationales conservatrices"
        },
        {
            "NomElu": "GAMACHE Nicolas",
            "ActionFinanc": "Analyser l'impact de la crise sur les finances des r\u00e9gions"
        },
        {
            "NomElu": "GERARD Vincent",
            "ActionFinanc": "Bilan carri\u00e8re-\u00e9volution professionnelle/Panorama des forces politiques nationales conservatrices"
        },
        {
            "NomElu": "HENAUT Christelle",
            "ActionFinanc": "Bilan carri\u00e8re-\u00e9volution professionnelle/Panorama des forces politiques nationales conservatrices"
        },
        {
            "NomElu": "HUSTAIX Gilles",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "HUSTAIX Gilles",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "JOUBERT Florence",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "JOUBERT Florence",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "LAMARA Laurent",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "LAMARA Laurent",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "LE GUEN Nathalie",
            "ActionFinanc": "Bilan carri\u00e8re-\u00e9volution professionnelle/Panorama des forces politiques nationales conservatrices"
        },
        {
            "NomElu": "LEICIAGUECAHAR alice",
            "ActionFinanc": "Les r\u00e9gions aujourd'hui et demain : concevoir des politiques r\u00e9gionales r\u00e9silientes et soutenables"
        },
        {
            "NomElu": "LEICIAGUECAHAR alice",
            "ActionFinanc": "Les R\u00e9gions et l'Europe"
        },
        {
            "NomElu": "MARTY Christine",
            "ActionFinanc": "Bilan carri\u00e8re-\u00e9volution professionnelle/Panorama des forces politiques nationales conservatrices"
        },
        {
            "NomElu": "MOGA Martine",
            "ActionFinanc": "Finances R\u00e9gionales : enjeux et perspectives"
        },
        {
            "NomElu": "MOGA Martine",
            "ActionFinanc": "La R\u00e9gion face aux enjeux financiers et les cons\u00e9quences de la Covid-19"
        },
        {
            "NomElu": "MONCOND'HUY L\u00e9onore",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "MONCOND'HUY L\u00e9onore",
            "ActionFinanc": "Les R\u00e9gions et l'Europe"
        },
        {
            "NomElu": "MOTOMAN Laurence",
            "ActionFinanc": "Les r\u00e9gions aujourd'hui et demain : concevoir des politiques r\u00e9gionales r\u00e9silientes et soutenables"
        },
        {
            "NomElu": "ORVAIN J\u00e9r\u00f4me",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "ORVAIN J\u00e9r\u00f4me",
            "ActionFinanc": "Les r\u00e9gions aujourd'hui et demain : concevoir des politiques r\u00e9gionales r\u00e9silientes et soutenables"
        },
        {
            "NomElu": "ORVAIN J\u00e9r\u00f4me",
            "ActionFinanc": "Les R\u00e9gions et l'Europe"
        },
        {
            "NomElu": "OZSOY Mumine",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "PAGES Jean-Louis",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "PAGES Jean-Louis",
            "ActionFinanc": "Les r\u00e9gions aujourd'hui et demain : concevoir des politiques r\u00e9gionales r\u00e9silientes et soutenables"
        },
        {
            "NomElu": "PALUTEAU Bruno",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "PALUTEAU Bruno",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "PERREAU Thierry",
            "ActionFinanc": "Analyser l'impact de la crise sur les finances des r\u00e9gions"
        },
        {
            "NomElu": "PERREAU Thierry",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "PERREAU Thierry",
            "ActionFinanc": "Les r\u00e9gions aujourd'hui et demain : concevoir des politiques r\u00e9gionales r\u00e9silientes et soutenables"
        },
        {
            "NomElu": "REQUENNA Pascale",
            "ActionFinanc": "Finances R\u00e9gionales : enjeux et perspectives"
        },
        {
            "NomElu": "REQUENNA Pascale",
            "ActionFinanc": "La R\u00e9gion face aux enjeux financiers et les cons\u00e9quences de la Covid-19"
        },
        {
            "NomElu": "ROGISTER Thierry",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "ROGISTER Thierry",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "SAINT PE Denise",
            "ActionFinanc": "La R\u00e9gion face aux enjeux financiers et les cons\u00e9quences de la Covid-19"
        },
        {
            "NomElu": "SEBTON Aur\u00e9lien",
            "ActionFinanc": "Budget primitif 2021 de la R\u00e9gion"
        },
        {
            "NomElu": "SEBTON Aur\u00e9lien",
            "ActionFinanc": "Budget r\u00e9gional : budget primitif, d\u00e9cisions modificatives"
        },
        {
            "NomElu": "SEBTON Aur\u00e9lien",
            "ActionFinanc": "D\u00e9bat d'orientation budg\u00e9taire dans le cadre d'une crise \u00e9conomique et sanitaire"
        },
        {
            "NomElu": "SEBTON Aur\u00e9lien",
            "ActionFinanc": "Prise de parole en public"
        },
        {
            "NomElu": "SEGUINAU Christine",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "SEGUINAU Christine",
            "ActionFinanc": "Les R\u00e9gions et l'Europe"
        },
        {
            "NomElu": "TIRANT Beno\u00eet ",
            "ActionFinanc": "Les collectivit\u00e9s territoriales garantes du mieux-vivre ensemble et du progr\u00e8s"
        },
        {
            "NomElu": "TRIFILETTI St\u00e9phane",
            "ActionFinanc": "Envisager le r\u00f4le des r\u00e9gions et celui de leurs \u00e9lu-es dans l'apr\u00e8s-crise"
        },
        {
            "NomElu": "TRIFILETTI St\u00e9phane",
            "ActionFinanc": "Les R\u00e9gions et l'Europe"
        },
        {
            "NomElu": "VERDIN Alain",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "VERDIN Alain",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        },
        {
            "NomElu": "VEUNAC Michel",
            "ActionFinanc": "Finances R\u00e9gionales : enjeux et perspectives"
        },
        {
            "NomElu": "VEUNAC Michel",
            "ActionFinanc": "La R\u00e9gion face aux enjeux financiers et les cons\u00e9quences de la Covid-19"
        },
        {
            "NomElu": "VOLPATO Mireille",
            "ActionFinanc": "Faites de vos \u00e9motions un atout politique"
        },
        {
            "NomElu": "WERBROUCK S\u00e9verine",
            "ActionFinanc": "Gestion de la crise et Relance apr\u00e8s-crise"
        },
        {
            "NomElu": "WERBROUCK S\u00e9verine",
            "ActionFinanc": "Les relocalisations, enjeux vitaux de l'am\u00e9nagement du territoire"
        }
    ],
    "DATA_FISCALITE": [
        {
            "CodTypContrib": "D",
            "CodSousTypContrib": "05",
            "CodTypeCarburant": "01",
            "MtBaseNotif": "9374505.0",
            "TxVariBase": "-15.1",
            "TxApplicConsMunic": "1.77",
            "MtProdVote": "16592875",
            "TxVariProd": "-15.1",
            "Unite": "\u20ac"
        },
        {
            "CodTypContrib": "D",
            "CodSousTypContrib": "05",
            "CodTypeCarburant": "02",
            "MtBaseNotif": "36622340",
            "TxVariBase": "-13.2",
            "TxApplicConsMunic": "1.15",
            "MtProdVote": "42115691",
            "TxVariProd": "-13.2",
            "Unite": "\u20ac"
        },
        {
            "CodTypContrib": "D",
            "CodSousTypContrib": "24",
            "CodTypeCarburant": "01",
            "MtBaseNotif": "9374505.0",
            "TxVariBase": "-14.9",
            "TxApplicConsMunic": "0.73",
            "MtProdVote": "6843389.0",
            "TxVariProd": "-14.9",
            "Unite": "\u20ac"
        },
        {
            "CodTypContrib": "D",
            "CodSousTypContrib": "24",
            "CodTypeCarburant": "02",
            "MtBaseNotif": "36692561",
            "TxVariBase": "-13.2",
            "TxApplicConsMunic": "1.35",
            "MtProdVote": "49534957",
            "TxVariProd": "-13.2",
            "Unite": "\u20ac"
        },
        {
            "CodTypContrib": "D",
            "CodSousTypContrib": "07",
            "MtBaseNotif": "4555196.0",
            "TxVariBase": "-10.5",
            "TxApplicConsMunic": "41.0",
            "MtProdVote": "186763050",
            "TxVariProd": "-10.5",
            "Unite": "\u20ac"
        },
        {
            "CodTypContrib": "D",
            "CodSousTypContrib": "99",
            "MtProdVote": "301849961",
            "Unite": "\u20ac"
        }
    ],
    "DATA_CONSOLIDATION": [
        {
            "CodTypBudAgreg": "01",
            "CodInvFonc": "I",
            "CodRD": "R",
            "MtCredOuv": "2707828117.54",
            "MtRealMandatTitre": "2136641678.22",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900011"
        },
        {
            "CodTypBudAgreg": "01",
            "CodInvFonc": "F",
            "CodRD": "R",
            "MtCredOuv": "3094052130.52",
            "MtRealMandatTitre": "2923022514.17",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900011"
        },
        {
            "CodTypBudAgreg": "01",
            "CodInvFonc": "I",
            "CodRD": "D",
            "MtCredOuv": "2707828117.54",
            "MtRealMandatTitre": "1952579764.94",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900011"
        },
        {
            "CodTypBudAgreg": "01",
            "CodInvFonc": "F",
            "CodRD": "D",
            "MtCredOuv": "3094052130.52",
            "MtRealMandatTitre": "2658802296.87",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900011"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "1",
            "LibBudAnnex": "Energie Photovolta\u00efque",
            "CodInvFonc": "I",
            "CodRD": "R",
            "MtCredOuv": "149526.94",
            "MtRealMandatTitre": "78937",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900029"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "1",
            "LibBudAnnex": "Energie Photovolta\u00efque",
            "CodInvFonc": "F",
            "CodRD": "D",
            "MtCredOuv": "135643",
            "MtRealMandatTitre": "108039.88",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900029"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "1",
            "LibBudAnnex": "Energie Photovolta\u00efque",
            "CodInvFonc": "F",
            "CodRD": "R",
            "MtCredOuv": "135643",
            "MtRealMandatTitre": "86290.37",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900029"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "1",
            "LibBudAnnex": "Energie Photovolta\u00efque",
            "CodInvFonc": "I",
            "CodRD": "D",
            "MtCredOuv": "149526.94",
            "MtRealMandatTitre": "71552.05",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900029"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "2",
            "LibBudAnnex": "Cin\u00e9ma",
            "CodInvFonc": "F",
            "CodRD": "R",
            "MtCredOuv": "388505.14",
            "MtRealMandatTitre": "70918",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900037"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "2",
            "LibBudAnnex": "Cin\u00e9ma",
            "CodInvFonc": "I",
            "CodRD": "D",
            "MtCredOuv": "70918",
            "MtRealMandatTitre": "70918",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900037"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "2",
            "LibBudAnnex": "Cin\u00e9ma",
            "CodInvFonc": "I",
            "CodRD": "R",
            "MtCredOuv": "229037.59",
            "MtRealMandatTitre": "70918",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900037"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "2",
            "LibBudAnnex": "Cin\u00e9ma",
            "CodInvFonc": "F",
            "CodRD": "D",
            "MtCredOuv": "250918",
            "MtRealMandatTitre": "185105.61",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900037"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "3",
            "LibBudAnnex": "Ag. R\u00e9gionale de l'Innovation",
            "CodInvFonc": "I",
            "CodRD": "D",
            "MtCredOuv": "207089.65",
            "MtRealMandatTitre": "107504.07",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900052"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "3",
            "LibBudAnnex": "Ag. R\u00e9gionale de l'Innovation",
            "CodInvFonc": "F",
            "CodRD": "R",
            "MtCredOuv": "265984.52",
            "MtRealMandatTitre": "85789.65",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900052"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "3",
            "LibBudAnnex": "Ag. R\u00e9gionale de l'Innovation",
            "CodInvFonc": "I",
            "CodRD": "R",
            "MtCredOuv": "1013464.88",
            "MtRealMandatTitre": "126054.85",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900052"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "3",
            "LibBudAnnex": "Ag. R\u00e9gionale de l'Innovation",
            "CodInvFonc": "F",
            "CodRD": "D",
            "MtCredOuv": "107589.65",
            "MtRealMandatTitre": "85789.65",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900052"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "4",
            "LibBudAnnex": "Prog. Op\u00e9rationnel Europ\u00e9en",
            "CodInvFonc": "F",
            "CodRD": "R",
            "MtCredOuv": "105503232.51",
            "MtRealMandatTitre": "89294289.69",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900045"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "4",
            "LibBudAnnex": "Prog. Op\u00e9rationnel Europ\u00e9en",
            "CodInvFonc": "F",
            "CodRD": "D",
            "MtCredOuv": "105503232.51",
            "MtRealMandatTitre": "91946123.01",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900045"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "4",
            "LibBudAnnex": "Prog. Op\u00e9rationnel Europ\u00e9en",
            "CodInvFonc": "I",
            "CodRD": "D",
            "MtCredOuv": "179477383.16",
            "MtRealMandatTitre": "169633653.96",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900045"
        },
        {
            "CodTypBudAgreg": "02",
            "CodBudAnnex": "4",
            "LibBudAnnex": "Prog. Op\u00e9rationnel Europ\u00e9en",
            "CodInvFonc": "I",
            "CodRD": "R",
            "MtCredOuv": "211994129.08",
            "MtRealMandatTitre": "184192663.91",
            "RAR": "0",
            "SiretBudAnnexe": "20005375900045"
        }
    ],
    "DATA_ORGANISME_ENG": [
        {
            "CodNatEng": "01",
            "DtEng": "2008-12-15",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2008.2942 ",
            "NomOrgEng": "CHAMBRE DE COMMERCE ET D'INDUSTRIE DE BAYONNE PAYS BASQUE",
            "RSOrgEng": "CHAMBRE DE COMMERCE ET D'INDUSTRIE DE BAYONNE PAYS BASQUE",
            "NatJurOrgEng": "Organisme consulaire",
            "MtOrgEng": "0.0"
        },
        {
            "CodNatEng": "01",
            "DtEng": "2006-06-19",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b02006.0940 ",
            "NomOrgEng": "COMMUNAUTE D'AGGLOMERATION DE BAYONNE-ANGLET-BIARRITZ ",
            "RSOrgEng": "COMMUNAUTE D'AGGLOMERATION DE BAYONNE-ANGLET-BIARRITZ ",
            "NatJurOrgEng": "Communaut\u00e9 d'Agglom\u00e9ration",
            "MtOrgEng": "0.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "10H11 ",
            "RSOrgEng": "10H11 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "101500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "13 VENTS ECOLE INT METIERS COMP LIMOUS ",
            "RSOrgEng": "13 VENTS ECOLE INT METIERS COMP LIMOUS ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "44849.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "13 VENTS ECOLE INT METIERS COMP LIMOUS ",
            "RSOrgEng": "13 VENTS ECOLE INT METIERS COMP LIMOUS ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "183586.21"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "13 VENTS ECOLE INT METIERS COMP LIMOUS ",
            "RSOrgEng": "13 VENTS ECOLE INT METIERS COMP LIMOUS ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "12772.5"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "13 VENTS ECOLE INT METIERS COMP LIMOUS ",
            "RSOrgEng": "13 VENTS ECOLE INT METIERS COMP LIMOUS ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "71963.34"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "1B2L ",
            "RSOrgEng": "1B2L ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "146590.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "2D-3D ANIMATIONS ",
            "RSOrgEng": "2D-3D ANIMATIONS ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "3943.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "2D-3D ANIMATIONS ",
            "RSOrgEng": "2D-3D ANIMATIONS ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "2D-3D ANIMATIONS ",
            "RSOrgEng": "2D-3D ANIMATIONS ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "2 GARENI INDUSTRIE ",
            "RSOrgEng": "2 GARENI INDUSTRIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "32468.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "2 GARENI INDUSTRIE ",
            "RSOrgEng": "2 GARENI INDUSTRIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "49510.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "3F RESIDENCES ",
            "RSOrgEng": "3F RESIDENCES ",
            "NatJurOrgEng": "SA de HLM \u00e0 conseil d'administration",
            "MtOrgEng": "600000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "9\u00c8ME ART ",
            "RSOrgEng": "9\u00c8ME ART ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "520000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ABBAYE AUX DAMES LA CITE MUSICALE SAINTES",
            "RSOrgEng": "ABBAYE AUX DAMES LA CITE MUSICALE SAINTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "64950.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ABBAYE AUX DAMES LA CITE MUSICALE SAINTES",
            "RSOrgEng": "ABBAYE AUX DAMES LA CITE MUSICALE SAINTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "151550.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ABBAYE ST ANDRE ",
            "RSOrgEng": "ABBAYE ST ANDRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ABBAYE ST ANDRE ",
            "RSOrgEng": "ABBAYE ST ANDRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "22500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ABBAYE ST ANDRE ",
            "RSOrgEng": "ABBAYE ST ANDRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "52500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ABYSSA ",
            "RSOrgEng": "ABYSSA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "250000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ACA ",
            "RSOrgEng": "ACA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "530442.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ACADEMIE MUSIQUE M RAVEL ",
            "RSOrgEng": "ACADEMIE MUSIQUE M RAVEL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ACADEMIE MUSIQUE M RAVEL ",
            "RSOrgEng": "ACADEMIE MUSIQUE M RAVEL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ACADEMIE MUSIQUE M RAVEL ",
            "RSOrgEng": "ACADEMIE MUSIQUE M RAVEL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "42500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ACADEMIE MUSIQUE M RAVEL ",
            "RSOrgEng": "ACADEMIE MUSIQUE M RAVEL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ACCLIMATERRA - COMITE SCIENTIFIQUE REG IONAL SUR LE CHANGEMENT CLIMATIQUE",
            "RSOrgEng": "ACCLIMATERRA - COMITE SCIENTIFIQUE REG IONAL SUR LE CHANGEMENT CLIMATIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "76566.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ACEASCOP FORMASCOPE ",
            "RSOrgEng": "ACEASCOP FORMASCOPE ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "68538.79"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ACEASCOP FORMASCOPE ",
            "RSOrgEng": "ACEASCOP FORMASCOPE ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "125380.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ACTION POUR DEVELOP. ECONOMIQ FINANCE PARTICIPATIVE ADEFIP",
            "RSOrgEng": "ACTION POUR DEVELOP. ECONOMIQ FINANCE PARTICIPATIVE ADEFIP",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ACTION POUR DEVELOP. ECONOMIQ FINANCE PARTICIPATIVE ADEFIP",
            "RSOrgEng": "ACTION POUR DEVELOP. ECONOMIQ FINANCE PARTICIPATIVE ADEFIP",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19429.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ACTION POUR DEVELOP. ECONOMIQ FINANCE PARTICIPATIVE ADEFIP",
            "RSOrgEng": "ACTION POUR DEVELOP. ECONOMIQ FINANCE PARTICIPATIVE ADEFIP",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "95200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "ACTIV INSIDE ",
            "RSOrgEng": "ACTIV INSIDE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2021-01-29",
            "NatEng": "Subvention",
            "NomOrgEng": "ACTIV INSIDE ",
            "RSOrgEng": "ACTIV INSIDE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "11080.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ADAIAQ ",
            "RSOrgEng": "ADAIAQ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "162653.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ADAIAQ ",
            "RSOrgEng": "ADAIAQ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "155000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ADAIAQ ",
            "RSOrgEng": "ADAIAQ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "152904.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ADAIAQ ",
            "RSOrgEng": "ADAIAQ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10713.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ADAIAQ ",
            "RSOrgEng": "ADAIAQ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1325.81"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ADAIAQ ",
            "RSOrgEng": "ADAIAQ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "339000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ADAM ",
            "RSOrgEng": "ADAM ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "111000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ADAM ",
            "RSOrgEng": "ADAM ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "18931.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ADERA ",
            "RSOrgEng": "ADERA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ADERA ",
            "RSOrgEng": "ADERA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "381000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ADERA ",
            "RSOrgEng": "ADERA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "56377.72"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ADIT - SOCIETE NATIONAL D'INTELLIGENCE STRATEGIQUE",
            "RSOrgEng": "ADIT - SOCIETE NATIONAL D'INTELLIGENCE STRATEGIQUE",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ADOPT ",
            "RSOrgEng": "ADOPT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "77185.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ADVANCED ISOTOPIC ANALYSIS ",
            "RSOrgEng": "ADVANCED ISOTOPIC ANALYSIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "115000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ADV TECH ",
            "RSOrgEng": "ADV TECH ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "57500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ADV TECH ",
            "RSOrgEng": "ADV TECH ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "112000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "AELIS FARMA ",
            "RSOrgEng": "AELIS FARMA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "250000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROCAMPUS AQUITAINE ",
            "RSOrgEng": "AEROCAMPUS AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "216000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROCAMPUS AQUITAINE ",
            "RSOrgEng": "AEROCAMPUS AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "175000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROCAMPUS AQUITAINE ",
            "RSOrgEng": "AEROCAMPUS AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2284920.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROCAMPUS AQUITAINE ",
            "RSOrgEng": "AEROCAMPUS AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "29509.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AERODIODE ",
            "RSOrgEng": "AERODIODE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-20",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROLYCE ",
            "RSOrgEng": "AEROLYCE ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "123024.26"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROLYCE SARL ",
            "RSOrgEng": "AEROLYCE SARL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "340319.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPACE VALLEY ",
            "RSOrgEng": "AEROSPACE VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "55264.23"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPACE VALLEY ",
            "RSOrgEng": "AEROSPACE VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "72000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPACE VALLEY ",
            "RSOrgEng": "AEROSPACE VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPACE VALLEY ",
            "RSOrgEng": "AEROSPACE VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "173475.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPACE VALLEY ",
            "RSOrgEng": "AEROSPACE VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "22000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPACE VALLEY ",
            "RSOrgEng": "AEROSPACE VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "469340.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPACE VALLEY ",
            "RSOrgEng": "AEROSPACE VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPACE VALLEY ",
            "RSOrgEng": "AEROSPACE VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "70308.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AEROSPLINE ",
            "RSOrgEng": "AEROSPLINE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "164179.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "AEVA ",
            "RSOrgEng": "AEVA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "56964.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AEVA ",
            "RSOrgEng": "AEVA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AFDAS ",
            "RSOrgEng": "AFDAS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27531.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AFDAS ",
            "RSOrgEng": "AFDAS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "RSOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "33672.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "RSOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "RSOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "RSOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6790.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "RSOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "RSOrgEng": "AFDI NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "RSOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "RSOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7104.37"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "RSOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16820.51"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "RSOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "RSOrgEng": "AFIPAR FORMAT ET INFORMAT DES PAYSANS RURAUX",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-01-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AFPBTP DE LA VIENNE CFA BATIMENT",
            "RSOrgEng": "AFPBTP DE LA VIENNE CFA BATIMENT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1061450.88"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AFPBTP DE LA VIENNE CFA BATIMENT",
            "RSOrgEng": "AFPBTP DE LA VIENNE CFA BATIMENT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "249000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGEC - AQUITAINE GROUPEMENT EMPLOYEURS CULTURE",
            "RSOrgEng": "AGEC - AQUITAINE GROUPEMENT EMPLOYEURS CULTURE",
            "NatJurOrgEng": "Groupement d'employeurs",
            "MtOrgEng": "54600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "AGEC - AQUITAINE GROUPEMENT EMPLOYEURS CULTURE",
            "RSOrgEng": "AGEC - AQUITAINE GROUPEMENT EMPLOYEURS CULTURE",
            "NatJurOrgEng": "Groupement d'employeurs",
            "MtOrgEng": "124900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AGEFOS PME NOUVELLE-AQUITAINE ",
            "RSOrgEng": "AGEFOS PME NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "79183.28"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-12-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DE COOP\u00c9RATION INTERNATIONALE I NTERCO NOUVELLE-AQUITAINE",
            "RSOrgEng": "AGENCE DE COOP\u00c9RATION INTERNATIONALE I NTERCO NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DE COOP\u00c9RATION INTERNATIONALE I NTERCO NOUVELLE-AQUITAINE",
            "RSOrgEng": "AGENCE DE COOP\u00c9RATION INTERNATIONALE I NTERCO NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9257.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-12-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DE COOP\u00c9RATION INTERNATIONALE I NTERCO NOUVELLE-AQUITAINE",
            "RSOrgEng": "AGENCE DE COOP\u00c9RATION INTERNATIONALE I NTERCO NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "325800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DE L'ALIMENTATION NOUVELLE AQUI TAINE",
            "RSOrgEng": "AGENCE DE L'ALIMENTATION NOUVELLE AQUI TAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "263908.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DE L'ALIMENTATION NOUVELLE AQUI TAINE",
            "RSOrgEng": "AGENCE DE L'ALIMENTATION NOUVELLE AQUI TAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19547.42"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DE L'ALIMENTATION NOUVELLE AQUI TAINE",
            "RSOrgEng": "AGENCE DE L'ALIMENTATION NOUVELLE AQUI TAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3095290.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DE L'ALIMENTATION NOUVELLE AQUI TAINE",
            "RSOrgEng": "AGENCE DE L'ALIMENTATION NOUVELLE AQUI TAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36025.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "58144.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16775.63"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17960.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "437931.06"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-11",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "350000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "356668.54"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "33808.41"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4122.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "86995.68"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1701000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "78303.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5222450.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50104.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-30",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "388870.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "104132.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "48072.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "RSOrgEng": "AGENCE DEVELOP INNOVATION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "235728.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-05-29",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "RSOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16692.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "RSOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "RSOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "RSOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "RSOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5378.86"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "RSOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3049000.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "RSOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "RSOrgEng": "AGENCE LIVRE CIN\u00c9MA AUDIOVISUEL EN NOU VELLE-AQUITAINE - ALCA NOUVELLE-AQUITA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "RSOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6148.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "RSOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6148.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "RSOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "RSOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "68000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "RSOrgEng": "AGENCE LOCALE DE L ENERGIE ET DU CLIMAT ALEC",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9856.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE POUR LA VALORISATION DE LA RECH ERCHE UNIVERSITAIRE DU LIMOUSIN",
            "RSOrgEng": "AGENCE POUR LA VALORISATION DE LA RECH ERCHE UNIVERSITAIRE DU LIMOUSIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "74000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE POUR LA VALORISATION DE LA RECH ERCHE UNIVERSITAIRE DU LIMOUSIN",
            "RSOrgEng": "AGENCE POUR LA VALORISATION DE LA RECH ERCHE UNIVERSITAIRE DU LIMOUSIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "316500.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE POUR LA VALORISATION DE LA RECH ERCHE UNIVERSITAIRE DU LIMOUSIN",
            "RSOrgEng": "AGENCE POUR LA VALORISATION DE LA RECH ERCHE UNIVERSITAIRE DU LIMOUSIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8560.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "RSOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "67101.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "RSOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "87298.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-12-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "RSOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "128661.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "RSOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "617601.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-30",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "RSOrgEng": "AGENCE REGIONALE DE LA BIODIVERSITE NO UVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "40769.87"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-09-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE VALOR RECHERCHE UNIV LIMOUSIN ",
            "RSOrgEng": "AGENCE VALOR RECHERCHE UNIV LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "8560.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE VALOR RECHERCHE UNIV LIMOUSIN ",
            "RSOrgEng": "AGENCE VALOR RECHERCHE UNIV LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "64675.07"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AGENCE VALOR RECHERCHE UNIV LIMOUSIN ",
            "RSOrgEng": "AGENCE VALOR RECHERCHE UNIV LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "55500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGORA ",
            "RSOrgEng": "AGORA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "126797.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRICULT FRANCAIS DEVELOP INTERNAT DOR DOGNE",
            "RSOrgEng": "AGRICULT FRANCAIS DEVELOP INTERNAT DOR DOGNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRICULT FRANCAIS DEVELOP INTERNAT DOR DOGNE",
            "RSOrgEng": "AGRICULT FRANCAIS DEVELOP INTERNAT DOR DOGNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRISUD INTERNATIONAL ",
            "RSOrgEng": "AGRISUD INTERNATIONAL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "48000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRISUD INTERNATIONAL ",
            "RSOrgEng": "AGRISUD INTERNATIONAL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "72953.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRISUD INTERNATIONAL ",
            "RSOrgEng": "AGRISUD INTERNATIONAL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "55000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRISUD INTERNATIONAL ",
            "RSOrgEng": "AGRISUD INTERNATIONAL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRISUD INTERNATIONAL ",
            "RSOrgEng": "AGRISUD INTERNATIONAL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15310.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRISUD INTERNATIONAL ",
            "RSOrgEng": "AGRISUD INTERNATIONAL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "165000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRI SUD-OUEST INNOVATION ",
            "RSOrgEng": "AGRI SUD-OUEST INNOVATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRI SUD-OUEST INNOVATION ",
            "RSOrgEng": "AGRI SUD-OUEST INNOVATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRI SUD-OUEST INNOVATION ",
            "RSOrgEng": "AGRI SUD-OUEST INNOVATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRI SUD-OUEST INNOVATION ",
            "RSOrgEng": "AGRI SUD-OUEST INNOVATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "219899.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRITUBEL ",
            "RSOrgEng": "AGRITUBEL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "156891.53"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRITUBEL ",
            "RSOrgEng": "AGRITUBEL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "4000.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRO-ALIMENTAIRE INNOVATION RECHERCHE ",
            "RSOrgEng": "AGRO-ALIMENTAIRE INNOVATION RECHERCHE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "62262.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRO-ALIMENTAIRE INNOVATION RECHERCHE ",
            "RSOrgEng": "AGRO-ALIMENTAIRE INNOVATION RECHERCHE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "133315.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AGROPOLE SERVICES ",
            "RSOrgEng": "AGROPOLE SERVICES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-26",
            "NatEng": "Subvention",
            "NomOrgEng": "AGROPOLE SERVICES ",
            "RSOrgEng": "AGROPOLE SERVICES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47351.71"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGROPOLE SERVICES ",
            "RSOrgEng": "AGROPOLE SERVICES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-19",
            "NatEng": "Subvention",
            "NomOrgEng": "AGROPOLE SERVICES ",
            "RSOrgEng": "AGROPOLE SERVICES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-30",
            "NatEng": "Subvention",
            "NomOrgEng": "AGROPOLE SERVICES ",
            "RSOrgEng": "AGROPOLE SERVICES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75528.82"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AGRO TECHNIQUE MAINTENANCE ",
            "RSOrgEng": "AGRO TECHNIQUE MAINTENANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "97325.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AGUILA TECHNOLOGIE ",
            "RSOrgEng": "AGUILA TECHNOLOGIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "89000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "A.I.E.C. - ASS. INTER ETABLISSE MENTS DE CAMBO ECOLE D'AIDES SOIGN",
            "RSOrgEng": "A.I.E.C. - ASS. INTER ETABLISSE MENTS DE CAMBO ECOLE D'AIDES SOIGN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19136.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "A.I.E.C. - ASS. INTER ETABLISSE MENTS DE CAMBO ECOLE D'AIDES SOIGN",
            "RSOrgEng": "A.I.E.C. - ASS. INTER ETABLISSE MENTS DE CAMBO ECOLE D'AIDES SOIGN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "88000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AIO ",
            "RSOrgEng": "AIO ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "131446.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AIRELLE CORREZE ",
            "RSOrgEng": "AIRELLE CORREZE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "AIRELLE CORREZE ",
            "RSOrgEng": "AIRELLE CORREZE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11697.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "AIRELLE CORREZE ",
            "RSOrgEng": "AIRELLE CORREZE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AIR QUALITY PROCESS ",
            "RSOrgEng": "AIR QUALITY PROCESS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AIR QUALITY PROCESS ",
            "RSOrgEng": "AIR QUALITY PROCESS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "35500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AKKA I&S ",
            "RSOrgEng": "AKKA I&S ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "97834.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AKTO ",
            "RSOrgEng": "AKTO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "148326.12"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "AKTO ",
            "RSOrgEng": "AKTO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "221749.83"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AKTO ",
            "RSOrgEng": "AKTO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AKTO ",
            "RSOrgEng": "AKTO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "216300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AKTO ",
            "RSOrgEng": "AKTO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "125000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ALASER ",
            "RSOrgEng": "ALASER ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "106500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ALDUDARRAK BIDEO ",
            "RSOrgEng": "ALDUDARRAK BIDEO ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "10400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ALDUDARRAK BIDEO ",
            "RSOrgEng": "ALDUDARRAK BIDEO ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "72900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ALDUDARRAK BIDEO ",
            "RSOrgEng": "ALDUDARRAK BIDEO ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "170100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ALEDA SAS ",
            "RSOrgEng": "ALEDA SAS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "14850.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ALEDA SAS ",
            "RSOrgEng": "ALEDA SAS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "74919.95"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "ALGO'TECH INFORMATIQUE SAS ",
            "RSOrgEng": "ALGO'TECH INFORMATIQUE SAS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "28726.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ALGO'TECH INFORMATIQUE SAS ",
            "RSOrgEng": "ALGO'TECH INFORMATIQUE SAS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "102000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "ALLIANCE CAOUTCHOUC ",
            "RSOrgEng": "ALLIANCE CAOUTCHOUC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "25112.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ALLIANCE CAOUTCHOUC ",
            "RSOrgEng": "ALLIANCE CAOUTCHOUC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "82050.19"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ALLIANCE FORETS BOIS ",
            "RSOrgEng": "ALLIANCE FORETS BOIS ",
            "NatJurOrgEng": "Union de soci\u00e9t\u00e9s coop\u00e9ratives agricoles",
            "MtOrgEng": "210656.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ALLIANCE FORETS BOIS ",
            "RSOrgEng": "ALLIANCE FORETS BOIS ",
            "NatJurOrgEng": "Union de soci\u00e9t\u00e9s coop\u00e9ratives agricoles",
            "MtOrgEng": "20509.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ALLIANCE INNOVATION SANTE NOUVELLE-AQU ITAINE (ALLIS-NA)",
            "RSOrgEng": "ALLIANCE INNOVATION SANTE NOUVELLE-AQU ITAINE (ALLIS-NA)",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "227858.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ALMAY ",
            "RSOrgEng": "ALMAY ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "187480.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ALOGIA ",
            "RSOrgEng": "ALOGIA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "125000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ALSTOM TRANSPORT SA ",
            "RSOrgEng": "ALSTOM TRANSPORT SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "332165.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ALSTOM TRANSPORT SA ",
            "RSOrgEng": "ALSTOM TRANSPORT SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "79850.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AMBITION 2.24 NOUVELLE-AQUITAINE ",
            "RSOrgEng": "AMBITION 2.24 NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AMBITION 2.24 NOUVELLE-AQUITAINE ",
            "RSOrgEng": "AMBITION 2.24 NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AMCAD ENGINEERING ",
            "RSOrgEng": "AMCAD ENGINEERING ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AMCAD ENGINEERING ",
            "RSOrgEng": "AMCAD ENGINEERING ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "119600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AMPLITUDE SYSTEMES ",
            "RSOrgEng": "AMPLITUDE SYSTEMES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "64937.15"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AMPLITUDE SYSTEMES ",
            "RSOrgEng": "AMPLITUDE SYSTEMES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "288241.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AMVALOR ",
            "RSOrgEng": "AMVALOR ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "185250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ANEFA NOUVELLE-AQUITAINE ",
            "RSOrgEng": "ANEFA NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ANEFA NOUVELLE-AQUITAINE ",
            "RSOrgEng": "ANEFA NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ANTARCTIC FOODS AQUITAINE ",
            "RSOrgEng": "ANTARCTIC FOODS AQUITAINE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-30",
            "NatEng": "Subvention",
            "NomOrgEng": "ANTARCTIC FOODS AQUITAINE ",
            "RSOrgEng": "ANTARCTIC FOODS AQUITAINE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "121919.25"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ANTARES SELLIER FRANCE ",
            "RSOrgEng": "ANTARES SELLIER FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "127165.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "APDHES ",
            "RSOrgEng": "APDHES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "65045.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "APDHES ",
            "RSOrgEng": "APDHES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "246000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "APDHES ",
            "RSOrgEng": "APDHES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "APMAC ",
            "RSOrgEng": "APMAC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36728.65"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "APMAC ",
            "RSOrgEng": "APMAC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "281200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "APMAC ",
            "RSOrgEng": "APMAC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "APPLIED TECHNOLOGIES INTERNET ",
            "RSOrgEng": "APPLIED TECHNOLOGIES INTERNET ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "93971.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "APTIC ",
            "RSOrgEng": "APTIC ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "203073.64"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AQUASSAY ",
            "RSOrgEng": "AQUASSAY ",
            "NatJurOrgEng": "SA nationale \u00e0 directoire",
            "MtOrgEng": "63994.52"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "AQ
",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "119611.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS AND\u00c8RE NAHIA ",
            "RSOrgEng": "ASS AND\u00c8RE NAHIA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "42458.35"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS AND\u00c8RE NAHIA ",
            "RSOrgEng": "ASS AND\u00c8RE NAHIA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS AND\u00c8RE NAHIA ",
            "RSOrgEng": "ASS AND\u00c8RE NAHIA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS AND\u00c8RE NAHIA ",
            "RSOrgEng": "ASS AND\u00c8RE NAHIA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS BALLET BIARRITZ ",
            "RSOrgEng": "ASS BALLET BIARRITZ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "139834.32"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS BALLET BIARRITZ ",
            "RSOrgEng": "ASS BALLET BIARRITZ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "336700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS BELLAC SUR SCENE ",
            "RSOrgEng": "ASS BELLAC SUR SCENE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24980.05"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS BELLAC SUR SCENE ",
            "RSOrgEng": "ASS BELLAC SUR SCENE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9108.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS BELLAC SUR SCENE ",
            "RSOrgEng": "ASS BELLAC SUR SCENE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "72590.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS BRILAC ",
            "RSOrgEng": "ASS BRILAC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "201612.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS BRILAC ",
            "RSOrgEng": "ASS BRILAC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "153276.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS CLIMATOLOGIQUE MOYENNE-GARONNE ET SUD-OUEST",
            "RSOrgEng": "ASS CLIMATOLOGIQUE MOYENNE-GARONNE ET SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "62500.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS CLIMATOLOGIQUE MOYENNE-GARONNE ET SUD-OUEST",
            "RSOrgEng": "ASS CLIMATOLOGIQUE MOYENNE-GARONNE ET SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "54170.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS COOL'EURS DU MONDE ",
            "RSOrgEng": "ASS COOL'EURS DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "48769.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DE LA FONDATION ETUDIANTE POUR LA VILLE",
            "RSOrgEng": "ASS DE LA FONDATION ETUDIANTE POUR LA VILLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DE LA FONDATION ETUDIANTE POUR LA VILLE",
            "RSOrgEng": "ASS DE LA FONDATION ETUDIANTE POUR LA VILLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "58000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DE LA FONDATION ETUDIANTE POUR LA VILLE",
            "RSOrgEng": "ASS DE LA FONDATION ETUDIANTE POUR LA VILLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "37123.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DE LA FONDATION ETUDIANTE POUR LA VILLE",
            "RSOrgEng": "ASS DE LA FONDATION ETUDIANTE POUR LA VILLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEPT PUPILLES DE L'ENSEIGNEMENT PUBLIC DES PYR\u00c9N\u00c9ES ATLANTIQUES",
            "RSOrgEng": "ASS DEPT PUPILLES DE L'ENSEIGNEMENT PUBLIC DES PYR\u00c9N\u00c9ES ATLANTIQUES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "139000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEPT PUPILLES DE L'ENSEIGNEMENT PUBLIC DES PYR\u00c9N\u00c9ES ATLANTIQUES",
            "RSOrgEng": "ASS DEPT PUPILLES DE L'ENSEIGNEMENT PUBLIC DES PYR\u00c9N\u00c9ES ATLANTIQUES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17516.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DES ELEVEURS DE CHEVAUX NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS DES ELEVEURS DE CHEVAUX NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "55000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DES ELEVEURS DE CHEVAUX NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS DES ELEVEURS DE CHEVAUX NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19779.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "41096.82"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-12",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "92671.32"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13517.58"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "68631.21"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "102167.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "59422.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "RSOrgEng": "ASS DEVELOP AGRO-BIOLOGIE PERIGORD ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17150.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP APICULTURE NOUVELLEAQUITAI NE",
            "RSOrgEng": "ASS DEVELOP APICULTURE NOUVELLEAQUITAI NE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "65000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP APICULTURE NOUVELLEAQUITAI NE",
            "RSOrgEng": "ASS DEVELOP APICULTURE NOUVELLEAQUITAI NE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "130000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-11-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "RSOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "103432.48"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "RSOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19071.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-29",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "RSOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "275284.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "RSOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "62500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "RSOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "49341.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "RSOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "132369.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "RSOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "470366.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "RSOrgEng": "ASS DEVELOP ENSEIGN RECHER AQUITAINE ADERA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "159380.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "RSOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10464.34"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "RSOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "RSOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21516.67"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "RSOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "52822.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "RSOrgEng": "ASS DEV EMPLOI AGRIC RURAL LIMOUSIN ADEAR LIMOUSIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DU FESTIVAL DE LA FICTION ",
            "RSOrgEng": "ASS DU FESTIVAL DE LA FICTION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DU FESTIVAL DE LA FICTION ",
            "RSOrgEng": "ASS DU FESTIVAL DE LA FICTION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DU FESTIVAL DE LA FICTION ",
            "RSOrgEng": "ASS DU FESTIVAL DE LA FICTION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DU FLOCON A LA VAGUE ",
            "RSOrgEng": "ASS DU FLOCON A LA VAGUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DU FLOCON A LA VAGUE ",
            "RSOrgEng": "ASS DU FLOCON A LA VAGUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "98000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DU FLOCON A LA VAGUE ",
            "RSOrgEng": "ASS DU FLOCON A LA VAGUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DVPT PROMO POLE EUROP CERAMIQUE ",
            "RSOrgEng": "ASS DVPT PROMO POLE EUROP CERAMIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DVPT PROMO POLE EUROP CERAMIQUE ",
            "RSOrgEng": "ASS DVPT PROMO POLE EUROP CERAMIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "210000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS DVPT PROMO POLE EUROP CERAMIQUE ",
            "RSOrgEng": "ASS DVPT PROMO POLE EUROP CERAMIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10298.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "RSOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15728.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "RSOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9110.99"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "RSOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "129199.89"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "RSOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17610.02"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "RSOrgEng": "ASS EDUC ENS SCOLAIRE PRIVE ST GENES LG ET LP PRIVE ST GENES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7649.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "RSOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13132.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "RSOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11916.09"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "RSOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "584285.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "RSOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17550.86"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "RSOrgEng": "ASS EDUC SCOLAIRE DE PAU - ICBF LGT ET LP IMMACULEE CONCEPTION B-FRENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10339.44"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSELDOR ",
            "RSOrgEng": "ASSELDOR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "86395.36"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS FESTIVAL INTERNAT PROGRAM AUDIOVIS FIPA",
            "RSOrgEng": "ASS FESTIVAL INTERNAT PROGRAM AUDIOVIS FIPA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "125000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS FORMATION EDUC PERMANENT TIVOLI AFEPT",
            "RSOrgEng": "ASS FORMATION EDUC PERMANENT TIVOLI AFEPT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "29942.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS FORMATION EDUC PERMANENT TIVOLI AFEPT",
            "RSOrgEng": "ASS FORMATION EDUC PERMANENT TIVOLI AFEPT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS FORMATION EDUC PERMANENT TIVOLI AFEPT",
            "RSOrgEng": "ASS FORMATION EDUC PERMANENT TIVOLI AFEPT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60283.19"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS HEGALALDIA L'ENVOL",
            "RSOrgEng": "ASS HEGALALDIA L'ENVOL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS HEGALALDIA L'ENVOL",
            "RSOrgEng": "ASS HEGALALDIA L'ENVOL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS HEGALALDIA L'ENVOL",
            "RSOrgEng": "ASS HEGALALDIA L'ENVOL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3920.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS HEGALALDIA L'ENVOL",
            "RSOrgEng": "ASS HEGALALDIA L'ENVOL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "52612.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "24816.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "1039.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "24485.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "3700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "12242.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "53357.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "17139.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "9067.5"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "RSOrgEng": "ASS INITIATION ENV CONNAISSANCE NATURE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "20530.03"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "RSOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10158.79"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "RSOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "93117.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "RSOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "38500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "RSOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "69038.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "RSOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "277102.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "RSOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5844.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "RSOrgEng": "ASS INTERPROFESSIONNELLE BIO REGIONALE AQUITAINE LIMOUSIN POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS LES PAPILLONS BLANCS ",
            "RSOrgEng": "ASS LES PAPILLONS BLANCS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "88572.88"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS LIMOUSINE DES CHALLENGES ",
            "RSOrgEng": "ASS LIMOUSINE DES CHALLENGES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "21072.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-01-30",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS LIMOUSINE DES CHALLENGES ",
            "RSOrgEng": "ASS LIMOUSINE DES CHALLENGES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "69023.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS LIMOUSINE DES CHALLENGES ",
            "RSOrgEng": "ASS LIMOUSINE DES CHALLENGES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "67530.12"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS LIMOUSINE PROF TECH L INFORMAT ",
            "RSOrgEng": "ASS LIMOUSINE PROF TECH L INFORMAT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14559.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS LIMOUSINE PROF TECH L INFORMAT ",
            "RSOrgEng": "ASS LIMOUSINE PROF TECH L INFORMAT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14559.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS LIMOUSINE PROF TECH L INFORMAT ",
            "RSOrgEng": "ASS LIMOUSINE PROF TECH L INFORMAT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MISSION LOCALE DES DEUX RIVES ",
            "RSOrgEng": "ASS MISSION LOCALE DES DEUX RIVES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "94480.49"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MISSION LOCALE DES DEUX RIVES ",
            "RSOrgEng": "ASS MISSION LOCALE DES DEUX RIVES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MISSION LOCALE DES DEUX RIVES ",
            "RSOrgEng": "ASS MISSION LOCALE DES DEUX RIVES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15219.19"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MISSION LOCALE RURALE HAUTE VIENNE ",
            "RSOrgEng": "ASS MISSION LOCALE RURALE HAUTE VIENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "397356.25"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MISSION LOCALE RURALE HAUTE VIENNE ",
            "RSOrgEng": "ASS MISSION LOCALE RURALE HAUTE VIENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12499.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MISSION LOCALE RURALE HAUTE VIENNE ",
            "RSOrgEng": "ASS MISSION LOCALE RURALE HAUTE VIENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSICALARUE ",
            "RSOrgEng": "ASS MUSICALARUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSICALARUE ",
            "RSOrgEng": "ASS MUSICALARUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20340.56"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSICALARUE ",
            "RSOrgEng": "ASS MUSICALARUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "119000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14994.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "214.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5204.37"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27053.18"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4272.05"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-01-30",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "239483.27"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "88000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "105000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-19",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "RSOrgEng": "ASS MUSIQUES DE NUIT DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "123037.15"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS NATIONALE DES PRODUCTEURS DE NOISETTES",
            "RSOrgEng": "ASS NATIONALE DES PRODUCTEURS DE NOISETTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60213.55"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS NATIONALE DES PRODUCTEURS DE NOISETTES",
            "RSOrgEng": "ASS NATIONALE DES PRODUCTEURS DE NOISETTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "65358.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO AIDE PROMOTION EMPLOI DES JEUNES APEJ",
            "RSOrgEng": "ASSO AIDE PROMOTION EMPLOI DES JEUNES APEJ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "100348.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION CIRECA ",
            "RSOrgEng": "ASSOCIATION CIRECA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION DE GESTION DU CNAM EN R\u00c9GI ON NOUVELLE-AQUITAINE",
            "RSOrgEng": "ASSOCIATION DE GESTION DU CNAM EN R\u00c9GI ON NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "853016.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION DE GESTION DU CNAM EN R\u00c9GI ON NOUVELLE-AQUITAINE",
            "RSOrgEng": "ASSOCIATION DE GESTION DU CNAM EN R\u00c9GI ON NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "600000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION DE PREFIGURATION TARMAQ ",
            "RSOrgEng": "ASSOCIATION DE PREFIGURATION TARMAQ ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "294365.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION D\u00c9VELOPPEMENT PYR\u00c9N\u00c9ES PAR FORMATION",
            "RSOrgEng": "ASSOCIATION D\u00c9VELOPPEMENT PYR\u00c9N\u00c9ES PAR FORMATION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION D\u00c9VELOPPEMENT PYR\u00c9N\u00c9ES PAR FORMATION",
            "RSOrgEng": "ASSOCIATION D\u00c9VELOPPEMENT PYR\u00c9N\u00c9ES PAR FORMATION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION ELASTOPOLE ",
            "RSOrgEng": "ASSOCIATION ELASTOPOLE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15945.62"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION ELASTOPOLE ",
            "RSOrgEng": "ASSOCIATION ELASTOPOLE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "68352.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-09-14",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "RSOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4749.79"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "RSOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "RSOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "RSOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "RSOrgEng": "ASSOCIATION ESPRIT DE CORPS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "214900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION FOOTBALL CLUB GIRONDINS BORDEAUX",
            "RSOrgEng": "ASSOCIATION FOOTBALL CLUB GIRONDINS BORDEAUX",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION FOOTBALL CLUB GIRONDINS BORDEAUX",
            "RSOrgEng": "ASSOCIATION FOOTBALL CLUB GIRONDINS BORDEAUX",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION FOOTBALL CLUB GIRONDINS BORDEAUX",
            "RSOrgEng": "ASSOCIATION FOOTBALL CLUB GIRONDINS BORDEAUX",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "RSOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "105600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "RSOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "157421.53"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "RSOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "167967.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "RSOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "575400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "RSOrgEng": "ASSOCIATION LASER PHONIQUE HYPERFR\u00c9QUE NCES ET APPLICATIONS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MIGADO ",
            "RSOrgEng": "ASSOCIATION MIGADO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "39433.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MIGADO ",
            "RSOrgEng": "ASSOCIATION MIGADO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "309519.73"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MIGADO ",
            "RSOrgEng": "ASSOCIATION MIGADO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7037.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MIGADO ",
            "RSOrgEng": "ASSOCIATION MIGADO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5709.07"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MIGADO ",
            "RSOrgEng": "ASSOCIATION MIGADO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "66788.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-20",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MIGADO ",
            "RSOrgEng": "ASSOCIATION MIGADO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "139735.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MIGADO ",
            "RSOrgEng": "ASSOCIATION MIGADO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3500.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MIGADO ",
            "RSOrgEng": "ASSOCIATION MIGADO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "77163.03"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MUSIQUE ET HISTOIRE EN MON TIGNACOIS",
            "RSOrgEng": "ASSOCIATION MUSIQUE ET HISTOIRE EN MON TIGNACOIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MUSIQUE ET HISTOIRE EN MON TIGNACOIS",
            "RSOrgEng": "ASSOCIATION MUSIQUE ET HISTOIRE EN MON TIGNACOIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "63000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION MUSIQUE ET HISTOIRE EN MON TIGNACOIS",
            "RSOrgEng": "ASSOCIATION MUSIQUE ET HISTOIRE EN MON TIGNACOIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "RSOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "RSOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "RSOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "RSOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "RSOrgEng": "ASSOCIATION POUR L ENSEIGNEMENT DU NUM ERIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION RECHERCHE EMPLOI NOE ENTREPRISE - ARENE",
            "RSOrgEng": "ASSOCIATION RECHERCHE EMPLOI NOE ENTREPRISE - ARENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "49515.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION RECHERCHE EMPLOI NOE ENTREPRISE - ARENE",
            "RSOrgEng": "ASSOCIATION RECHERCHE EMPLOI NOE ENTREPRISE - ARENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "78600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION RECHERCHE EMPLOI NOE ENTREPRISE - ARENE",
            "RSOrgEng": "ASSOCIATION RECHERCHE EMPLOI NOE ENTREPRISE - ARENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7875.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION R\u00c9GIONALE DU TRAVAIL SOCIA L NOUVELLE-AQUITAINE",
            "RSOrgEng": "ASSOCIATION R\u00c9GIONALE DU TRAVAIL SOCIA L NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "750278.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION R\u00c9GIONALE DU TRAVAIL SOCIA L NOUVELLE-AQUITAINE",
            "RSOrgEng": "ASSOCIATION R\u00c9GIONALE DU TRAVAIL SOCIA L NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28650.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION R\u00c9GIONALE DU TRAVAIL SOCIA L NOUVELLE-AQUITAINE",
            "RSOrgEng": "ASSOCIATION R\u00c9GIONALE DU TRAVAIL SOCIA L NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3060000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION SECONDE CHANCE 24 ",
            "RSOrgEng": "ASSOCIATION SECONDE CHANCE 24 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17186.63"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION SECONDE CHANCE 24 ",
            "RSOrgEng": "ASSOCIATION SECONDE CHANCE 24 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "54000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION SECONDE CHANCE 24 ",
            "RSOrgEng": "ASSOCIATION SECONDE CHANCE 24 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "53625.41"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-11",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION SOYONS LE CHANGEMENT ",
            "RSOrgEng": "ASSOCIATION SOYONS LE CHANGEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "62646.36"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION SOYONS LE CHANGEMENT ",
            "RSOrgEng": "ASSOCIATION SOYONS LE CHANGEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION SOYONS LE CHANGEMENT ",
            "RSOrgEng": "ASSOCIATION SOYONS LE CHANGEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION UNIS-CITE ",
            "RSOrgEng": "ASSOCIATION UNIS-CITE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "122850.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION UNIS-CITE ",
            "RSOrgEng": "ASSOCIATION UNIS-CITE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "290500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION UNIS-CITE OCCITANIE ",
            "RSOrgEng": "ASSOCIATION UNIS-CITE OCCITANIE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5428.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION UNIS-CITE OCCITANIE ",
            "RSOrgEng": "ASSOCIATION UNIS-CITE OCCITANIE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION XLR ",
            "RSOrgEng": "ASSOCIATION XLR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION XLR ",
            "RSOrgEng": "ASSOCIATION XLR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION XLR ",
            "RSOrgEng": "ASSOCIATION XLR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION XLR ",
            "RSOrgEng": "ASSOCIATION XLR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "56000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION XYLOFUTUR PRODUITS ET MATERIAUX DES FORETS CULTIVEES",
            "RSOrgEng": "ASSOCIATION XYLOFUTUR PRODUITS ET MATERIAUX DES FORETS CULTIVEES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "42179.22"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOCIATION XYLOFUTUR PRODUITS ET MATERIAUX DES FORETS CULTIVEES",
            "RSOrgEng": "ASSOCIATION XYLOFUTUR PRODUITS ET MATERIAUX DES FORETS CULTIVEES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "152500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOC REGIONALE DIFFUSION ART CONTEMPORAIN",
            "RSOrgEng": "ASSOC REGIONALE DIFFUSION ART CONTEMPORAIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "43400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSOC REGIONALE DIFFUSION ART CONTEMPORAIN",
            "RSOrgEng": "ASSOC REGIONALE DIFFUSION ART CONTEMPORAIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "254500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO DEVELOPPEMENT DE L APPRENTISSAGE INDUSTRIEL DE L ADOUR - ADAI ADOUR",
            "RSOrgEng": "ASSO DEVELOPPEMENT DE L APPRENTISSAGE INDUSTRIEL DE L ADOUR - ADAI ADOUR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "72772.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO DEVELOPPEMENT DE L APPRENTISSAGE INDUSTRIEL DE L ADOUR - ADAI ADOUR",
            "RSOrgEng": "ASSO DEVELOPPEMENT DE L APPRENTISSAGE INDUSTRIEL DE L ADOUR - ADAI ADOUR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10135.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO DEVELOPPEMENT DE L APPRENTISSAGE INDUSTRIEL DE L ADOUR - ADAI ADOUR",
            "RSOrgEng": "ASSO DEVELOPPEMENT DE L APPRENTISSAGE INDUSTRIEL DE L ADOUR - ADAI ADOUR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "115200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "RSOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "523923.48"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "RSOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "34000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "RSOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "RSOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "51000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "RSOrgEng": "ASSO POUR LE DROIT A L INITIATIVE ECONOMIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO REGIONALE DES MISSIONS LOCALES NOUVELLE-AQUITAINE",
            "RSOrgEng": "ASSO REGIONALE DES MISSIONS LOCALES NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "160667.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASSO REGIONALE DES MISSIONS LOCALES NOUVELLE-AQUITAINE",
            "RSOrgEng": "ASSO REGIONALE DES MISSIONS LOCALES NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "32592.26"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "RSOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "73407.11"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "RSOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "48369.68"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "RSOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "RSOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "19638.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "RSOrgEng": "ASS OUVR COMPAG DEVOIR TOUR DE FRANCE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "31464.73"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PALSO ",
            "RSOrgEng": "ASS PALSO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PALSO ",
            "RSOrgEng": "ASS PALSO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8320.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PALSO ",
            "RSOrgEng": "ASS PALSO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "114333.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "RSOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "56500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "RSOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "RSOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4950.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "RSOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "44800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "RSOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "44000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "RSOrgEng": "ASS PARALL\u00c8LES ATTITUDES DIFFUSION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "RSOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10389.39"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "RSOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "RSOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1957.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "RSOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "37557.97"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "RSOrgEng": "ASS PAYS P\u00c9RIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "53000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "RSOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "RSOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "RSOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "RSOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3500.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "RSOrgEng": "ASS POUR DROIT A L INITIATIVE ECONOMIQ UE - ADIE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "195250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LA CREATION ET DEVELOPPEMENT ESPACE PAUL REBEYROLLE",
            "RSOrgEng": "ASS POUR LA CREATION ET DEVELOPPEMENT ESPACE PAUL REBEYROLLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23476.94"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LA CREATION ET DEVELOPPEMENT ESPACE PAUL REBEYROLLE",
            "RSOrgEng": "ASS POUR LA CREATION ET DEVELOPPEMENT ESPACE PAUL REBEYROLLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7155.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LA CREATION ET DEVELOPPEMENT ESPACE PAUL REBEYROLLE",
            "RSOrgEng": "ASS POUR LA CREATION ET DEVELOPPEMENT ESPACE PAUL REBEYROLLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "51800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "RSOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "219819.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "RSOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7560.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "RSOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "870000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "RSOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8926.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "RSOrgEng": "ASS POUR LA FORMATION EN MILIEU RURAL AFMR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "166400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "RSOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "148790.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "RSOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "77625.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "RSOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "490000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "RSOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "68170.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "RSOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "RSOrgEng": "ASS POUR LE DEVELOPPEMENT ECONOMIQUE ET SOCIAL - ADES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "65625.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR L ENVIRONNEMENT ET LA SECURITE EN AQUITAINE - APESA",
            "RSOrgEng": "ASS POUR L ENVIRONNEMENT ET LA SECURITE EN AQUITAINE - APESA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "268410.39"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS POUR L ENVIRONNEMENT ET LA SECURITE EN AQUITAINE - APESA",
            "RSOrgEng": "ASS POUR L ENVIRONNEMENT ET LA SECURITE EN AQUITAINE - APESA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "463268.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS RECH REG DVP HORTICULTURE ",
            "RSOrgEng": "ASS RECH REG DVP HORTICULTURE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "159437.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS RECH REG DVP HORTICULTURE ",
            "RSOrgEng": "ASS RECH REG DVP HORTICULTURE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "250917.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REG DE FORMATION PROF INDUSTRIE DU BOIS",
            "RSOrgEng": "ASS REG DE FORMATION PROF INDUSTRIE DU BOIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3966.03"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REG DE FORMATION PROF INDUSTRIE DU BOIS",
            "RSOrgEng": "ASS REG DE FORMATION PROF INDUSTRIE DU BOIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "441834.56"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REG DE FORMATION PROF INDUSTRIE DU BOIS",
            "RSOrgEng": "ASS REG DE FORMATION PROF INDUSTRIE DU BOIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20476.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REG DE FORMATION PROF INDUSTRIE DU BOIS",
            "RSOrgEng": "ASS REG DE FORMATION PROF INDUSTRIE DU BOIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "RSOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12462.33"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "RSOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "165508.27"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "RSOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61502.31"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "RSOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "RSOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4798.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "RSOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "130500.27"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "RSOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "284052.18"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "RSOrgEng": "ASS REGIONALE DES FEDERATIONS DE PECHE DE PROTECTION DU MILIEU AQ N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "111084.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4453011.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "22090.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "513996.53"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "239375.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "RSOrgEng": "ASS REGIONALE POUR L ORIENTATION LA FO RMATION ET L EMPLOI NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS SEPANSO ",
            "RSOrgEng": "ASS SEPANSO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS SEPANSO ",
            "RSOrgEng": "ASS SEPANSO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "55700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS SEPANSO ",
            "RSOrgEng": "ASS SEPANSO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2450.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS SEPANSO ",
            "RSOrgEng": "ASS SEPANSO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "66577.18"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS STE DE TIR DE LONS ",
            "RSOrgEng": "ASS STE DE TIR DE LONS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "92600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "RSOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "RSOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36208.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "RSOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-19",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "RSOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9809.2"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "RSOrgEng": "ASS TERRITOIRES ET INNOVATION SOCIALE - ATIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "32428.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS TRANSROCK ",
            "RSOrgEng": "ASS TRANSROCK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS TRANSROCK ",
            "RSOrgEng": "ASS TRANSROCK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "52500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS VACANCES OUVERTES ",
            "RSOrgEng": "ASS VACANCES OUVERTES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24036.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASS VACANCES OUVERTES ",
            "RSOrgEng": "ASS VACANCES OUVERTES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "96000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ASTRE ",
            "RSOrgEng": "ASTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ASTRE ",
            "RSOrgEng": "ASTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "22737.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ASTRE ",
            "RSOrgEng": "ASTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61950.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "RSOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat \u00e9conomique (GIE)",
            "MtOrgEng": "6029.51"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "RSOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat \u00e9conomique (GIE)",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "RSOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat \u00e9conomique (GIE)",
            "MtOrgEng": "38504.52"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "RSOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat \u00e9conomique (GIE)",
            "MtOrgEng": "1320.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "RSOrgEng": "ASTREDHOR SUD OUEST GIE FLEURS ET PLAN TES",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat \u00e9conomique (GIE)",
            "MtOrgEng": "50400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ATEK ",
            "RSOrgEng": "ATEK ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "91980.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ATELIER CHAUDRONNERIE LASER ACL 23 ",
            "RSOrgEng": "ATELIER CHAUDRONNERIE LASER ACL 23 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "90644.02"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ATELIER CHAUDRONNERIE LASER ACL 23 ",
            "RSOrgEng": "ATELIER CHAUDRONNERIE LASER ACL 23 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "321683.22"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ATELIER CONSEIL CREATION ENTREPRISES ACTIVITES LAN BERRI",
            "RSOrgEng": "ATELIER CONSEIL CREATION ENTREPRISES ACTIVITES LAN BERRI",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "81746.96"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ATELIER CONSEIL CREATION ENTREPRISES ACTIVITES LAN BERRI",
            "RSOrgEng": "ATELIER CONSEIL CREATION ENTREPRISES ACTIVITES LAN BERRI",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "9216.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ATELIER M\u00c9CANIQUE THOUARSAIS D ELECTRO \u00c9ROSION ET USINAGE - AMTHEUS",
            "RSOrgEng": "ATELIER M\u00c9CANIQUE THOUARSAIS D ELECTRO \u00c9ROSION ET USINAGE - AMTHEUS",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "89742.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ATELIERS BIGATA SAS ",
            "RSOrgEng": "ATELIERS BIGATA SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "193106.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ATE SOCI\u00c9T\u00c9 NOUVELLE ",
            "RSOrgEng": "ATE SOCI\u00c9T\u00c9 NOUVELLE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "76137.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ATILAC ",
            "RSOrgEng": "ATILAC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "3750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ATILAC ",
            "RSOrgEng": "ATILAC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "37810.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ATILAC ",
            "RSOrgEng": "ATILAC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "38410.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANDES ",
            "RSOrgEng": "ATLANDES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "122500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANPACK ",
            "RSOrgEng": "ATLANPACK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANPACK ",
            "RSOrgEng": "ATLANPACK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "74684.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANPACK ",
            "RSOrgEng": "ATLANPACK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLAN ROUTE ",
            "RSOrgEng": "ATLAN ROUTE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "143542.42"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANTECH ",
            "RSOrgEng": "ATLANTECH ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "89250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANTHAL ",
            "RSOrgEng": "ATLANTHAL ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "179720.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANTIC CLUSTER ",
            "RSOrgEng": "ATLANTIC CLUSTER ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "33601.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANTIC CLUSTER ",
            "RSOrgEng": "ATLANTIC CLUSTER ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "55717.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANTIQUE STADE ROCHELAIS ",
            "RSOrgEng": "ATLANTIQUE STADE ROCHELAIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "65000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANTIQUE STADE ROCHELAIS ",
            "RSOrgEng": "ATLANTIQUE STADE ROCHELAIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "39000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLANTIQUE STADE ROCHELAIS ",
            "RSOrgEng": "ATLANTIQUE STADE ROCHELAIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "91000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLAS SOUTENIR LES COMPETENCES ",
            "RSOrgEng": "ATLAS SOUTENIR LES COMPETENCES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLAS SOUTENIR LES COMPETENCES ",
            "RSOrgEng": "ATLAS SOUTENIR LES COMPETENCES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14774.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLAS SOUTENIR LES COMPETENCES ",
            "RSOrgEng": "ATLAS SOUTENIR LES COMPETENCES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ATLAS SOUTENIR LES COMPETENCES ",
            "RSOrgEng": "ATLAS SOUTENIR LES COMPETENCES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ATMO NOUVELLE AQUITAINE ",
            "RSOrgEng": "ATMO NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "184980.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ATMO NOUVELLE AQUITAINE ",
            "RSOrgEng": "ATMO NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "268000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "AUBERGE KOSKENIA ",
            "RSOrgEng": "AUBERGE KOSKENIA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AUBINEAU CONSTRUCTEUR ",
            "RSOrgEng": "AUBINEAU CONSTRUCTEUR ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "85602.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AUBIN IMPRIMEUR ",
            "RSOrgEng": "AUBIN IMPRIMEUR ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "99199.82"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AUBIN IMPRIMEUR ",
            "RSOrgEng": "AUBIN IMPRIMEUR ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "16721.89"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "AUDAP - AGENCE D'URBANISME ATLANTIQUE ET PYR\u00c9N\u00c9ES",
            "RSOrgEng": "AUDAP - AGENCE D'URBANISME ATLANTIQUE ET PYR\u00c9N\u00c9ES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "48000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "AUDAP - AGENCE D'URBANISME ATLANTIQUE ET PYR\u00c9N\u00c9ES",
            "RSOrgEng": "AUDAP - AGENCE D'URBANISME ATLANTIQUE ET PYR\u00c9N\u00c9ES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "126000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AUDENSIEL TECHNOLOGIES SUD-OUEST ",
            "RSOrgEng": "AUDENSIEL TECHNOLOGIES SUD-OUEST ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "104280.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "A'URBA AGENCE URB. BX METRO POLE AQUITAINE",
            "RSOrgEng": "A'URBA AGENCE URB. BX METRO POLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "A'URBA AGENCE URB. BX METRO POLE AQUITAINE",
            "RSOrgEng": "A'URBA AGENCE URB. BX METRO POLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "115250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AUSCHITZKY ",
            "RSOrgEng": "AUSCHITZKY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTHENTIC MEDIA ",
            "RSOrgEng": "AUTHENTIC MEDIA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "105000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS CASTERAN ",
            "RSOrgEng": "AUTOCARS CASTERAN ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "93499.83"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS CASTERAN ",
            "RSOrgEng": "AUTOCARS CASTERAN ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "26279.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS COURNIL ",
            "RSOrgEng": "AUTOCARS COURNIL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "58140.21"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS COURNIL ",
            "RSOrgEng": "AUTOCARS COURNIL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "17739.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS GERARDIN ",
            "RSOrgEng": "AUTOCARS GERARDIN ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "72226.92"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS GERARDIN ",
            "RSOrgEng": "AUTOCARS GERARDIN ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "29332.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS GERARDIN ",
            "RSOrgEng": "AUTOCARS GERARDIN ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "22644.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS PASCAL ",
            "RSOrgEng": "AUTOCARS PASCAL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "58032.52"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOCARS PASCAL ",
            "RSOrgEng": "AUTOCARS PASCAL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "34495.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOMOBILES CHATENET ",
            "RSOrgEng": "AUTOMOBILES CHATENET ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "97344.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOMOTIVE CELLS COMPANY SE ",
            "RSOrgEng": "AUTOMOTIVE CELLS COMPANY SE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 commerciale \u00e9trang\u00e8re immatricul\u00e9e au RCS",
            "MtOrgEng": "1750000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOUR DE MINUIT PRODUCTIONS ",
            "RSOrgEng": "AUTOUR DE MINUIT PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "AUTOUR DE MINUIT PRODUCTIONS ",
            "RSOrgEng": "AUTOUR DE MINUIT PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AVENIE ENERGIE ENVIRONNEMENT AVENIA",
            "RSOrgEng": "AVENIE ENERGIE ENVIRONNEMENT AVENIA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "52100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "AVENIE ENERGIE ENVIRONNEMENT AVENIA",
            "RSOrgEng": "AVENIE ENERGIE ENVIRONNEMENT AVENIA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "88000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AVENIE ENERGIE ENVIRONNEMENT AVENIA",
            "RSOrgEng": "AVENIE ENERGIE ENVIRONNEMENT AVENIA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "218071.74"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AVENIE ENERGIE ENVIRONNEMENT AVENIA",
            "RSOrgEng": "AVENIE ENERGIE ENVIRONNEMENT AVENIA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AVENIR ATLANTIQUE ",
            "RSOrgEng": "AVENIR ATLANTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "654787.01"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "AVENIR ATLANTIQUE ",
            "RSOrgEng": "AVENIR ATLANTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "170584.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "AVIRON BAYONNAIS RUGBY ",
            "RSOrgEng": "AVIRON BAYONNAIS RUGBY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "130000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "AVIRON BAYONNAIS RUGBY ",
            "RSOrgEng": "AVIRON BAYONNAIS RUGBY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "91000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AXE ET CIBLE ",
            "RSOrgEng": "AXE ET CIBLE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "223403.64"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "AXIS ",
            "RSOrgEng": "AXIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "198267.34"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "AXIS ",
            "RSOrgEng": "AXIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "32066.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "AZUR LIGHT SYSTEMS ",
            "RSOrgEng": "AZUR LIGHT SYSTEMS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "68456.96"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "AZUR LIGHT SYSTEMS ",
            "RSOrgEng": "AZUR LIGHT SYSTEMS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "26663.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "BABCOCK WANSON ",
            "RSOrgEng": "BABCOCK WANSON ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "151298.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "BABCOCK WANSON ",
            "RSOrgEng": "BABCOCK WANSON ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "24670.68"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "BACQUEYRISSES SOCI\u00c9T\u00c9 AUTOMOBILES ",
            "RSOrgEng": "BACQUEYRISSES SOCI\u00c9T\u00c9 AUTOMOBILES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "77613.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "BANQUE ALIMENTAIRE DE BORDEAUX ET GIRONDE",
            "RSOrgEng": "BANQUE ALIMENTAIRE DE BORDEAUX ET GIRONDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "92588.55"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "BANQUE ALIMENTAIRE DE BORDEAUX ET GIRONDE",
            "RSOrgEng": "BANQUE ALIMENTAIRE DE BORDEAUX ET GIRONDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "308750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "BANQUE ALIMENTAIRE DE BORDEAUX ET GIRONDE",
            "RSOrgEng": "BANQUE ALIMENTAIRE DE BORDEAUX ET GIRONDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "588341.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "BANQUE ALIMENTAIRE DE BORDEAUX ET GIRONDE",
            "RSOrgEng": "BANQUE ALIMENTAIRE DE BORDEAUX ET GIRONDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "348800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "BASE ",
            "RSOrgEng": "BASE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "10507.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "BASE ",
            "RSOrgEng": "BASE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "BASKALIA ",
            "RSOrgEng": "BASKALIA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "103154.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "BASKET LANDES SASP ",
            "RSOrgEng": "BASKET LANDES SASP ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "BASKET LANDES SASP ",
            "RSOrgEng": "BASKET LANDES SASP ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIMENT CFA LIMOUSIN ",
            "RSOrgEng": "BATIMENT CFA LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "144000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIMENT CFA LIMOUSIN ",
            "RSOrgEng": "BATIMENT CFA LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "78442.24"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIMENT CFA LIMOUSIN ",
            "RSOrgEng": "BATIMENT CFA LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "6628.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIMENT CFA LIMOUSIN ",
            "RSOrgEng": "BATIMENT CFA LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "6829.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIMENT CFA LIMOUSIN ",
            "RSOrgEng": "BATIMENT CFA LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "243600.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIMENT CFA LIMOUSIN ",
            "RSOrgEng": "BATIMENT CFA LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "48261.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIPRO ",
            "RSOrgEng": "BATIPRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "35529.37"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIPRO ",
            "RSOrgEng": "BATIPRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "34974.05"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIPRO ",
            "RSOrgEng": "BATIPRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "47019.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "BATIPRO ",
            "RSOrgEng": "BATIPRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "102433.74"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "BEARN PYRENEES VOYAGES ",
            "RSOrgEng": "BEARN PYRENEES VOYAGES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "338543.64"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "BEARN PYRENEES VOYAGES ",
            "RSOrgEng": "BEARN PYRENEES VOYAGES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "9843.22"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "BEARN PYRENEES VOYAGES ",
            "RSOrgEng": "BEARN PYRENEES VOYAGES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "43863.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "BELLE FACTORY ",
            "RSOrgEng": "BELLE FACTORY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "119850.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "BELLE FACTORY ",
            "RSOrgEng": "BELLE FACTORY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "BELLE FACTORY ",
            "RSOrgEng": "BELLE FACTORY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "129500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "BENOO INVEST ",
            "RSOrgEng": "BENOO INVEST ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "9500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "BENOO INVEST ",
            "RSOrgEng": "BENOO INVEST ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "147000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "BERNADET ",
            "RSOrgEng": "BERNADET ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "86194.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "BERNARD DUMAS SA ",
            "RSOrgEng": "BERNARD DUMAS SA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "14362.23"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "BERNARD DUMAS SA ",
            "RSOrgEng": "BERNARD DUMAS SA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "122038.53"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "BETONS 2 L AVANCE ",
            "RSOrgEng": "BETONS 2 L AVANCE ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "237725.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BETTERISE TECHNOLOGIES ",
            "RSOrgEng": "BETTERISE TECHNOLOGIES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "263200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-07-06",
            "NatEng": "Subvention",
            "NomOrgEng": "BEYOND THE SEA ",
            "RSOrgEng": "BEYOND THE SEA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "15924.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "BEYOND THE SEA ",
            "RSOrgEng": "BEYOND THE SEA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "400000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE LANDES TEC GE COOP ",
            "RSOrgEng": "BGE LANDES TEC GE COOP ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "65000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE LANDES TEC GE COOP ",
            "RSOrgEng": "BGE LANDES TEC GE COOP ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4875.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE LANDES TEC GE COOP ",
            "RSOrgEng": "BGE LANDES TEC GE COOP ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE LIMOUSIN ",
            "RSOrgEng": "BGE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "341958.31"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE LIMOUSIN ",
            "RSOrgEng": "BGE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15400.09"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE LIMOUSIN ",
            "RSOrgEng": "BGE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE LIMOUSIN ",
            "RSOrgEng": "BGE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19600.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE LIMOUSIN ",
            "RSOrgEng": "BGE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "54809.55"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD OUEST ",
            "RSOrgEng": "BGE SUD OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-04-03",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD OUEST ",
            "RSOrgEng": "BGE SUD OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3351.76"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD OUEST ",
            "RSOrgEng": "BGE SUD OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "32290.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD OUEST ",
            "RSOrgEng": "BGE SUD OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4875.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD OUEST ",
            "RSOrgEng": "BGE SUD OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11341.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD OUEST ",
            "RSOrgEng": "BGE SUD OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12950.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD OUEST ",
            "RSOrgEng": "BGE SUD OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-30",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD OUEST ",
            "RSOrgEng": "BGE SUD OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "56055.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD-OUEST ",
            "RSOrgEng": "BGE SUD-OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "123603.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "BGE SUD-OUEST ",
            "RSOrgEng": "BGE SUD-OUEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "BIDEGAIN PIERRE",
            "RSOrgEng": "BIDEGAIN PIERRE",
            "NatJurOrgEng": "Profession lib\u00e9rale",
            "MtOrgEng": "64869.68"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "BIDEGAIN PIERRE",
            "RSOrgEng": "BIDEGAIN PIERRE",
            "NatJurOrgEng": "Profession lib\u00e9rale",
            "MtOrgEng": "10131.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "RSOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "6750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "RSOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "23100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "RSOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "RSOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "96800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "RSOrgEng": "BIEN OU BIEN PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "16800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "BIOBEARN ",
            "RSOrgEng": "BIOBEARN ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "700000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "BIOENERGIES 123 ",
            "RSOrgEng": "BIOENERGIES 123 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "450000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "BIOMETHABEARN ",
            "RSOrgEng": "BIOMETHABEARN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "248950.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BIOPYTHOS ",
            "RSOrgEng": "BIOPYTHOS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "BIOPYTHOS ",
            "RSOrgEng": "BIOPYTHOS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "56113.78"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "BLANCHON ",
            "RSOrgEng": "BLANCHON ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "237417.92"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "BLANCHON ",
            "RSOrgEng": "BLANCHON ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BLAYE FERMETURES ",
            "RSOrgEng": "BLAYE FERMETURES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "123000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "BLAYE FERMETURES ",
            "RSOrgEng": "BLAYE FERMETURES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "17019.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "BLF IMPRESSION ",
            "RSOrgEng": "BLF IMPRESSION ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "146870.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "BLOOK UP ",
            "RSOrgEng": "BLOOK UP ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "BOISE FRANCE ",
            "RSOrgEng": "BOISE FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "104184.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BOIS ET CHARPENTES INDUSTRIELLES BCI",
            "RSOrgEng": "BOIS ET CHARPENTES INDUSTRIELLES BCI",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "98129.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "BOISLIM ",
            "RSOrgEng": "BOISLIM ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "80538.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX AQUITAINE INNO VIN ",
            "RSOrgEng": "BORDEAUX AQUITAINE INNO VIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "77000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX AQUITAINE INNO VIN ",
            "RSOrgEng": "BORDEAUX AQUITAINE INNO VIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX BEGLES ENERGIE ",
            "RSOrgEng": "BORDEAUX BEGLES ENERGIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "1006817.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX DEMOLITION SERVICES ",
            "RSOrgEng": "BORDEAUX DEMOLITION SERVICES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "90940.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX DEMOLITION SERVICES ",
            "RSOrgEng": "BORDEAUX DEMOLITION SERVICES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "64218.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX DEMOLITION SERVICES ",
            "RSOrgEng": "BORDEAUX DEMOLITION SERVICES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "62740.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX TECHNOWEST ",
            "RSOrgEng": "BORDEAUX TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX TECHNOWEST ",
            "RSOrgEng": "BORDEAUX TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50686.66"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX TECHNOWEST ",
            "RSOrgEng": "BORDEAUX TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "192500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX TECHNOWEST ",
            "RSOrgEng": "BORDEAUX TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "BORDEAUX TECHNOWEST ",
            "RSOrgEng": "BORDEAUX TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "405000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "BORIE INDUSTRIES ",
            "RSOrgEng": "BORIE INDUSTRIES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "147267.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "
",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "92317.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CAPRICCI FILMS ",
            "RSOrgEng": "CAPRICCI FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CAPRICCI FILMS ",
            "RSOrgEng": "CAPRICCI FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CAPRICCI FILMS ",
            "RSOrgEng": "CAPRICCI FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "14752.37"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CAPRICCI FILMS ",
            "RSOrgEng": "CAPRICCI FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CAPRICCI FILMS ",
            "RSOrgEng": "CAPRICCI FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CAPRICCI FILMS ",
            "RSOrgEng": "CAPRICCI FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "23100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CAP SCIENCES CCSTI BORDEAUX NOUVELLE-A QUITAINE",
            "RSOrgEng": "CAP SCIENCES CCSTI BORDEAUX NOUVELLE-A QUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "108716.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CAP SCIENCES CCSTI BORDEAUX NOUVELLE-A QUITAINE",
            "RSOrgEng": "CAP SCIENCES CCSTI BORDEAUX NOUVELLE-A QUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "350104.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "CAP SCIENCES CCSTI BORDEAUX NOUVELLE-A QUITAINE",
            "RSOrgEng": "CAP SCIENCES CCSTI BORDEAUX NOUVELLE-A QUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1199764.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "CAP SCIENCES CCSTI BORDEAUX NOUVELLE-A QUITAINE",
            "RSOrgEng": "CAP SCIENCES CCSTI BORDEAUX NOUVELLE-A QUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "450000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "CARALLIANCE ",
            "RSOrgEng": "CARALLIANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "200124.32"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CARALLIANCE ",
            "RSOrgEng": "CARALLIANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "49404.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CARALLIANCE ",
            "RSOrgEng": "CARALLIANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "37910.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CARBON WATERS ",
            "RSOrgEng": "CARBON WATERS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "144000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CARBON WATERS ",
            "RSOrgEng": "CARBON WATERS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "19350.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CARCIDIAG BIOTECHNOLOGIES ",
            "RSOrgEng": "CARCIDIAG BIOTECHNOLOGIES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "15402.53"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CARCIDIAG BIOTECHNOLOGIES ",
            "RSOrgEng": "CARCIDIAG BIOTECHNOLOGIES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "86500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CARELINE SOLUTIONS ",
            "RSOrgEng": "CARELINE SOLUTIONS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS EVASION ",
            "RSOrgEng": "CARS EVASION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "89206.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS EVASION ",
            "RSOrgEng": "CARS EVASION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "25427.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS ROUSSELOT ",
            "RSOrgEng": "CARS ROUSSELOT ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "66184.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS ROUSSELOT ",
            "RSOrgEng": "CARS ROUSSELOT ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "15329.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS SARRO ",
            "RSOrgEng": "CARS SARRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en nom collectif",
            "MtOrgEng": "23185.54"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS SARRO ",
            "RSOrgEng": "CARS SARRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en nom collectif",
            "MtOrgEng": "79790.26"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS SARRO ",
            "RSOrgEng": "CARS SARRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en nom collectif",
            "MtOrgEng": "21375.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS SARRO ",
            "RSOrgEng": "CARS SARRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en nom collectif",
            "MtOrgEng": "21176.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS THORIN ",
            "RSOrgEng": "CARS THORIN ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "87407.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS THORIN ",
            "RSOrgEng": "CARS THORIN ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "14221.31"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CARS THORIN ",
            "RSOrgEng": "CARS THORIN ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "59006.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CARTOL ",
            "RSOrgEng": "CARTOL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "98174.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CARTOL ",
            "RSOrgEng": "CARTOL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "187060.72"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "RSOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "NatJurOrgEng": "Organisme consulaire",
            "MtOrgEng": "32812.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "RSOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "NatJurOrgEng": "Organisme consulaire",
            "MtOrgEng": "30692.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-01-30",
            "NatEng": "Subvention",
            "NomOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "RSOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "NatJurOrgEng": "Organisme consulaire",
            "MtOrgEng": "136303.51"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "RSOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "NatJurOrgEng": "Organisme consulaire",
            "MtOrgEng": "1670515.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "RSOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "NatJurOrgEng": "Organisme consulaire",
            "MtOrgEng": "37500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "RSOrgEng": "CCI BAYONNE PAYS BASQUE ",
            "NatJurOrgEng": "Organisme consulaire",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CC LAB ",
            "RSOrgEng": "CC LAB ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "53595.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CC LAB ",
            "RSOrgEng": "CC LAB ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "25089.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CELLOZ ",
            "RSOrgEng": "CELLOZ ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "105000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "CELLULE ECONOMIQUE REGIONALE DE CONSTR UCTION NOUVELLE AQUITAINE",
            "RSOrgEng": "CELLULE ECONOMIQUE REGIONALE DE CONSTR UCTION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "57120.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CELLULE ECONOMIQUE REGIONALE DE CONSTR UCTION NOUVELLE AQUITAINE",
            "RSOrgEng": "CELLULE ECONOMIQUE REGIONALE DE CONSTR UCTION NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "51700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE AQUITAIN DES TECHNOLOGIES DE L INFORMATION ET ELECTRONIQUES - CATIE",
            "RSOrgEng": "CENTRE AQUITAIN DES TECHNOLOGIES DE L INFORMATION ET ELECTRONIQUES - CATIE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "225243.15"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE AQUITAIN DES TECHNOLOGIES DE L INFORMATION ET ELECTRONIQUES - CATIE",
            "RSOrgEng": "CENTRE AQUITAIN DES TECHNOLOGIES DE L INFORMATION ET ELECTRONIQUES - CATIE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "515952.02"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE AQUITAIN DES TECHNOLOGIES DE L INFORMATION ET ELECTRONIQUES - CATIE",
            "RSOrgEng": "CENTRE AQUITAIN DES TECHNOLOGIES DE L INFORMATION ET ELECTRONIQUES - CATIE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1224169.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE CHOREGRAPHIQUE NATIONAL DE LA ROCHELLE",
            "RSOrgEng": "CENTRE CHOREGRAPHIQUE NATIONAL DE LA ROCHELLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "89697.53"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE CHOREGRAPHIQUE NATIONAL DE LA ROCHELLE",
            "RSOrgEng": "CENTRE CHOREGRAPHIQUE NATIONAL DE LA ROCHELLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "301000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "RSOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1525.39"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "RSOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "RSOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "RSOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "RSOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "RSOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "105000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "RSOrgEng": "CENTRE D ACTION CULTURELLE LE MOULIN DU ROC - SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "
.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REG ECOENERGETIQUE AQUITAINE ",
            "RSOrgEng": "CENTRE REG ECOENERGETIQUE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "33909.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REG ECOENERGETIQUE AQUITAINE ",
            "RSOrgEng": "CENTRE REG ECOENERGETIQUE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "57600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REGIONAL DES ENERGIES RENOUVELABLES",
            "RSOrgEng": "CENTRE REGIONAL DES ENERGIES RENOUVELABLES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "44000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REGIONAL DES ENERGIES RENOUVELABLES",
            "RSOrgEng": "CENTRE REGIONAL DES ENERGIES RENOUVELABLES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "235400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REGIONAL DES ENERGIES RENOUVELABLES",
            "RSOrgEng": "CENTRE REGIONAL DES ENERGIES RENOUVELABLES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "RSOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "133500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "RSOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4794.11"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "RSOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13440.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "RSOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "252000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "RSOrgEng": "CENTRE REGIONAL D EXPERIMENTATION ET D APPLICATION AQUACOLE - CREAA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11081.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE SOCIAL LO SOLAN ",
            "RSOrgEng": "CENTRE SOCIAL LO SOLAN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE SOCIAL LO SOLAN ",
            "RSOrgEng": "CENTRE SOCIAL LO SOLAN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "81200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE SOCIAL LO SOLAN ",
            "RSOrgEng": "CENTRE SOCIAL LO SOLAN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE TECHNOLOGIQUE ALPHANOV ",
            "RSOrgEng": "CENTRE TECHNOLOGIQUE ALPHANOV ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1255112.91"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE TECHNOLOGIQUE ALPHANOV ",
            "RSOrgEng": "CENTRE TECHNOLOGIQUE ALPHANOV ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1983469.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE TECHNOLOGIQUE ALPHANOV ",
            "RSOrgEng": "CENTRE TECHNOLOGIQUE ALPHANOV ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "210000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE VALOR AGRO RESSOURCES ",
            "RSOrgEng": "CENTRE VALOR AGRO RESSOURCES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "31090.69"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CENTRE VALOR AGRO RESSOURCES ",
            "RSOrgEng": "CENTRE VALOR AGRO RESSOURCES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60484.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CERAQUITAINE SAS ",
            "RSOrgEng": "CERAQUITAINE SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "19216.68"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CERAQUITAINE SAS ",
            "RSOrgEng": "CERAQUITAINE SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "78685.5"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "CERTENERGIE ",
            "RSOrgEng": "CERTENERGIE ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CERTIS THERAPEUTICS ",
            "RSOrgEng": "CERTIS THERAPEUTICS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "128500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CESAM FORMATION ",
            "RSOrgEng": "CESAM FORMATION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "18000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CESAM FORMATION ",
            "RSOrgEng": "CESAM FORMATION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "36000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CESAM FORMATION ",
            "RSOrgEng": "CESAM FORMATION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "28800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "C E SI ",
            "RSOrgEng": "C E SI ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "98000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "RSOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "2400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "RSOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "3560.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "RSOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "62605.54"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "RSOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "1750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "RSOrgEng": "CFAI LIMOUSIN SITE DE TULLE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "33600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI POITOU-CHARENTES ",
            "RSOrgEng": "CFAI POITOU-CHARENTES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18821.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI POITOU-CHARENTES ",
            "RSOrgEng": "CFAI POITOU-CHARENTES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI POITOU-CHARENTES ",
            "RSOrgEng": "CFAI POITOU-CHARENTES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "188842.25"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI POITOU-CHARENTES ",
            "RSOrgEng": "CFAI POITOU-CHARENTES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "92500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CFAI POITOU-CHARENTES ",
            "RSOrgEng": "CFAI POITOU-CHARENTES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6853.28"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "CFTA CENTRE OUEST ",
            "RSOrgEng": "CFTA CENTRE OUEST ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "10130.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "CFTA CENTRE OUEST ",
            "RSOrgEng": "CFTA CENTRE OUEST ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "462198.74"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CFTA CENTRE OUEST ",
            "RSOrgEng": "CFTA CENTRE OUEST ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "194586.55"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "CFTI COMPAGNIE FRANCAISE TRANSPORT INT ERURBAIN",
            "RSOrgEng": "CFTI COMPAGNIE FRANCAISE TRANSPORT INT ERURBAIN",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "98930.22"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CFTI COMPAGNIE FRANCAISE TRANSPORT INT ERURBAIN",
            "RSOrgEng": "CFTI COMPAGNIE FRANCAISE TRANSPORT INT ERURBAIN",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "10904.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "CHAINTRIER ",
            "RSOrgEng": "CHAINTRIER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "157548.61"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "CHAINTRIER ",
            "RSOrgEng": "CHAINTRIER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "6427.73"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CHAINTRIER ",
            "RSOrgEng": "CHAINTRIER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "4049.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "RSOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "RSOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "108692.96"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "RSOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "RSOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "248920.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "RSOrgEng": "CHAMBRE R\u00c9GIONALE DE L ECONOMIE SOCIAL E ET SOLIDAIRE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20913.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CHANTIER NAVAL COUACH CNC ",
            "RSOrgEng": "CHANTIER NAVAL COUACH CNC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng":
",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CLAIRSIENNE ",
            "RSOrgEng": "CLAIRSIENNE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CLISSON METAL SAS ",
            "RSOrgEng": "CLISSON METAL SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "83189.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CLOTURES ET PIQUETS ",
            "RSOrgEng": "CLOTURES ET PIQUETS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "105900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CLUB AT BRIVISTE CORREZE LIMOUSIN SASP ",
            "RSOrgEng": "CLUB AT BRIVISTE CORREZE LIMOUSIN SASP ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "39000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CLUB AT BRIVISTE CORREZE LIMOUSIN SASP ",
            "RSOrgEng": "CLUB AT BRIVISTE CORREZE LIMOUSIN SASP ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "91000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "CLUSTER STPM ",
            "RSOrgEng": "CLUSTER STPM ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "236400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CMP COMPOSITES ",
            "RSOrgEng": "CMP COMPOSITES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "RSOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "3200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "RSOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "19864.05"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-12",
            "NatEng": "Subvention",
            "NomOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "RSOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "115000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "RSOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "24200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "RSOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "1250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "RSOrgEng": "CO-ACTIONS COOPERATIVE D ENTREPRENEUR. E.S SOLIDAIRES",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "2500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "COAEQUO ",
            "RSOrgEng": "COAEQUO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "COAEQUO ",
            "RSOrgEng": "COAEQUO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "40500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "COAEQUO ",
            "RSOrgEng": "COAEQUO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "COAEQUO ",
            "RSOrgEng": "COAEQUO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "169300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "COAEQUO ",
            "RSOrgEng": "COAEQUO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "COAXIS SOFTWARE ",
            "RSOrgEng": "COAXIS SOFTWARE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75863.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "COFIDUR EMS ",
            "RSOrgEng": "COFIDUR EMS ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "16730.15"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COFIDUR EMS ",
            "RSOrgEng": "COFIDUR EMS ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "64986.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "COLEEN ",
            "RSOrgEng": "COLEEN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "94060.77"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "C.O.L. PYRENEES ATLANTIQUES COMIT\u00c9 OUVRIER DU LOGEMENT",
            "RSOrgEng": "C.O.L. PYRENEES ATLANTIQUES COMIT\u00c9 OUVRIER DU LOGEMENT",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative de production de HLM anonyme \u00e0 directoire",
            "MtOrgEng": "135000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23448.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "33605.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7249.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "29400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26308.02"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "58015.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10733.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-19",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "RSOrgEng": "COMITE DE BASSIN D EMPLOI DU SEIGNANX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "RSOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "129300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "RSOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "RSOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9774.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "RSOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "158280.53"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "RSOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "308000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "RSOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "65100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "RSOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5250.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "RSOrgEng": "COMITE LIAISON ACTEURS DE LA PROMOTION DANS SUD-OUEST - CLAP SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "180008.06"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18312.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "52800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL CANO\u00cb KAYAK NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL CGT NOUVELLE AQUITAINE ",
            "RSOrgEng": "COMITE REGIONAL CGT NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Syndicat de salari\u00e9s",
            "MtOrgEng": "103684.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL CGT NOUVELLE AQUITAINE ",
            "RSOrgEng": "COMITE REGIONAL CGT NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Syndicat de salari\u00e9s",
            "MtOrgEng": "62210.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16592.56"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6844.93"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "78937.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5766.96"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL CONCHYLICULTURE ARCACHON AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "861.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL D EQUITATION DE NOUVEL LE AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL D EQUITATION DE NOUVEL LE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21340.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL D EQUITATION DE NOUVEL LE AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL D EQUITATION DE NOUVEL LE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL D EQUITATION DE NOUVEL LE AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL D EQUITATION DE NOUVEL LE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL DU TOURISME NOUVELLE-A QUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL DU TOURISME NOUVELLE-A QUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "885401.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL DU TOURISME NOUVELLE-A QUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL DU TOURISME NOUVELLE-A QUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "87357.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL DU TOURISME NOUVELLE-A QUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL DU TOURISME NOUVELLE-A QUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "120500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL DU TOURISME NOUVELLE-A QUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL DU TOURISME NOUVELLE-A QUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5049368.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27904.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1409.95"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16829.76"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15099.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "RSOrgEng": "COMIT\u00c9 R\u00c9GIONAL HANDISPORT DE LA NOUVE LLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "RSOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21375.95"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "RSOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23194.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "RSOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "RSOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "43100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "RSOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "RSOrgEng": "COMITE REGIONAL NOUVELLE-AQUITAINE DE CYCLISME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4493.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "116832.83"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "49000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "215000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL OLYMPIQUE ET SPORTIF NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6249.33"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL PECHES MARITIMES NOUVE LLE AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL PECHES MARITIMES NOUVE LLE AQUITAINE",
            "NatJurOrgEng": "Autre organisme professionnel",
            "MtOrgEng": "36144.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL PECHES MARITIMES NOUVE LLE AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL PECHES MARITIMES NOUVE LLE AQUITAINE",
            "NatJurOrgEng": "Autre organisme professionnel",
            "MtOrgEng": "1000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "COMITE REGIONAL PECHES MARITIMES NOUVE LLE AQUITAINE",
            "RSOrgEng": "COMITE REGIONAL PECHES MARITIMES NOUVE LLE AQUITAINE",
            "NatJurOrgEng": "Autre organisme professionnel",
            "MtOrgEng": "81805.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "COMPAGNIE MADRANGE ",
            "RSOrgEng": "COMPAGNIE MADRANGE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "392403.71"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "COMPAG
5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "COOP DEP AGRICOLE D ACTION SANITAIRE ",
            "RSOrgEng": "COOP DEP AGRICOLE D ACTION SANITAIRE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "154832.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COOPERATIVE LAITIERE DE LA SEVRE ",
            "RSOrgEng": "COOPERATIVE LAITIERE DE LA SEVRE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "259462.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "COOPERATIVE LAITIERE DE LA SEVRE ",
            "RSOrgEng": "COOPERATIVE LAITIERE DE LA SEVRE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "187560.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "COOP\u00c9RATIVE TIERS LIEUX ",
            "RSOrgEng": "COOP\u00c9RATIVE TIERS LIEUX ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "162362.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COOP\u00c9RATIVE TIERS LIEUX ",
            "RSOrgEng": "COOP\u00c9RATIVE TIERS LIEUX ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "472500.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "COOP\u00c9RATIVE TIERS LIEUX ",
            "RSOrgEng": "COOP\u00c9RATIVE TIERS LIEUX ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "194589.19"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "RSOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "RSOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "RSOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "RSOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61048.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "RSOrgEng": "COORDINATION POUR PROMOUVOIR COMPETENC ES ET VOLONTARIAT SUD-OUEST",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "COPPET ",
            "RSOrgEng": "COPPET ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "124761.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CORAB CENTR ATLANTIQUE ",
            "RSOrgEng": "CORAB CENTR ATLANTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "59737.69"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CORAB CENTR ATLANTIQUE ",
            "RSOrgEng": "CORAB CENTR ATLANTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "33787.46"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CORAB CENTR ATLANTIQUE ",
            "RSOrgEng": "CORAB CENTR ATLANTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "13843.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "COREN ",
            "RSOrgEng": "COREN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "135840.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "CORR\u00c8ZE ENERGIES ",
            "RSOrgEng": "CORR\u00c8ZE ENERGIES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en nom collectif",
            "MtOrgEng": "1300000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-26",
            "NatEng": "Subvention",
            "NomOrgEng": "CORRTECH TERRITOIRE NUMERIQUE ",
            "RSOrgEng": "CORRTECH TERRITOIRE NUMERIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26064.02"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CORRTECH TERRITOIRE NUMERIQUE ",
            "RSOrgEng": "CORRTECH TERRITOIRE NUMERIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "49500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "COSMETIC VALLEY ",
            "RSOrgEng": "COSMETIC VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "53291.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "COSMETIC VALLEY ",
            "RSOrgEng": "COSMETIC VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "183026.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "COSMETIC VALLEY ",
            "RSOrgEng": "COSMETIC VALLEY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24279.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CREDER ",
            "RSOrgEng": "CREDER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "90027.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "CREDIT MUTUEL LEASING ",
            "RSOrgEng": "CREDIT MUTUEL LEASING ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "3315.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CREDIT MUTUEL LEASING ",
            "RSOrgEng": "CREDIT MUTUEL LEASING ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "99334.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "CREDIT MUTUEL LEASING ",
            "RSOrgEng": "CREDIT MUTUEL LEASING ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "149001.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CREUZET AERONAUTIQUE ",
            "RSOrgEng": "CREUZET AERONAUTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "208686.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-10-22",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "173215.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "336000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "RSOrgEng": "CRIJ- CENTRE REGIONAL INFORMATION JEUN ESSE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL GROUPE ",
            "RSOrgEng": "CRISTAL GROUPE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "9900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL GROUPE ",
            "RSOrgEng": "CRISTAL GROUPE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL GROUPE ",
            "RSOrgEng": "CRISTAL GROUPE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL GROUPE ",
            "RSOrgEng": "CRISTAL GROUPE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "19000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL GROUPE ",
            "RSOrgEng": "CRISTAL GROUPE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "15250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL PRODUCTION ",
            "RSOrgEng": "CRISTAL PRODUCTION ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL PRODUCTION ",
            "RSOrgEng": "CRISTAL PRODUCTION ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL PRODUCTION ",
            "RSOrgEng": "CRISTAL PRODUCTION ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "24500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CRISTAL PRODUCTION ",
            "RSOrgEng": "CRISTAL PRODUCTION ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CRITT AGRO ALIMENTAIRE ",
            "RSOrgEng": "CRITT AGRO ALIMENTAIRE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "119743.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "CRITT AGRO ALIMENTAIRE ",
            "RSOrgEng": "CRITT AGRO ALIMENTAIRE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "184223.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CRITT AGRO ALIMENTAIRE ",
            "RSOrgEng": "CRITT AGRO ALIMENTAIRE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "142500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "CRITT INFORMATIQUE ",
            "RSOrgEng": "CRITT INFORMATIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "206588.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CRITT INFORMATIQUE ",
            "RSOrgEng": "CRITT INFORMATIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "193926.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CRITT SPORTS LOISIRS ",
            "RSOrgEng": "CRITT SPORTS LOISIRS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "181160.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CRITT SPORTS LOISIRS ",
            "RSOrgEng": "CRITT SPORTS LOISIRS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "483379.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "RSOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "406536.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "RSOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "67761.28"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "RSOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "1890000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "RSOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "57000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "RSOrgEng": "CROIX ROUGE FCAISE IRF SANIT SOCIALE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "32994.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX ROUGE FRANCAISE INSTITUT DE FORMATION SOINS INFIRMIERS",
            "RSOrgEng": "CROIX ROUGE FRANCAISE INSTITUT DE FORMATION SOINS INFIRMIERS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "597266.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX ROUGE FRANCAISE INSTITUT DE FORMATION SOINS INFIRMIERS",
            "RSOrgEng": "CROIX ROUGE FRANCAISE INSTITUT DE FORMATION SOINS INFIRMIERS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "1776000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX ROUGE FRANCAISE INSTITUT DE FORMATION SOINS INFIRMIERS",
            "RSOrgEng": "CROIX ROUGE FRANCAISE INSTITUT DE FORMATION SOINS INFIRMIERS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "7356.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX-ROUGE FRAN\u00c7AISE IRFSS AQUITAINE ",
            "RSOrgEng": "CROIX-ROUGE FRAN\u00c7AISE IRFSS AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "452845.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CROIX-ROUGE FRAN\u00c7AISE IRFSS AQUITAINE ",
            "RSOrgEng": "CROIX-ROUGE FRAN\u00c7AISE IRFSS AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "1250000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CTM ",
            "RSOrgEng": "CTM ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CTRE ING EN TRAIT RVT SURFACE AVANCES ",
            "RSOrgEng": "CTRE ING EN TRAIT RVT SURFACE AVANCES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "201693.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CTRE ING EN TRAIT RVT SURFACE AVANCES ",
            "RSOrgEng": "CTRE ING EN TRAIT RVT SURFACE AVANCES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "420000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "CTRE ING EN TRAIT RVT SURFACE AVANCES ",
            "RSOrgEng": "CTRE ING EN TRAIT RVT SURFACE AVANCES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "12800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CTRE RESSOURCES DES GROUPEMENTS D EMPLOYEURS CRGE",
            "RSOrgEng": "CTRE RESSOURCES DES GROUPEMENTS D EMPLOYEURS CRGE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "59400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "CTRE RESSOURCES DES GROUPEMENTS D EMPLOYEURS CRGE",
            "RSOrgEng": "CTRE RESSOURCES DES GROUPEMENTS D EMPLOYEURS CRGE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "138600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "CTRE TRANSFERT TECHNO CERAMIQUES ",
            "RSOrgEng": "CTRE TRANSFERT TECHNO CERAMIQUES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "270542.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "CTRE TRANSFERT TECHNO CERAMIQUES ",
            "RSOrgEng": "CTRE TRANSFERT TECHNO CERAMIQUES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "404600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "CUVELIER POLYMECA INDUSTRIE ",
            "RSOrgEng": "CUVELIER POLYMECA INDUSTRIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "CYBER GROUP STUDIOS ",
            "RSOrgEng": "CYBER GROUP STUDIOS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "CYBER GROUP STUDIOS ",
            "RSOrgEng": "CYBER GROUP STUDIOS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "65000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "DAMNED FILMS PRODUCTION ET DISTRIBUTIO N",
            "RSOrgEng": "DAMNED FILMS PRODUCTION ET DISTRIBUTIO N",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "105000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "DAMNED FILMS PRODUCTION ET DISTRIBUTIO N",
            "RSOrgEng": "DAMNED FILMS PRODUCTION ET DISTRIBUTIO N",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "DASYL PR\u00c9VOT ",
            "RSOrgEng": "DASYL PR\u00c9VOT ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "114892.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "DEBITEX ",
            "RSOrgEng": "DEBITEX ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "129583.73"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "DECATHLON ",
            "RSOrgEng": "DECATHLON ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "302041.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "DE COURTEBOTTE SCEA M. GERGERES JEAN-ROBERT",
            "RSOrgEng": "DE COURTEBOTTE SCEA M. GERGERES JEAN-ROBERT",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 civile d'exploitation agricole",
            "MtOrgEng": "235050.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "DE LA TRANSITION ECOLOGIQUE EN AGRICUL TURE",
            "RSOrgEng": "DE LA TRANSITION ECOLOGIQUE EN AGRICUL TURE",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat \u00e9conomique (GIE)",
            "MtOrgEng": "263040.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "DE LA VALONIE EARL PALU J-CL ",
            "RSOrgEng": "DE LA VALONIE EARL PALU J-CL ",
            "NatJurOrgEng": "Exploitation agricole \u00e0 responsabilit\u00e9 limit\u00e9e",
            "MtOrgEng": "156461.81"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "DE SANGOSSE ",
            "RSOrgEng": "DE SANGOSSE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "77287.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "RSOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24507.24"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "RSOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "RSOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "RSOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "33600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "RSOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30880.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "RSOrgEng": "DES LENDEMAINS QUI CHANTENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "29305.92"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "DEUX SEVRES NATURE ENVIRONNEMENT ",
            "RSOrgEng": "DEUX SEVRES NATURE ENVIRONNEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3169.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "DEUX SEVRES NATURE ENVIRONNEMENT ",
            "RSOrgEng": "DEUX SEVRES NATURE ENVIRONNEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "49677.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "DEUX SEVRES NATURE ENVIRONNEMENT ",
            "RSOrgEng": "DEUX SEVRES NATURE ENVIRONNEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4595.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "DEUX SEVRES NATURE ENVIRONNEMENT ",
            "RSOrgEng": "DEUX SEVRES NATURE ENVIRONNEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "72766.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "DEVELOP CULTUREL DU ROUILLACAIS LA PALENE",
            "RSOrgEng": "DEVELOP CULTUREL DU ROUILLACAIS LA PALENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "DEVELOP CULTUREL DU ROUILLACAIS LA PALENE",
            "RSOrgEng": "DEVELOP CULTUREL DU ROUILLACAIS LA PALENE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "DIADES MARINE SAS ",
            "RSOrgEng": "DIADES MARINE SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "103124.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "DIAPASOM ",
            "RSOrgEng": "DIAPASOM ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "41172.08"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "DIAPASOM ",
            "RSOrgEng": "DIAPASOM ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13799.04"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "DIAPASOM ",
            "RSOrgEng": "DIAPASOM ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "DIAPASOM ",
            "RSOrgEng": "DIAPASOM ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18546.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "DIAPASOM ",
            "RSOrgEng": "DIAPASOM ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61789.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "DIGITAL AQUITAINE ",
            "RSOrgEng": "DIGITAL AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "29750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "DIGITAL AQUITAINE ",
            "RSOrgEng": "DIGITAL AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "156000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "DIGITAL AQUITAINE ",
            "RSOrgEng": "DIGITAL AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "DIGITAL AQUITAINE ",
            "RSOrgEng": "DIGITAL AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "234000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "DILANGE MENUISERIES INDUSTRIELLES PVC - DMI PVC",
            "RSOrgEng": "DILANGE MENUISERIES INDUSTRIELLES PVC - DMI PVC",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "102020.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "DIOTASOFT ",
            "RSOrgEng": "DIOTASOFT ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "82038.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "DISTILLERIE DE LA TOUR ",
            "RSOrgEng": "DISTILLERIE DE LA TOUR ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "114000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "DISTILLERIE MICHEL BOINAUD ",
            "RSOrgEng": "DISTILLERIE MICHEL BOINAUD ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "237080.84"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "DOMALYS ",
            "RSOrgEng": "DOMALYS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "96036.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "DOMALYS ",
            "RSOrgEng": "DOMALYS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-11-24",
            "NatEng": "Subvention",
            "NomOrgEng": "DOMOFRANCE ",
            "RSOrgEng": "DOMOFRANCE ",
            "NatJurOrgEng": "SA coop\u00e9rative de production de HLM \u00e0 conseil d'administration",
            "MtOrgEng": "436994.77"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-04-25",
            "NatEng": "Subvention",
            "NomOrgEng": "DOMOFRANCE ",
            "RSOrgEng": "DOMOFRANCE ",
            "NatJurOrgEng": "SA coop\u00e9rative de production de HLM \u00e0 conseil d'administration",
            "MtOrgEng": "35945.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "DOMOFRANCE ",
            "RSOrgEng": "DOMOFRANCE ",
            "NatJurOrgEng": "SA coop\u00e9rative de production de HLM \u00e0 conseil d'administration",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "DOMOFRANCE ",
            "RSOrgEng": "DOMOFRANCE ",
            "NatJurOrgEng": "SA coop\u00e9rative de production de HLM \u00e0 conseil d'administration",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "DONE HUI ",
            "RSOrgEng": "DONE HUI ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "DOUMEN SAS ",
            "RSOrgEng": "DOUMEN SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "50251.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "DOUMEN SAS ",
            "RSOrgEng": "DOUMEN SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "39440.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "DOUMEN SAS ",
            "RSOrgEng": "DOUMEN SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "14320.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "DREAMTRONIC ",
            "RSOrgEng": "DREAMTRONIC ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "DREAMTRONIC ",
            "RSOrgEng": "DREAMTRONIC ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "183103.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "DRONISOS ",
            "RSOrgEng": "DRONISOS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "35511.91"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "DRONISOS ",
            "RSOrgEng": "DRONISOS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "DSI LASER CHATELLERAULT ",
            "RSOrgEng": "DSI LASER CHATELLERAULT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "23523.87"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "DSI LASER CHATELLERAULT ",
            "RSOrgEng": "DSI LASER CHATELLERAULT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "115329.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "DUBLIN FILMS ",
            "RSOrgEng": "DUBLIN FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "9900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "DUBLIN FILMS ",
            "RSOrgEng": "DUBLIN FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "11100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "DUBLIN FILMS ",
            "RSOrgEng": "DUBLIN FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "38000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "DUBLIN FILMS ",
            "RSOrgEng": "DUBLIN FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "11250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "DUBLIN FILMS ",
            "RSOrgEng": "DUBLIN FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "12600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "DUPRAT FRERES UNION CAVES FRAN IB QUES ",
            "RSOrgEng": "DUPRAT FRERES UNION CAVES FRAN IB QUES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "42600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "DUPRAT FRERES UNION CAVES FRAN IB QUES ",
            "RSOrgEng": "DUPRAT FRERES UNION CAVES FRAN IB QUES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "40128.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "DUSSAU DISTRIBUTION ",
            "RSOrgEng": "DUSSAU DISTRIBUTION ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "150072.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "DYNVIBE ",
            "RSOrgEng": "DYNVIBE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "91000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "EARL DE LOIVIVE ",
            "RSOrgEng": "EARL DE LOIVIVE ",
            "NatJurOrgEng": "Exploitation agricole \u00e0 responsabilit\u00e9 limit\u00e9e",
            "MtOrgEng": "376518.06"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "EARL DU BOIS NOIR ",
            "RSOrgEng": "EARL DU BOIS NOIR ",
            "NatJurOrgEng": "Exploitation agricole \u00e0 responsabilit\u00e9 limit\u00e9e",
            "MtOrgEng": "268941.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "EARL LES PIQUERELLES ",
            "RSOrgEng": "EARL LES PIQUERELLES ",
            "NatJurOrgEng": "Exploitation agricole \u00e0 responsabilit\u00e9 limit\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "EARL LORENZ ",
            "RSOrgEng": "EARL LORENZ ",
            "NatJurOrgEng": "Exploitation agricole \u00e0 responsabilit\u00e9 limit\u00e9e",
            "MtOrgEng": "376518.06"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "EARL VAL DE SAYE ",
            "RSOrgEng": "EARL VAL DE SAYE ",
            "NatJurOrgEng": "Exploitation agricole \u00e0 responsabilit\u00e9 limit\u00e9e",
            "MtOrgEng": "268941.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "EASYLI ",
            "RSOrgEng": "EASYLI ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "132424.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "EASYLI ",
            "RSOrgEng": "EASYLI ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ECCE FILMS ",
            "RSOrgEng": "ECCE FILMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ECHANGES PAYS BASQUE ",
            "RSOrgEng": "ECHANGES PAYS BASQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ECHEVERRIA ",
            "RSOrgEng": "ECHEVERRIA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "213318.89"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE CIRQUE DE BORDEAUX ",
            "RSOrgEng": "ECOLE DE CIRQUE DE BORDEAUX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14620.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE CIRQUE DE BORDEAUX ",
            "RSOrgEng": "ECOLE DE CIRQUE DE BORDEAUX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15829.88"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE CIRQUE DE BORDEAUX ",
            "RSOrgEng": "ECOLE DE CIRQUE DE BORDEAUX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14620.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE CIRQUE DE BORDEAUX ",
            "RSOrgEng": "ECOLE DE CIRQUE DE BORDEAUX ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "34114.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "RSOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9677.66"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "RSOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "298000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "RSOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "RSOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "339200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "RSOrgEng": "ECOLE DE LA 2EME CHANCE DE LA CHARENTE ET DU POITOU",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12584.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE D\u00c9PARTEMENTALE DE LA DEUXI\u00c8ME CH ANCE DES PYR\u00c9N\u00c9ES ATLANTIQUES",
            "RSOrgEng": "ECOLE D\u00c9PARTEMENTALE DE LA DEUXI\u00c8ME CH ANCE DES PYR\u00c9N\u00c9ES ATLANTIQUES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "108000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE NATIONALE DE CIRQUE CHATELLERAULT",
            "RSOrgEng": "ECOLE NATIONALE DE CIRQUE CHATELLERAULT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "43225.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE NATIONALE DE CIRQUE CHATELLERAULT",
            "RSOrgEng": "ECOLE NATIONALE DE CIRQUE CHATELLERAULT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "133000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLES D'AMBULANCIERS DES O.H.F.O.M.",
            "RSOrgEng": "ECOLES D'AMBULANCIERS DES O.H.F.O.M.",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "40445.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLES D'AMBULANCIERS DES O.H.F.O.M.",
            "RSOrgEng": "ECOLES D'AMBULANCIERS DES O.H.F.O.M.",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "158000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "RSOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "35050.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "RSOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "17973.64"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "RSOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "239000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "RSOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "49000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "RSOrgEng": "ECOLE SUPERIEURE DES TECHNOLOGIES INDU STRIELLES AVANCEES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "239000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-30",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU STRIELLES AVANC\u00c9ES - ESTIA",
            "RSOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU STRIELLES AVANC\u00c9ES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "510032.77"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU STRIELLES AVANC\u00c9ES - ESTIA",
            "RSOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU STRIELLES AVANC\u00c9ES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "381500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "RSOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "83000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "RSOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "26272.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "RSOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "RSOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "558000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "RSOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "54048.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "RSOrgEng": "ECOLE SUP\u00c9RIEURE DES TECHNOLOGIES INDU TRIELLES AVANC\u00c9ES - ESTIA",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "1097399.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "EDUMEDIA ",
            "RSOrgEng": "EDUMEDIA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "94500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ELAN BEARNAIS PAU LACQ ORTHEZ EBPLO",
            "RSOrgEng": "ELAN BEARNAIS PAU LACQ ORTHEZ EBPLO",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "65000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ELAN BEARNAIS PAU LACQ ORTHEZ EBPLO",
            "RSOrgEng": "ELAN BEARNAIS PAU LACQ ORTHEZ EBPLO",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "45000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ELAN BEARNAIS PAU LACQ ORTHEZ EBPLO",
            "RSOrgEng": "ELAN BEARNAIS PAU LACQ ORTHEZ EBPLO",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "105000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ELC ",
            "RSOrgEng": "ELC ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "180983.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "ELECTRA ",
            "RSOrgEng": "ELECTRA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "23568.78"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ELECTRA ",
            "RSOrgEng": "ELECTRA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "71952.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ELICIT PLANT ",
            "RSOrgEng": "ELICIT PLANT ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "146000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ELLYX ",
            "RSOrgEng": "ELLYX ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "ELRINGKLINGER MEILLOR SAS ",
            "RSOrgEng": "ELRINGKLINGER MEILLOR SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "84943.63"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "EMPREINT DIGITALE ",
            "RSOrgEng": "EMPREINT DIGITALE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "EMSPROTO ",
            "RSOrgEng": "EMSPROTO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "175000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "EMSPROTO ",
            "RSOrgEng": "EMSPROTO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ENDESA ENERGIA ",
            "RSOrgEng": "ENDESA ENERGIA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 commerciale \u00e9trang\u00e8re immatricul\u00e9e au RCS",
            "MtOrgEng": "292640.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ENEAL SA D HABITATION LOYER MODERE - FONCIERE MEDICO SOCIALE",
            "RSOrgEng": "ENEAL SA D HABITATION LOYER MODERE - FONCIERE MEDICO SOCIALE",
            "NatJurOrgEng": "SA de HLM \u00e0 conseil d'administration",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-10-22",
            "NatEng": "Subvention",
            "NomOrgEng": "ENERGIES POUR DEMAIN ",
            "RSOrgEng": "ENERGIES POUR DEMAIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7895.35"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ENERGIES POUR DEMAIN ",
            "RSOrgEng": "ENERGIES POUR DEMAIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1441.64"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ENERGIES POUR DEMAIN ",
            "RSOrgEng": "ENERGIES POUR DEMAIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5351.27"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "ENERGIES POUR DEMAIN ",
            "RSOrgEng": "ENERGIES POUR DEMAIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "51545.36"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ENERGIES POUR DEMAIN ",
            "RSOrgEng": "ENERGIES POUR DEMAIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7261.6"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ENERGIES POUR DEMAIN ",
            "RSOrgEng": "ENERGIES POUR DEMAIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2937.08"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ENTREPRISE DANEY ",
            "RSOrgEng": "ENTREPRISE DANEY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "160000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ENVIRONNEMENT ET DEVELOPPEME NT DURABLE EN BEARN- EDDB",
            "RSOrgEng": "ENVIRONNEMENT ET DEVELOPPEME NT DURABLE EN BEARN- EDDB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "80700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ENVIRONNEMENT ET DEVELOPPEME NT DURABLE EN BEARN- EDDB",
            "RSOrgEng": "ENVIRONNEMENT ET DEVELOPPEME NT DURABLE EN BEARN- EDDB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "40350.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "EPLEFPA BORDEAUX GIRONDE - CFAA ",
            "RSOrgEng": "EPLEFPA BORDEAUX GIRONDE - CFAA ",
            "NatJurOrgEng": "\u00c9tablissement public local d'enseignement",
            "MtOrgEng": "135600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "EPLEFPA DE LIMOGES ET DU NORD HAUTE-VI ENNE",
            "RSOrgEng": "EPLEFPA DE LIMOGES ET DU NORD HAUTE-VI ENNE",
            "NatJurOrgEng": "\u00c9tablissement public local d'enseignement",
            "MtOrgEng": "62377.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "EPLEFPA DE LIMOGES ET DU NORD HAUTE-VI ENNE",
            "RSOrgEng": "EPLEFPA DE LIMOGES ET DU NORD HAUTE-VI ENNE",
            "NatJurOrgEng": "\u00c9tablissement public local d'enseignement",
            "MtOrgEng": "24192.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "EPLEFPA DE LIMOGES ET DU NORD HAUTE-VI ENNE",
            "RSOrgEng": "EPLEFPA DE LIMOGES ET DU NORD HAUTE-VI ENNE",
            "NatJurOrgEng": "\u00c9tablissement public local d'enseignement",
            "MtOrgEng": "1000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "EPLEFPA DU PERIGORD LYCEE AGRI DEP COULOUNIEIX CDFAA",
            "RSOrgEng": "EPLEFPA DU PERIGORD LYCEE AGRI DEP COULOUNIEIX CDFAA",
            "NatJurOrgEng": "\u00c9tablissement public local d'enseignement",
            "MtOrgEng": "104100.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "EPLEFPA DU PERIGORD LYCEE AGRI DEP COULOUNIEIX CDFAA",
            "RSOrgEng": "EPLEFPA DU PERIGORD LYCEE AGRI DEP COULOUNIEIX CDFAA",
            "NatJurOrgEng": "\u00c9tablissement public local d'enseignement",
            "MtOrgEng": "59602.21"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "EPSILON COMPOSITE ",
            "RSOrgEng": "EPSILON COMPOSITE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "159000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "EPSILON COMPOSITE ",
            "RSOrgEng": "EPSILON COMPOSITE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "19698.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "EPSILON COMPOSITE ",
            "RSOrgEng": "EPSILON COMPOSITE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "8613.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "EPTA FRANCE SAS ",
            "RSOrgEng": "EPTA FRANCE SAS ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "146704.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "EQUIPE VIENNE FUTUROSCOPE ",
            "RSOrgEng": "EQUIPE VIENNE FUTUROSCOPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "EQUIPE VIENNE FUTUROSCOPE ",
            "RSOrgEng": "EQUIPE VIENNE FUTUROSCOPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "EQUIPE VIENNE FUTUROSCOPE ",
            "RSOrgEng": "EQUIPE VIENNE FUTUROSCOPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "48529.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ERIOSYS ",
            "RSOrgEng": "ERIOSYS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ERMA ELECTRONIQUE ",
            "RSOrgEng": "ERMA ELECTRONIQUE ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "114860.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ERTECH INDUSTRIE ",
            "RSOrgEng": "ERTECH INDUSTRIE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "171181.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ERVENT AQUITAINE ",
            "RSOrgEng": "ERVENT AQUITAINE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "133400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ESHARD ",
            "RSOrgEng": "ESHARD ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "86000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ESHARD ",
            "RSOrgEng": "ESHARD ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ESI GROUP ",
            "RSOrgEng": "ESI GROUP ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "275262.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ESPACE GESTION CHARENTE MARITIME ",
            "RSOrgEng": "ESPACE GESTION CHARENTE MARITIME ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "85294.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ESPACE PIERRE MENDES FRANCE MAISON SCIENCES TECHNIQUES POITOU-CHAR",
            "RSOrgEng": "ESPACE PIERRE MENDES FRANCE MAISON SCIENCES TECHNIQUES POITOU-CHAR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ESPACE PIERRE MENDES FRANCE MAISON SCIENCES TECHNIQUES POITOU-CHAR",
            "RSOrgEng": "ESPACE PIERRE MENDES FRANCE MAISON SCIENCES TECHNIQUES POITOU-CHAR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "147400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ESPACE PIERRE MENDES FRANCE MAISON SCIENCES TECHNIQUES POITOU-CHAR",
            "RSOrgEng": "ESPACE PIERRE MENDES FRANCE MAISON SCIENCES TECHNIQUES POITOU-CHAR",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "606900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "ESPACES PLURIELS SCENE CON VENTIONNEE DANSE THEATRE",
            "RSOrgEng": "ESPACES PLURIELS SCENE CON VENTIONNEE DANSE THEATRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ESPACES PLURIELS SCENE CON VENTIONNEE DANSE THEATRE",
            "RSOrgEng": "ESPACES PLURIELS SCENE CON VENTIONNEE DANSE THEATRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "67000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ESPACES PLURIELS SCENE CON VENTIONNEE DANSE THEATRE",
            "RSOrgEng": "ESPACES PLURIELS SCENE CON VENTIONNEE DANSE THEATRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "46900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ESTBA - ECOLE SUP\u00c9RIEURE DE TH\u00c9\u00c2TRE BORDEAUX AQUITAINE",
            "RSOrgEng": "ESTBA - ECOLE SUP\u00c9RIEURE DE TH\u00c9\u00c2TRE BORDEAUX AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "32000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ESTBA - ECOLE SUP\u00c9RIEURE DE TH\u00c9\u00c2TRE BORDEAUX AQUITAINE",
            "RSOrgEng": "ESTBA - ECOLE SUP\u00c9RIEURE DE TH\u00c9\u00c2TRE BORDEAUX AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "63656.18"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ESTBA - ECOLE SUP\u00c9RIEURE DE TH\u00c9\u00c2TRE BORDEAUX AQUITAINE",
            "RSOrgEng": "ESTBA - ECOLE SUP\u00c9RIEURE DE TH\u00c9\u00c2TRE BORDEAUX AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "150500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENT BARRE ",
            "RSOrgEng": "ETABLISSEMENT BARRE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "30800.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENT BARRE ",
            "RSOrgEng": "ETABLISSEMENT BARRE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "57463.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENT DUVERNEUIL GUY ",
            "RSOrgEng": "ETABLISSEMENT DUVERNEUIL GUY ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "69288.16"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENT DUVERNEUIL GUY ",
            "RSOrgEng": "ETABLISSEMENT DUVERNEUIL GUY ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "26677.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS CATHERINEAU ",
            "RSOrgEng": "ETABLISSEMENTS CATHERINEAU ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "210000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS CATHERINEAU ",
            "RSOrgEng": "ETABLISSEMENTS CATHERINEAU ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "1498.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS CATHERINEAU ",
            "RSOrgEng": "ETABLISSEMENTS CATHERINEAU ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "13828.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS GARANDEAU FRERES ",
            "RSOrgEng": "ETABLISSEMENTS GARANDEAU FRERES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "25205.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS GARANDEAU FRERES ",
            "RSOrgEng": "ETABLISSEMENTS GARANDEAU FRERES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS LOUBAT FRERES SA ",
            "RSOrgEng": "ETABLISSEMENTS LOUBAT FRERES SA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "91291.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS MARTIN ",
            "RSOrgEng": "ETABLISSEMENTS MARTIN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "49655.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS MARTIN ",
            "RSOrgEng": "ETABLISSEMENTS MARTIN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "23259.63"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS MARTIN ",
            "RSOrgEng": "ETABLISSEMENTS MARTIN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "2904.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS MICHEL DUPUY ",
            "RSOrgEng": "ETABLISSEMENTS MICHEL DUPUY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "371105.59"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENTS ORAZIO ",
            "RSOrgEng": "ETABLISSEMENTS ORAZIO ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "127575.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENT THERMAL EVAUX LES BAINS ",
            "RSOrgEng": "ETABLISSEMENT THERMAL EVAUX LES BAINS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "400000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ETABLISSEMENT THERMAL EVAUX LES BAINS ",
            "RSOrgEng": "ETABLISSEMENT THERMAL EVAUX LES BAINS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "18500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ETS GABRIEL BEYRIA SARL ",
            "RSOrgEng": "ETS GABRIEL BEYRIA SARL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ETS GUINGUET ",
            "RSOrgEng": "ETS GUINGUET ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "309020.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ETS JEAN CLAUDE IDIART ",
            "RSOrgEng": "ETS JEAN CLAUDE IDIART ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "6195.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ETS JEAN CLAUDE IDIART ",
            "RSOrgEng": "ETS JEAN CLAUDE IDIART ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ETS JEAN CLAUDE IDIART ",
            "RSOrgEng": "ETS JEAN CLAUDE IDIART ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "EUCLIDE 87 ",
            "RSOrgEng": "EUCLIDE 87 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "EURO PLV ",
            "RSOrgEng": "EURO PLV ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "96280.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "EUROP VOYAGES 23 ",
            "RSOrgEng": "EUROP VOYAGES 23 ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "413912.73"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "EUROP VOYAGES 23 ",
            "RSOrgEng": "EUROP VOYAGES 23 ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "9778.07"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "EUROP VOYAGES 23 ",
            "RSOrgEng": "EUROP VOYAGES 23 ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "104595.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "EUROSIMA ",
            "RSOrgEng": "EUROSIMA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "EUROSIMA ",
            "RSOrgEng": "EUROSIMA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "EUROTECH ",
            "RSOrgEng": "EUROTECH ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "112328.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "RSOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "RSOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "RSOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13980.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "RSOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "83886.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-26",
            "NatEng": "Subvention",
            "NomOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "RSOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24975.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "RSOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9812.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "RSOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "39069.27"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "RSOrgEng": "EUSKAL HERRIKO LABORANTZA GANBARA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5625.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "EVERGLASS ",
            "RSOrgEng": "EVERGLASS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "133000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "EXOES ",
            "RSOrgEng": "EXOES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "100547.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "EXTENDE ",
            "RSOrgEng": "EXTENDE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "109298.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "EYREIN INDUSTRIE ",
            "RSOrgEng": "EYREIN INDUSTRIE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "F-451 ",
            "RSOrgEng": "F-451 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "77500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "FABACIER ",
            "RSOrgEng": "FABACIER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "196000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "F.ASS.T ",
            "RSOrgEng": "F.ASS.T ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "FAURE CORREZE AUTOCARS ",
            "RSOrgEng": "FAURE CORREZE AUTOCARS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "106675.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "FAURE CORREZE AUTOCARS ",
            "RSOrgEng": "FAURE CORREZE AUTOCARS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "34745.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "FBM DISTILLERIE ",
            "RSOrgEng": "FBM DISTILLERIE ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "143365.49"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "FC2 AILES ",
            "RSOrgEng": "FC2 AILES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "FCBA ",
            "RSOrgEng": "FCBA ",
            "NatJurOrgEng": "Centre technique industriel ou comit\u00e9 professionnel du d\u00e9veloppement \u00e9conomique",
            "MtOrgEng": "243000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "FED COMPAGN METIERS BATIMENT ",
            "RSOrgEng": "FED COMPAGN METIERS BATIMENT ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "FED COMPAGN METIERS BATIMENT ",
            "RSOrgEng": "FED COMPAGN METIERS BATIMENT ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "22820.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "FED COMPAGN METIERS BATIMENT ",
            "RSOrgEng": "FED COMPAGN METIERS BATIMENT ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "28111.77"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "FED COMPAGN METIERS BATIMENT ",
            "RSOrgEng": "FED COMPAGN METIERS BATIMENT ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "31903.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDD FABRICATION ELECTRONIQUE DE DORDOGNE",
            "RSOrgEng": "FEDD FABRICATION ELECTRONIQUE DE DORDOGNE",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "107454.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-11",
            "NatEng": "Subvention",
            "NomOrgEng": "F\u00c9D\u00c9RATION DE LA GIRONDE POUR LA P\u00caCHE ET LA PROTECTION DU MILIEU AQUATIQUE",
            "RSOrgEng": "F\u00c9D\u00c9RATION DE LA GIRONDE POUR LA P\u00caCHE ET LA PROTECTION DU MILIEU AQUATIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "222249.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "F\u00c9D\u00c9RATION DE LA GIRONDE POUR LA P\u00caCHE ET LA PROTECTION DU MILIEU AQUATIQUE",
            "RSOrgEng": "F\u00c9D\u00c9RATION DE LA GIRONDE POUR LA P\u00caCHE ET LA PROTECTION DU MILIEU AQUATIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "96102.87"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-12-17",
            "NatEng": "Subvention",
            "NomOrgEng": "F\u00c9D\u00c9RATION DE LA GIRONDE POUR LA P\u00caCHE ET LA PROTECTION DU MILIEU AQUATIQUE",
            "RSOrgEng": "F\u00c9D\u00c9RATION DE LA GIRONDE POUR LA P\u00caCHE ET LA PROTECTION DU MILIEU AQUATIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "131210.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-19",
            "NatEng": "Subvention",
            "NomOrgEng": "F\u00c9D\u00c9RATION DE LA GIRONDE POUR LA P\u00caCHE ET LA PROTECTION DU MILIEU AQUATIQUE",
            "RSOrgEng": "F\u00c9D\u00c9RATION DE LA GIRONDE POUR LA P\u00caCHE ET LA PROTECTION DU MILIEU AQUATIQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "55229.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEUR S DE LA GIRONDE",
            "RSOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEUR S DE LA GIRONDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "85220.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEUR S DE LA GIRONDE",
            "RSOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEUR S DE LA GIRONDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12613.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEUR S DE LA GIRONDE",
            "RSOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEUR S DE LA GIRONDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "128040.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEUR S DE LA GIRONDE",
            "RSOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEUR S DE LA GIRONDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3849.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEURS DES LANDES",
            "RSOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEURS DES LANDES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21871.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEURS DES LANDES",
            "RSOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEURS DES LANDES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "55397.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEURS DES LANDES",
            "RSOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEURS DES LANDES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23456.36"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEURS DES LANDES",
            "RSOrgEng": "FEDERATION DEPARTEMENTALE DES CHASSEURS DES LANDES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21502.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE DES CHASSEURS DE LA NOUVELLE-AQUITAINE",
            "RSOrgEng": "FEDERATION REGIONALE DES CHASSEURS DE LA NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3759.79"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE DES CHASSEURS DE LA NOUVELLE-AQUITAINE",
            "RSOrgEng": "FEDERATION REGIONALE DES CHASSEURS DE LA NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "127014.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE DES CUMA DE NOUVELLE-AQUITAINE",
            "RSOrgEng": "FEDERATION REGIONALE DES CUMA DE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "37707.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE DES CUMA DE NOUVELLE-AQUITAINE",
            "RSOrgEng": "FEDERATION REGIONALE DES CUMA DE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "430000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE DES CUMA DE NOUVELLE-AQUITAINE",
            "RSOrgEng": "FEDERATION REGIONALE DES CUMA DE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "31190.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE DES CUMA DE NOUVELLE-AQUITAINE",
            "RSOrgEng": "FEDERATION REGIONALE DES CUMA DE NOUVELLE-AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "287000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE DES SYNDICATS D E XPLOITANTS AGRICOLES FAMILIAUX MODEF N",
            "RSOrgEng": "FEDERATION REGIONALE DES SYNDICATS D E XPLOITANTS AGRICOLES FAMILIAUX MODEF N",
            "NatJurOrgEng": "Autre organisme professionnel",
            "MtOrgEng": "48549.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE DES SYNDICATS D E XPLOITANTS AGRICOLES FAMILIAUX MODEF N",
            "RSOrgEng": "FEDERATION REGIONALE DES SYNDICATS D E XPLOITANTS AGRICOLES FAMILIAUX MODEF N",
            "NatJurOrgEng": "Autre organisme professionnel",
            "MtOrgEng": "38839.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "RSOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "RSOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "53000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "RSOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "RSOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "RSOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "RSOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "RSOrgEng": "FEDERATION REGIONALE N.A DU MOUVEM ENT FRANCAIS POUR LE PLANNING FAMILIAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "81200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION TERRE DE LIENS NOUVELLE-AQU ITAINE",
            "RSOrgEng": "FEDERATION TERRE DE LIENS NOUVELLE-AQU ITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "38750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION TERRE DE LIENS NOUVELLE-AQU ITAINE",
            "RSOrgEng": "FEDERATION TERRE DE LIENS NOUVELLE-AQU ITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDERATION TERRE DE LIENS NOUVELLE-AQU ITAINE",
            "RSOrgEng": "FEDERATION TERRE DE LIENS NOUVELLE-AQU ITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "72450.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "RSOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6700.12"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "RSOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10888.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "RSOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14135.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "RSOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "RSOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61456.27"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "RSOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "400000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "RSOrgEng": "FEDE REG MAISONS FAMILIALES RURALES D EDUCATION ET D ORIENTATION N-A",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "41970.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "FERME LA CAMPELIERE ",
            "RSOrgEng": "FERME LA CAMPELIERE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "5640.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "FERME LA CAMPELIERE ",
            "RSOrgEng": "FERME LA CAMPELIERE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "68806.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "FERME LA CAMPELIERE ",
            "RSOrgEng": "FERME LA CAMPELIERE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "17500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "FERROCAMPUS ",
            "RSOrgEng": "FERROCAMPUS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "275000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "FESTIVAL CONFOLENS ",
            "RSOrgEng": "FESTIVAL CONFOLENS ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FESTIVAL CONFOLENS ",
            "RSOrgEng": "FESTIVAL CONFOLENS ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "FESTIVAL LA ROCHELLE CINEMA - INTERNAT IONNAL FILM FESTIVAL",
            "RSOrgEng": "FESTIVAL LA ROCHELLE CINEMA - INTERNAT IONNAL FILM FESTIVAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FESTIVAL LA ROCHELLE CINEMA - INTERNAT IONNAL FILM FESTIVAL",
            "RSOrgEng": "FESTIVAL LA ROCHELLE CINEMA - INTERNAT IONNAL FILM FESTIVAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "77700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "FIAGEO GROUPE DELBOS ",
            "RSOrgEng": "FIAGEO GROUPE DELBOS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "140236.99"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "FIAGEO GROUPE DELBOS ",
            "RSOrgEng": "FIAGEO GROUPE DELBOS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "54156.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "FIBOIS LANDES DE GASCOGNE ",
            "RSOrgEng": "FIBOIS LANDES DE GASCOGNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75112.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FIBOIS LANDES DE GASCOGNE ",
            "RSOrgEng": "FIBOIS LANDES DE GASCOGNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "114247.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "FIBOIS LANDES DE GASCOGNE ",
            "RSOrgEng": "FIBOIS LANDES DE GASCOGNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "39060.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FIBOIS NOUVELLE AQUITAINE ",
            "RSOrgEng": "FIBOIS NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "289664.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "FILMER LE TRAVAIL ",
            "RSOrgEng": "FILMER LE TRAVAIL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "FILMER LE TRAVAIL ",
            "RSOrgEng": "FILMER LE TRAVAIL ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "68000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "FINEHEART ",
            "RSOrgEng": "FINEHEART ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "250000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "FINEHEART ",
            "RSOrgEng": "FINEHEART ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "500000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FLEX-ON ",
            "RSOrgEng": "FLEX-ON ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "115560.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FOLIVARI ",
            "RSOrgEng": "FOLIVARI ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FOLIVARI ",
            "RSOrgEng": "FOLIVARI ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "FOLIVARI ",
            "RSOrgEng": "FOLIVARI ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION JOHN BOST ",
            "RSOrgEng": "FONDATION JOHN BOST ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "202696.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION JOHN BOST ",
            "RSOrgEng": "FONDATION JOHN BOST ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "6104.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION JOHN BOST ",
            "RSOrgEng": "FONDATION JOHN BOST ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "1050000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION JOHN BOST ",
            "RSOrgEng": "FONDATION JOHN BOST ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "1000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION NATIONALE SCIENCE POLITIQUE ",
            "RSOrgEng": "FONDATION NATIONALE SCIENCE POLITIQUE ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "250000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION NATIONALE SCIENCE POLITIQUE ",
            "RSOrgEng": "FONDATION NATIONALE SCIENCE POLITIQUE ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "263800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION NATIONALE SCIENCE POLITIQUE ",
            "RSOrgEng": "FONDATION NATIONALE SCIENCE POLITIQUE ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "250000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION NATIONALE SCIENCE POLITIQUE ",
            "RSOrgEng": "FONDATION NATIONALE SCIENCE POLITIQUE ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDATION TARA ",
            "RSOrgEng": "FONDATION TARA ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL ART CONTEMPORAIN ARTOTH EQUE NOUVELLE-AQUITAINE FRAC - ARTOTHE",
            "RSOrgEng": "FONDS REGIONAL ART CONTEMPORAIN ARTOTH EQUE NOUVELLE-AQUITAINE FRAC - ARTOTHE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL ART CONTEMPORAIN ARTOTH EQUE NOUVELLE-AQUITAINE FRAC - ARTOTHE",
            "RSOrgEng": "FONDS REGIONAL ART CONTEMPORAIN ARTOTH EQUE NOUVELLE-AQUITAINE FRAC - ARTOTHE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75350.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL ART CONTEMPORAIN ARTOTH EQUE NOUVELLE-AQUITAINE FRAC - ARTOTHE",
            "RSOrgEng": "FONDS REGIONAL ART CONTEMPORAIN ARTOTH EQUE NOUVELLE-AQUITAINE FRAC - ARTOTHE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "446887.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "RSOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "RSOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "RSOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "RSOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14722.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "RSOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "221914.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "RSOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12482.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "RSOrgEng": "FONDS REGIONAL D ART CONTEMPORAIN NOUV ELLE AQUITAINE MECA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1012560.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "FOOTBALL CLUB GIRONDINS DE BORDEAUX",
            "RSOrgEng": "FOOTBALL CLUB GIRONDINS DE BORDEAUX",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "FOOTBALL CLUB GIRONDINS DE BORDEAUX",
            "RSOrgEng": "FOOTBALL CLUB GIRONDINS DE BORDEAUX",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "56000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "FRAB NOUVELLE AQUITAINE ",
            "RSOrgEng": "FRAB NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "
S ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "29296.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "GASCOGNE BOIS ",
            "RSOrgEng": "GASCOGNE BOIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "443400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "GAU ESKOLAK AEK ",
            "RSOrgEng": "GAU ESKOLAK AEK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19912.59"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "GAU ESKOLAK AEK ",
            "RSOrgEng": "GAU ESKOLAK AEK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "56400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "GENERAL MILLS LANDES ",
            "RSOrgEng": "GENERAL MILLS LANDES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "G\u00c9N\u00c9RATION ROBOTS ",
            "RSOrgEng": "G\u00c9N\u00c9RATION ROBOTS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "6169.28"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "G\u00c9N\u00c9RATION ROBOTS ",
            "RSOrgEng": "G\u00c9N\u00c9RATION ROBOTS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "353920.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "GIP FORMATION CONTINUE ET INSERTION PR OFESSIONNELLE D AQUITAINE",
            "RSOrgEng": "GIP FORMATION CONTINUE ET INSERTION PR OFESSIONNELLE D AQUITAINE",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat public (GIP)",
            "MtOrgEng": "514310.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "GIRONDE INITIATIVE ASSOCIATION ",
            "RSOrgEng": "GIRONDE INITIATIVE ASSOCIATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "93445.69"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "GLOB THEATRE ",
            "RSOrgEng": "GLOB THEATRE ",
            "NatJurOrgEng": "SARL coop\u00e9rative ouvri\u00e8re de production (SCOP)",
            "MtOrgEng": "3207.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "GLOB THEATRE ",
            "RSOrgEng": "GLOB THEATRE ",
            "NatJurOrgEng": "SARL coop\u00e9rative ouvri\u00e8re de production (SCOP)",
            "MtOrgEng": "79927.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "GLOB THEATRE ",
            "RSOrgEng": "GLOB THEATRE ",
            "NatJurOrgEng": "SARL coop\u00e9rative ouvri\u00e8re de production (SCOP)",
            "MtOrgEng": "57050.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "GO4IOT ",
            "RSOrgEng": "GO4IOT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "GOUPIL INDUSTRIE ",
            "RSOrgEng": "GOUPIL INDUSTRIE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "168413.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "GOURDON FRERES SA ",
            "RSOrgEng": "GOURDON FRERES SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "14884.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "GOURDON FRERES SA ",
            "RSOrgEng": "GOURDON FRERES SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "99659.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "GOURDON FRERES SA ",
            "RSOrgEng": "GOURDON FRERES SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "19567.56"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "GOURMANDISE SANTE ",
            "RSOrgEng": "GOURMANDISE SANTE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "18858.46"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "GOURMANDISE SANTE ",
            "RSOrgEng": "GOURMANDISE SANTE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "80668.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "GOYALAB ",
            "RSOrgEng": "GOYALAB ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "17500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "GOYALAB ",
            "RSOrgEng": "GOYALAB ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "RSOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26340.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-12",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "RSOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "55569.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "RSOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "RSOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "63000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-12-17",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "RSOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "73524.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "RSOrgEng": "GRAINE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "71257.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "GRANABIO ",
            "RSOrgEng": "GRANABIO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "92484.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAND PAVOIS ORGANISATION ASSOCIATION",
            "RSOrgEng": "GRAND PAVOIS ORGANISATION ASSOCIATION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36490.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAND PAVOIS ORGANISATION ASSOCIATION",
            "RSOrgEng": "GRAND PAVOIS ORGANISATION ASSOCIATION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "54000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "GRAPHIC APPLICATION ",
            "RSOrgEng": "GRAPHIC APPLICATION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "156629.43"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "GREEN ENERGIE BRIVE ",
            "RSOrgEng": "GREEN ENERGIE BRIVE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "838956.16"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "GREENPILE ",
            "RSOrgEng": "GREENPILE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "94531.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPE AQMO ",
            "RSOrgEng": "GROUPE AQMO ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "176599.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPE BELARRITZ ",
            "RSOrgEng": "GROUPE BELARRITZ ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPEMENT DE DEFENSE CONTRE LES ORGAN ISMES NUISIBLES DE LA VIGNE DES BORDEA",
            "RSOrgEng": "GROUPEMENT DE DEFENSE CONTRE LES ORGAN ISMES NUISIBLES DE LA VIGNE DES BORDEA",
            "NatJurOrgEng": "Syndicat patronal",
            "MtOrgEng": "94694.21"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPEMENT D INTERET PUBLIC AUTONOM LAB",
            "RSOrgEng": "GROUPEMENT D INTERET PUBLIC AUTONOM LAB",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat public (GIP)",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPEMENT D INTERET PUBLIC AUTONOM LAB",
            "RSOrgEng": "GROUPEMENT D INTERET PUBLIC AUTONOM LAB",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat public (GIP)",
            "MtOrgEng": "21600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPEMENT D INTERET PUBLIC AUTONOM LAB",
            "RSOrgEng": "GROUPEMENT D INTERET PUBLIC AUTONOM LAB",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat public (GIP)",
            "MtOrgEng": "21735.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPEMENT D INTERET PUBLIC AUTONOM LAB",
            "RSOrgEng": "GROUPEMENT D INTERET PUBLIC AUTONOM LAB",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat public (GIP)",
            "MtOrgEng": "255000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPE REGIONAL D'ANIMATION ET D'INIT IATION A LA NATURE ET L'ENVIRONNEMENT",
            "RSOrgEng": "GROUPE REGIONAL D'ANIMATION ET D'INIT IATION A LA NATURE ET L'ENVIRONNEMENT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13301.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPE REGIONAL D'ANIMATION ET D'INIT IATION A LA NATURE ET L'ENVIRONNEMENT",
            "RSOrgEng": "GROUPE REGIONAL D'ANIMATION ET D'INIT IATION A LA NATURE ET L'ENVIRONNEMENT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPE REGIONAL D'ANIMATION ET D'INIT IATION A LA NATURE ET L'ENVIRONNEMENT",
            "RSOrgEng": "GROUPE REGIONAL D'ANIMATION ET D'INIT IATION A LA NATURE ET L'ENVIRONNEMENT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "GROUPE VOLTAIRE ",
            "RSOrgEng": "GROUPE VOLTAIRE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "110941.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "GUYENNE PLASTIQUE ",
            "RSOrgEng": "GUYENNE PLASTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "118977.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITAT ECO ACTION ",
            "RSOrgEng": "HABITAT ECO ACTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "18070.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITAT ECO ACTION ",
            "RSOrgEng": "HABITAT ECO ACTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "4000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITAT ECO ACTION ",
            "RSOrgEng": "HABITAT ECO ACTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "37853.6"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITAT ECO ACTION ",
            "RSOrgEng": "HABITAT ECO ACTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "43840.07"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITATS DES POSSIBLES ",
            "RSOrgEng": "HABITATS DES POSSIBLES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10052.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITATS DES POSSIBLES ",
            "RSOrgEng": "HABITATS DES POSSIBLES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITATS DES POSSIBLES ",
            "RSOrgEng": "HABITATS DES POSSIBLES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "62371.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITATS JEUNES LE LEVAIN ",
            "RSOrgEng": "HABITATS JEUNES LE LEVAIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "88000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "HABITATS JEUNES LE LEVAIN ",
            "RSOrgEng": "HABITATS JEUNES LE LEVAIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "HANDIC APTITUDE ",
            "RSOrgEng": "HANDIC APTITUDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "107871.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "HANDIC APTITUDE ",
            "RSOrgEng": "HANDIC APTITUDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "251701.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "HARI PRODUCTIONS ",
            "RSOrgEng": "HARI PRODUCTIONS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "HARI PRODUCTIONS ",
            "RSOrgEng": "HARI PRODUCTIONS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "45000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "HBRI ",
            "RSOrgEng": "HBRI ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "175000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "HERMIONE LA FAYETTE ",
            "RSOrgEng": "HERMIONE LA FAYETTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21159.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "HERMIONE LA FAYETTE ",
            "RSOrgEng": "HERMIONE LA FAYETTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "HERMIONE LA FAYETTE ",
            "RSOrgEng": "HERMIONE LA FAYETTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "32379.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "HERTUS INDUSTRIES ",
            "RSOrgEng": "HERTUS INDUSTRIES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "11806.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "HERTUS INDUSTRIES ",
            "RSOrgEng": "HERTUS INDUSTRIES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "309885.79"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "HEULIEZ BUS ",
            "RSOrgEng": "HEULIEZ BUS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "292729.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "HIBERNIAN WORKSHOP ",
            "RSOrgEng": "HIBERNIAN WORKSHOP ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "84590.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "HOMMES ET SAVOIRS ",
            "RSOrgEng": "HOMMES ET SAVOIRS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "48650.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "HOMMES ET SAVOIRS ",
            "RSOrgEng": "HOMMES ET SAVOIRS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "34515.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "HOPITAL BAGATELLE ",
            "RSOrgEng": "HOPITAL BAGATELLE ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "166147.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "HOPITAL BAGATELLE ",
            "RSOrgEng": "HOPITAL BAGATELLE ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "413447.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "HOPITAL BAGATELLE ",
            "RSOrgEng": "HOPITAL BAGATELLE ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "6638.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "HOPITAL BAGATELLE ",
            "RSOrgEng": "HOPITAL BAGATELLE ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "1316000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "HOPITAL BAGATELLE ",
            "RSOrgEng": "HOPITAL BAGATELLE ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "4962.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "HOPITAL BAGATELLE ",
            "RSOrgEng": "HOPITAL BAGATELLE ",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "2994.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "HOURAT ",
            "RSOrgEng": "HOURAT ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "52500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "HOURAT ",
            "RSOrgEng": "HOURAT ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "5883.33"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "HOURAT ",
            "RSOrgEng": "HOURAT ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "55944.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "HOURAT ",
            "RSOrgEng": "HOURAT ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "31146.72"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "HUBERTRACK ",
            "RSOrgEng": "HUBERTRACK ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "121800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "HUTCHINSON SNC ",
            "RSOrgEng": "HUTCHINSON SNC ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en nom collectif",
            "MtOrgEng": "183300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "HYDROGENE DE FRANCE ",
            "RSOrgEng": "HYDROGENE DE FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "232124.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "HYDROGENE DE FRANCE ",
            "RSOrgEng": "HYDROGENE DE FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "489050.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "I2S ",
            "RSOrgEng": "I2S ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "706.49"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "I2S ",
            "RSOrgEng": "I2S ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "9200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "I2S ",
            "RSOrgEng": "I2S ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "147827.5"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "I2S ",
            "RSOrgEng": "I2S ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "225790.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-05-29",
            "NatEng": "Subvention",
            "NomOrgEng": "I CERAM ",
            "RSOrgEng": "I CERAM ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "67767.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "I CERAM ",
            "RSOrgEng": "I CERAM ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "150266.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "I CERAM ",
            "RSOrgEng": "I CERAM ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "RSOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "RSOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "RSOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2803.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "RSOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "266558.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "RSOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "63000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "RSOrgEng": "ID INITIATIVE DEVELOPPEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19534.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "I.F.P. ATLANTIQUE ",
            "RSOrgEng": "I.F.P. ATLANTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "42000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "I.F.P. ATLANTIQUE ",
            "RSOrgEng": "I.F.P. ATLANTIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "52500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "IFREE ",
            "RSOrgEng": "IFREE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "74000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "IFREE ",
            "RSOrgEng": "IFREE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "IFREE ",
            "RSOrgEng": "IFREE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "280000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "RSOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "49237.55"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "RSOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "142048.55"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "RSOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11501.95"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "RSOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "227733.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-20",
            "NatEng": "Subvention",
            "NomOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "RSOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36600.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "RSOrgEng": "IFTS-INSTITUT FILTRATION ET DES TECHN IQUES SEPARATIVES LIQUIDE -SOLIDE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "137500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "IKASLEAK ",
            "RSOrgEng": "IKASLEAK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "IKASLEAK ",
            "RSOrgEng": "IKASLEAK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "159750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "ILASIS LASER ",
            "RSOrgEng": "ILASIS LASER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "125000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "IMAGENE ",
            "RSOrgEng": "IMAGENE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "75126.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "IMAGINE OPTIC ",
            "RSOrgEng": "IMAGINE OPTIC ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "126320.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "IMA - INSTITUT DES MILIEUX AQUATIQUES",
            "RSOrgEng": "IMA - INSTITUT DES MILIEUX AQUATIQUES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27709.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "IMA - INSTITUT DES MILIEUX AQUATIQUES",
            "RSOrgEng": "IMA - INSTITUT DES MILIEUX AQUATIQUES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "96310.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "IMMOBILI\u00c8RE ATLANTIC AM\u00c9NAGEMENT ",
            "RSOrgEng": "IMMOBILI\u00c8RE ATLANTIC AM\u00c9NAGEMENT ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "280000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "IMPRIMERIE COGNACAISE ",
            "RSOrgEng": "IMPRIMERIE COGNACAISE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "28817.89"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "IMPRIMERIE COGNACAISE ",
            "RSOrgEng": "IMPRIMERIE COGNACAISE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "47176.02"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "IMPRIMERIE VALANTIN G. ",
            "RSOrgEng": "IMPRIMERIE VALANTIN G. ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "80138.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "INAE ",
            "RSOrgEng": "INAE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8028.12"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "INAE ",
            "RSOrgEng": "INAE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3620.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "INAE ",
            "RSOrgEng": "INAE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "INAE ",
            "RSOrgEng": "INAE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "107250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "INAE ",
            "RSOrgEng": "INAE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "248500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "INAE ",
            "RSOrgEng": "INAE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1050.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "INAE ",
            "RSOrgEng": "INAE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18525.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "INCARTA ",
            "RSOrgEng": "INCARTA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "97400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "INCARTA ",
            "RSOrgEng": "INCARTA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "58821.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "INCIDENCES TECHNOLOGIES ",
            "RSOrgEng": "INCIDENCES TECHNOLOGIES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "100824.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "INFODROITS ",
            "RSOrgEng": "INFODROITS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "INFODROITS ",
            "RSOrgEng": "INFODROITS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "INFODROITS ",
            "RSOrgEng": "INFODROITS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "INFODROITS ",
            "RSOrgEng": "INFODROITS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21450.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "INFODROITS ",
            "RSOrgEng": "INFODROITS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE CORREZE ",
            "RSOrgEng": "INITIATIVE CORREZE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "132924.58"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE HAUTE VIENNE ",
            "RSOrgEng": "INITIATIVE HAUTE VIENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "69553.26"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE HAUTE VIENNE ",
            "RSOrgEng": "INITIATIVE HAUTE VIENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE HAUTE VIENNE ",
            "RSOrgEng": "INITIATIVE HAUTE VIENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "91000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE LANDES ",
            "RSOrgEng": "INITIATIVE LANDES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE NOUVELLE AQUITAINE ",
            "RSOrgEng": "INITIATIVE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "38500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-10",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE NOUVELLE AQUITAINE ",
            "RSOrgEng": "INITIATIVE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "0.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE NOUVELLE AQUITAINE ",
            "RSOrgEng": "INITIATIVE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "180000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE NOUVELLE AQUITAINE ",
            "RSOrgEng": "INITIATIVE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8000000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "INITIATIVE VIENNE ",
            "RSOrgEng": "INITIATIVE VIENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "115729.09"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-26",
            "NatEng": "Subvention",
            "NomOrgEng": "INNOLENS ",
            "RSOrgEng": "INNOLENS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "265591.12"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "INNOVATIVE ENERGY ",
            "RSOrgEng": "INNOVATIVE ENERGY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "150760.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "INNOVI ",
            "RSOrgEng": "INNOVI ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "112779.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "INPLANTA ",
            "RSOrgEng": "INPLANTA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "55000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "INPLANTA ",
            "RSOrgEng": "INPLANTA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "24058.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "INSERTION EMPLOI BEARN ADOUR ",
            "RSOrgEng": "INSERTION EMPLOI BEARN ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "67363.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "INSERTION EMPLOI BEARN ADOUR ",
            "RSOrgEng": "INSERTION EMPLOI BEARN ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7131.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "INSERTION EMPLOI BEARN ADOUR ",
            "RSOrgEng": "INSERTION EMPLOI BEARN ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15066.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "INSERTION EMPLOI BEARN ADOUR ",
            "RSOrgEng": "INSERTION EMPLOI BEARN ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10891.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "INSILIBIO ",
            "RSOrgEng": "INSILIBIO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "130000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "IN SITU TRAINING ",
            "RSOrgEng": "IN SITU TRAINING ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "INST D ETUDES OCCITANES DU LIMOUSIN IEO",
            "RSOrgEng": "INST D ETUDES OCCITANES DU LIMOUSIN IEO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "INST D ETUDES OCCITANES DU LIMOUSIN IEO",
            "RSOrgEng": "INST D ETUDES OCCITANES DU LIMOUSIN IEO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "INST D ETUDES OCCITANES DU LIMOUSIN IEO",
            "RSOrgEng": "INST D ETUDES OCCITANES DU LIMOUSIN IEO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "INST D ETUDES OCCITANES DU LIMOUSIN IEO",
            "RSOrgEng": "INST D ETUDES OCCITANES DU LIMOUSIN IEO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "64400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "RSOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45446.32"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "RSOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8439.73"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "RSOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "33348.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "RSOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-30",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "RSOrgEng": "INSTIT NATIONAL FORMATION APPLICATION CENTRE CULTURE OUVRIERE-INFA AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "128203.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT BERGONI\u00c9 ",
            "RSOrgEng": "INSTITUT BERGONI\u00c9 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "171330.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT BERGONI\u00c9 ",
            "RSOrgEng": "INSTITUT BERGONI\u00c9 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT CULTUREL BASQUE EUSKAL KULTUR ERAKUNDEA",
            "RSOrgEng": "INSTITUT CULTUREL BASQUE EUSKAL KULTUR ERAKUNDEA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "58800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT CULTUREL BASQUE EUSKAL KULTUR ERAKUNDEA",
            "RSOrgEng": "INSTITUT CULTUREL BASQUE EUSKAL KULTUR ERAKUNDEA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "137200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DE FORMATION SAINT ANTOINE ",
            "RSOrgEng": "INSTITUT DE FORMATION SAINT ANTOINE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "89428.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DE FORMATION SAINT ANTOINE ",
            "RSOrgEng": "INSTITUT DE FORMATION SAINT ANTOINE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "248000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DE L ENGAGEMENT ",
            "RSOrgEng": "INSTITUT DE L ENGAGEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "49000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DE L ENGAGEMENT ",
            "RSOrgEng": "INSTITUT DE L ENGAGEMENT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES MUSIQUES ROCK ",
            "RSOrgEng": "INSTITUT DES MUSIQUES ROCK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES MUSIQUES ROCK ",
            "RSOrgEng": "INSTITUT DES MUSIQUES ROCK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES MUSIQUES ROCK ",
            "RSOrgEng": "INSTITUT DES MUSIQUES ROCK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES MUSIQUES ROCK ",
            "RSOrgEng": "INSTITUT DES MUSIQUES ROCK ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "RSOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "NatJurOrgEng": "Syndicat patronal",
            "MtOrgEng": "8963.72"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "RSOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "NatJurOrgEng": "Syndicat patronal",
            "MtOrgEng": "413076.62"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "RSOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "NatJurOrgEng": "Syndicat patronal",
            "MtOrgEng": "7581.27"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "RSOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "NatJurOrgEng": "Syndicat patronal",
            "MtOrgEng": "14160.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "RSOrgEng": "INSTITUT DES SCIENCES DE LA NATURE ET DE L'AGROALIMENTAIRE DE BORDEAUX",
            "NatJurOrgEng": "Syndicat patronal",
            "MtOrgEng": "119145.94"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-07-07",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT D OPTIQUE ",
            "RSOrgEng": "INSTITUT D OPTIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "48500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-07-06",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT D OPTIQUE ",
            "RSOrgEng": "INSTITUT D OPTIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "181706.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT D OPTIQUE ",
            "RSOrgEng": "INSTITUT D OPTIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "97207.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT D OPTIQUE ",
            "RSOrgEng": "INSTITUT D OPTIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "709607.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-04-03",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT D OPTIQUE ",
            "RSOrgEng": "INSTITUT D OPTIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e, reconnue d'utilit\u00e9 publique",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DU TRAVAIL SOCIAL P. BOURDIEU ",
            "RSOrgEng": "INSTITUT DU TRAVAIL SOCIAL P. BOURDIEU ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "472971.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DU TRAVAIL SOCIAL P. BOURDIEU ",
            "RSOrgEng": "INSTITUT DU TRAVAIL SOCIAL P. BOURDIEU ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1810000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "INSTITUT DU TRAVAIL SOCIAL P. BOURDIEU ",
            "RSOrgEng": "INSTITUT DU TRAVAIL SOCIAL P. BOURDIEU ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "
GES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "27737.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "RSOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "142496.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "RSOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14595.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "RSOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9352.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "RSOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9885.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "RSOrgEng": "LEAP PRIVE ST-ANTOINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3304.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LEBOURG NEGOCE ",
            "RSOrgEng": "LEBOURG NEGOCE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "113754.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4222.32"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4026.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19342.18"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14025.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3850.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LE CENTRE ",
            "RSOrgEng": "LE CENTRE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LECTRA ",
            "RSOrgEng": "LECTRA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LECTRA ",
            "RSOrgEng": "LECTRA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "41660.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LE GRAND DRESSING ",
            "RSOrgEng": "LE GRAND DRESSING ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LE GRAND LARGE ",
            "RSOrgEng": "LE GRAND LARGE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LE GRENIER DE MEZOS ",
            "RSOrgEng": "LE GRENIER DE MEZOS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LE GRENIER DE MEZOS ",
            "RSOrgEng": "LE GRENIER DE MEZOS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "78189.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LE GRENIER DE MEZOS ",
            "RSOrgEng": "LE GRENIER DE MEZOS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6246.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LE GRENIER DES GASTRONOMES ",
            "RSOrgEng": "LE GRENIER DES GASTRONOMES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "160000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "RSOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19431.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "RSOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25337.56"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "RSOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5256.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "RSOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "288.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "RSOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5320.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "RSOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3406.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "RSOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21914.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "RSOrgEng": "LEGTPA PRIVE ARMAND DAVID OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8560.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LEH ",
            "RSOrgEng": "LEH ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "299810.71"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LEH ",
            "RSOrgEng": "LEH ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "510488.51"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LE LABA ",
            "RSOrgEng": "LE LABA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LE LABA ",
            "RSOrgEng": "LE LABA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LE LABA ",
            "RSOrgEng": "LE LABA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "LE LABA ",
            "RSOrgEng": "LE LABA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LE LABA ",
            "RSOrgEng": "LE LABA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-09-19",
            "NatEng": "Subvention",
            "NomOrgEng": "LE NOMBRIL DU MONDE ",
            "RSOrgEng": "LE NOMBRIL DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1150.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LE NOMBRIL DU MONDE ",
            "RSOrgEng": "LE NOMBRIL DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LE NOMBRIL DU MONDE ",
            "RSOrgEng": "LE NOMBRIL DU MONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "66500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "LES ALLEES GOURMANDES ",
            "RSOrgEng": "LES ALLEES GOURMANDES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "153277.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "LES ALLEES GOURMANDES ",
            "RSOrgEng": "LES ALLEES GOURMANDES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "63378.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "LES ATELIERS DU BOCAGE ",
            "RSOrgEng": "LES ATELIERS DU BOCAGE ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 directoire",
            "MtOrgEng": "52612.46"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LES ATELIERS DU BOCAGE ",
            "RSOrgEng": "LES ATELIERS DU BOCAGE ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 directoire",
            "MtOrgEng": "8000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "LES ATELIERS DU BOCAGE ",
            "RSOrgEng": "LES ATELIERS DU BOCAGE ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 directoire",
            "MtOrgEng": "7875.66"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LES ATELIERS DU BOCAGE ",
            "RSOrgEng": "LES ATELIERS DU BOCAGE ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 directoire",
            "MtOrgEng": "11687.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LES ATELIERS DU BOCAGE ",
            "RSOrgEng": "LES ATELIERS DU BOCAGE ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 directoire",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LES BOUCHAGES DELAGE ",
            "RSOrgEng": "LES BOUCHAGES DELAGE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LES BOUCHAGES DELAGE ",
            "RSOrgEng": "LES BOUCHAGES DELAGE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "120714.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LES CHAMPIGNONNIERES DE CHANCELADE ",
            "RSOrgEng": "LES CHAMPIGNONNIERES DE CHANCELADE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "94500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-20",
            "NatEng": "Subvention",
            "NomOrgEng": "LES CHEVRIERS DE NOUVELLE AQUITAINE ",
            "RSOrgEng": "LES CHEVRIERS DE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "65297.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LES CHEVRIERS DE NOUVELLE AQUITAINE ",
            "RSOrgEng": "LES CHEVRIERS DE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LES CHEVRIERS DE NOUVELLE AQUITAINE ",
            "RSOrgEng": "LES CHEVRIERS DE NOUVELLE AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "115200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LES CINEMAS DU NORD BASSIN ",
            "RSOrgEng": "LES CINEMAS DU NORD BASSIN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "160000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LES CINEMAS DU NORD BASSIN ",
            "RSOrgEng": "LES CINEMAS DU NORD BASSIN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "
2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE LE GUICHOT OGEC AEP LE GUICHOT",
            "RSOrgEng": "LP PRIVE LE GUICHOT OGEC AEP LE GUICHOT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1540.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "RSOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60759.03"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "RSOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4964.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "RSOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "RSOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7404.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "RSOrgEng": "LP PRIVE MONTPENSIER OGEC IMMACULEE CONCEPTION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2713.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "RSOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "448359.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "RSOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "920.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "RSOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1875.72"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "RSOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "198.62"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "RSOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1520000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "RSOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "RSOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "0.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "RSOrgEng": "LP PRIVE POLARIS FORMATION POLARIS FORMATION IESF LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "38400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "RSOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8265.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "RSOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "93110.71"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "RSOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8305.61"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "RSOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "681.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "RSOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2351.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "RSOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "RSOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3507.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "RSOrgEng": "LP PRIVE ST JOSEPH AEP OGEC DU GABARDAN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "876.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "RSOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "5629.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "RSOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "6651.67"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "RSOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "80453.56"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "RSOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "8098.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "RSOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "575.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "RSOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "280.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "RSOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "4900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "RSOrgEng": "LP PRIVE ST JOSEPH FONDATION D AUTEUIL",
            "NatJurOrgEng": "Fondation",
            "MtOrgEng": "800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13599.05"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13922.41"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "292747.61"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10704.37"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8820.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6810.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1140.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3519.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25864.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6640.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13796.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "38581.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1128.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC AEP HAZPARNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3266.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "77532.22"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8043.93"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8781.44"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "453.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3657.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1780.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "RSOrgEng": "LP PRIVE ST JOSEPH OGEC ST JOSEPH",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5455.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "RSOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11241.66"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "RSOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "148387.22"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "RSOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8536.22"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "RSOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18549.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "RSOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "32550.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "RSOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27669.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "RSOrgEng": "LP PRIVE ST MICHEL ASS DU LP ST MICHEL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3216.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "RSOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8630.32"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "RSOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8144.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "RSOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "53488.55"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "RSOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1245.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "RSOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16982.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "RSOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "780.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "RSOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3420.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "RSOrgEng": "LP PRIVE VINCENT DE PAUL OGEC ENSEMBLE SCOLAIRE VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12470.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19022.39"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15263.96"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "77511.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20790.37"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "344.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "712.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6559.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6531.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17570.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "RSOrgEng": "LP ST AUGUSTIN OGEC ST AUGUSTIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1352.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14961.59"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8959.15"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "117332.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8534.39"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7659.87"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "376.41"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2961.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9464.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "103400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "RSOrgEng": "LT PRIVE BEL ORME OGEC BEL ORME",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "23736.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "RSOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11532.54"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "RSOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9716.31"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "RSOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47780.37"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "RSOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8148.62"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "RSOrgEng": "LT PRIVE SAINTE-ANNE - OGEC STELLA MAR IS STE ANNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15588.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-09-25",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "81.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-20",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "70.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3664.95"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "179388.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3588.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1025.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2719.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6331.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "RSOrgEng": "LYCEE PROFESSIONNEL PRIVE LE VAL DE L OUIN",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "849.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "LYNXTER ",
            "RSOrgEng": "LYNXTER ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "95297.72"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "LYSPACKAGING ",
            "RSOrgEng": "LYSPACKAGING ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "19651.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "LYSPACKAGING ",
            "RSOrgEng": "LYSPACKAGING ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "27318.79"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "LYSPACKAGING ",
            "RSOrgEng": "LYSPACKAGING ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "79510.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MADEINVOTE ",
            "RSOrgEng": "MADEINVOTE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "MAGELLAN ",
            "RSOrgEng": "MAGELLAN ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "156589.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MAINTENANCE CHAUDRON TUYAUT MARMANDAIS E - MCTM",
            "RSOrgEng": "MAINTENANCE CHAUDRON TUYAUT MARMANDAIS E - MCTM",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "126468.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MAINTENANCE CHAUDRON TUYAUT MARMANDAIS E - MCTM",
            "RSOrgEng": "MAINTENANCE CHAUDRON TUYAUT MARMANDAIS E - MCTM",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "33439.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE LA NOUVELLE AQUITAINE \u00c0 PARI S",
            "RSOrgEng": "MAISON DE LA NOUVELLE AQUITAINE \u00c0 PARI S",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "124545.18"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE LA NOUVELLE AQUITAINE \u00c0 PARI S",
            "RSOrgEng": "MAISON DE LA NOUVELLE AQUITAINE \u00c0 PARI S",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "559980.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "109066.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8040.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6784.96"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9120.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "RSOrgEng": "MAISON DE L EMPLOI DU BOCAGE BRESSUIRAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MAISON DE L EMPLOI ET DE LA FORMATION DU PAYS THOUARSAIS",
            "RSOrgEng": "MAISON DE L EMPLOI ET DE LA FORMATION DU PAYS THOUARSAIS",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng":
",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "84094.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "MESOLIA HABITAT ",
            "RSOrgEng": "MESOLIA HABITAT ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "48000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "MESOLIA HABITAT ",
            "RSOrgEng": "MESOLIA HABITAT ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "48000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MESOLIA HABITAT ",
            "RSOrgEng": "MESOLIA HABITAT ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "349500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-30",
            "NatEng": "Subvention",
            "NomOrgEng": "MESOLIA HABITAT ",
            "RSOrgEng": "MESOLIA HABITAT ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "168580.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "METAL-CHROME ",
            "RSOrgEng": "METAL-CHROME ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "353861.31"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "METALO MECANIQUE ",
            "RSOrgEng": "METALO MECANIQUE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "52126.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "METALO MECANIQUE ",
            "RSOrgEng": "METALO MECANIQUE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "25543.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "METHACYCLE ",
            "RSOrgEng": "METHACYCLE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "182375.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "METHA DU ROC ",
            "RSOrgEng": "METHA DU ROC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "115200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "METHALAYOU ",
            "RSOrgEng": "METHALAYOU ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "94538.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "METHALAYOU ",
            "RSOrgEng": "METHALAYOU ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "155000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "METH ALLASSAC BIOGAZ ",
            "RSOrgEng": "METH ALLASSAC BIOGAZ ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "105000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "METHA-PALMI-PORC ",
            "RSOrgEng": "METHA-PALMI-PORC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "254142.56"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "METHA PEYROULET ",
            "RSOrgEng": "METHA PEYROULET ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "93485.19"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "METH INNOV ",
            "RSOrgEng": "METH INNOV ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "591039.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOUILLE SAINT PAUL ASS DE GESTION MFR BOUILLE SAINT PAUL",
            "RSOrgEng": "MFR DE BOUILLE SAINT PAUL ASS DE GESTION MFR BOUILLE SAINT PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "574.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOUILLE SAINT PAUL ASS DE GESTION MFR BOUILLE SAINT PAUL",
            "RSOrgEng": "MFR DE BOUILLE SAINT PAUL ASS DE GESTION MFR BOUILLE SAINT PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7500.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOUILLE SAINT PAUL ASS DE GESTION MFR BOUILLE SAINT PAUL",
            "RSOrgEng": "MFR DE BOUILLE SAINT PAUL ASS DE GESTION MFR BOUILLE SAINT PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "152740.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOUILLE SAINT PAUL ASS DE GESTION MFR BOUILLE SAINT PAUL",
            "RSOrgEng": "MFR DE BOUILLE SAINT PAUL ASS DE GESTION MFR BOUILLE SAINT PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8092.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOURGOUGNAGUE ",
            "RSOrgEng": "MFR DE BOURGOUGNAGUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "548.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOURGOUGNAGUE ",
            "RSOrgEng": "MFR DE BOURGOUGNAGUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "253134.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOURGOUGNAGUE ",
            "RSOrgEng": "MFR DE BOURGOUGNAGUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2820.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOURGOUGNAGUE ",
            "RSOrgEng": "MFR DE BOURGOUGNAGUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1960.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE BOURGOUGNAGUE ",
            "RSOrgEng": "MFR DE BOURGOUGNAGUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "RSOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8996.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "RSOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "109314.76"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "RSOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1820.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "RSOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2736.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "RSOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30250.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "RSOrgEng": "MFR DE L'ENTRE 2 MERS CENTRE FORMAT AGRICOLE PAR ALTERNANCE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10005.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE MIRAMONT DE GUYENNE ",
            "RSOrgEng": "MFR DE MIRAMONT DE GUYENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27417.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE MIRAMONT DE GUYENNE ",
            "RSOrgEng": "MFR DE MIRAMONT DE GUYENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2030.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE MIRAMONT DE GUYENNE ",
            "RSOrgEng": "MFR DE MIRAMONT DE GUYENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28752.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE MIRAMONT DE GUYENNE ",
            "RSOrgEng": "MFR DE MIRAMONT DE GUYENNE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE PONTONX/ADOUR ",
            "RSOrgEng": "MFR DE PONTONX/ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "34726.04"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE PONTONX/ADOUR ",
            "RSOrgEng": "MFR DE PONTONX/ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "101103.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE PONTONX/ADOUR ",
            "RSOrgEng": "MFR DE PONTONX/ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3660.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE PONTONX/ADOUR ",
            "RSOrgEng": "MFR DE PONTONX/ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE PONTONX/ADOUR ",
            "RSOrgEng": "MFR DE PONTONX/ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "54914.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DE PONTONX/ADOUR ",
            "RSOrgEng": "MFR DE PONTONX/ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1552.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU LIBOURNAIS ",
            "RSOrgEng": "MFR DU LIBOURNAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "77673.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU LIBOURNAIS ",
            "RSOrgEng": "MFR DU LIBOURNAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3450.25"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU LIBOURNAIS ",
            "RSOrgEng": "MFR DU LIBOURNAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13833.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU LIBOURNAIS ",
            "RSOrgEng": "MFR DU LIBOURNAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU LIBOURNAIS ",
            "RSOrgEng": "MFR DU LIBOURNAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "80031.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU LIBOURNAIS ",
            "RSOrgEng": "MFR DU LIBOURNAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8544.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU LIBOURNAIS ",
            "RSOrgEng": "MFR DU LIBOURNAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2910.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU NERACAIS ",
            "RSOrgEng": "MFR DU NERACAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "96281.45"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU NERACAIS ",
            "RSOrgEng": "MFR DU NERACAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1260.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU NERACAIS ",
            "RSOrgEng": "MFR DU NERACAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "33102.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU NERACAIS ",
            "RSOrgEng": "MFR DU NERACAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU PERIGORD VERT ",
            "RSOrgEng": "MFR DU PERIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "67967.89"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU PERIGORD VERT ",
            "RSOrgEng": "MFR DU PERIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU PERIGORD VERT ",
            "RSOrgEng": "MFR DU PERIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4970.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR DU PERIGORD VERT ",
            "RSOrgEng": "MFR DU PERIGORD VERT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47979.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "RSOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "138000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "RSOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "322.97"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "RSOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4130.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "RSOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1666.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "RSOrgEng": "MFREO D'AIRE SUR ADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1161.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DE VAYRES ",
            "RSOrgEng": "MFREO DE VAYRES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "54101.25"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DE VAYRES ",
            "RSOrgEng": "MFREO DE VAYRES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5066.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DE VAYRES ",
            "RSOrgEng": "MFREO DE VAYRES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1120.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DE VAYRES ",
            "RSOrgEng": "MFREO DE VAYRES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18218.17"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DE VAYRES ",
            "RSOrgEng": "MFREO DE VAYRES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "39500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DU BLAYAIS ",
            "RSOrgEng": "MFREO DU BLAYAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DU BLAYAIS ",
            "RSOrgEng": "MFREO DU BLAYAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "20550.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DU BLAYAIS ",
            "RSOrgEng": "MFREO DU BLAYAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DU BLAYAIS ",
            "RSOrgEng": "MFREO DU BLAYAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4830.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFREO DU BLAYAIS ",
            "RSOrgEng": "MFREO DU BLAYAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2168.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR MAULEON ",
            "RSOrgEng": "MFR MAULEON ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "43427.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR MAULEON ",
            "RSOrgEng": "MFR MAULEON ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2289.33"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR MAULEON ",
            "RSOrgEng": "MFR MAULEON ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10263.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR MAULEON ",
            "RSOrgEng": "MFR MAULEON ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "111288.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MFR MAULEON ",
            "RSOrgEng": "MFR MAULEON ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1185.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "MICHAEL PAETZOLD ",
            "RSOrgEng": "MICHAEL PAETZOLD ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MICROPLAN FRANCE ",
            "RSOrgEng": "MICROPLAN FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "36412.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-04-03",
            "NatEng": "Subvention",
            "NomOrgEng": "MICROPLAN FRANCE ",
            "RSOrgEng": "MICROPLAN FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "41360.91"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MICROPLAN FRANCE ",
            "RSOrgEng": "MICROPLAN FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "48600.4"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "MICROPLAN FRANCE ",
            "RSOrgEng": "MICROPLAN FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "62041.36"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "MIGNATON ",
            "RSOrgEng": "MIGNATON ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "61153.42"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "MIGNATON ",
            "RSOrgEng": "MIGNATON ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "23335.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MIGRADOUR ",
            "RSOrgEng": "MIGRADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-12-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MIGRADOUR ",
            "RSOrgEng": "MIGRADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-30",
            "NatEng": "Subvention",
            "NomOrgEng": "MIGRADOUR ",
            "RSOrgEng": "MIGRADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "106442.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MIGRADOUR ",
            "RSOrgEng": "MIGRADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "167262.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-19",
            "NatEng": "Subvention",
            "NomOrgEng": "MIGRADOUR ",
            "RSOrgEng": "MIGRADOUR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "95938.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MINOTERIE MOREAU ET FILS ",
            "RSOrgEng": "MINOTERIE MOREAU ET FILS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "98871.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MIRKO ",
            "RSOrgEng": "MIRKO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "RSOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "RSOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "107150.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "RSOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "399500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "RSOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27594.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "RSOrgEng": "MISSION DES OFFICES DE TOURISME NOUVEL LE-AQUITAINE- MONA",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "42575.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ",
            "RSOrgEng": "MISSION LOCALE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "67780.59"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ",
            "RSOrgEng": "MISSION LOCALE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "RSOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "113712.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "RSOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6508.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "RSOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "39758.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "RSOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2130.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "RSOrgEng": "MISSION LOCALE AGGLOMERATION ROYAN ATL ANTIQUE POUR INSERTION SOCIALE ET QUAL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ARC CHARENTE ",
            "RSOrgEng": "MISSION LOCALE ARC CHARENTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "203353.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ARC CHARENTE ",
            "RSOrgEng": "MISSION LOCALE ARC CHARENTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ARC CHARENTE ",
            "RSOrgEng": "MISSION LOCALE ARC CHARENTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ARC CHARENTE ",
            "RSOrgEng": "MISSION LOCALE ARC CHARENTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "RSOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "RSOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "263247.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "RSOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2105.67"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "RSOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "RSOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2715.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "RSOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61936.81"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "RSOrgEng": "MISSION LOCALE AVENIR JEUNES PAYS BASQUE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE BORDEAUX AVENIR JEUNES ",
            "RSOrgEng": "MISSION LOCALE BORDEAUX AVENIR JEUNES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "271434.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "RSOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "223907.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "RSOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1629.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "RSOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "RSOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7594.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "RSOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2491.97"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "RSOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "RSOrgEng": "MISSION LOCALE DE LA CREUSE INSER PROF SOC JEUNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8452.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE L AGENAIS DE L ALBRE T ET DU CONFLUENT",
            "RSOrgEng": "MISSION LOCALE DE L AGENAIS DE L ALBRE T ET DU CONFLUENT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "190458.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE DE L AGENAIS DE L ALBRE T ET DU CONFLUENT",
            
rgEng": "MISSION LOCALE LA ROCHELLE RE PAYS D A UNIS PR INSERTION SOCIALE ET PROFESSIO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE LA ROCHELLE RE PAYS D A UNIS PR INSERTION SOCIALE ET PROFESSIO",
            "RSOrgEng": "MISSION LOCALE LA ROCHELLE RE PAYS D A UNIS PR INSERTION SOCIALE ET PROFESSIO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE LA ROCHELLE RE PAYS D A UNIS PR INSERTION SOCIALE ET PROFESSIO",
            "RSOrgEng": "MISSION LOCALE LA ROCHELLE RE PAYS D A UNIS PR INSERTION SOCIALE ET PROFESSIO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE LA ROCHELLE RE PAYS D A UNIS PR INSERTION SOCIALE ET PROFESSIO",
            "RSOrgEng": "MISSION LOCALE LA ROCHELLE RE PAYS D A UNIS PR INSERTION SOCIALE ET PROFESSIO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE MOYENNE GAR. ",
            "RSOrgEng": "MISSION LOCALE MOYENNE GAR. ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "145928.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE MOYENNE GAR. ",
            "RSOrgEng": "MISSION LOCALE MOYENNE GAR. ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10255.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE MOYENNE GAR. ",
            "RSOrgEng": "MISSION LOCALE MOYENNE GAR. ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "RSOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "123980.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "RSOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "RSOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "RSOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "RSOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "37941.76"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "RSOrgEng": "MISSION LOCALE PERIGORD NOIR ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE RIBERACOIS VALLEE DE L'ISLE",
            "RSOrgEng": "MISSION LOCALE RIBERACOIS VALLEE DE L'ISLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "131222.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE RIBERACOIS VALLEE DE L'ISLE",
            "RSOrgEng": "MISSION LOCALE RIBERACOIS VALLEE DE L'ISLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "31649.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE RIBERACOIS VALLEE DE L'ISLE",
            "RSOrgEng": "MISSION LOCALE RIBERACOIS VALLEE DE L'ISLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "RSOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "157386.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "RSOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "RSOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "RSOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "RSOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1969.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "RSOrgEng": "MISSION LOCALE ROCHEFORT MARENNES OLERON",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1387.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE RURALE CENTRE ET SUD VIENNE",
            "RSOrgEng": "MISSION LOCALE RURALE CENTRE ET SUD VIENNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "164590.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE RURALE CENTRE ET SUD VIENNE",
            "RSOrgEng": "MISSION LOCALE RURALE CENTRE ET SUD VIENNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE SUD GIRONDE ",
            "RSOrgEng": "MISSION LOCALE SUD GIRONDE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "132560.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TECHNOWEST ",
            "RSOrgEng": "MISSION LOCALE TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "227810.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TECHNOWEST ",
            "RSOrgEng": "MISSION LOCALE TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6454.05"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TECHNOWEST ",
            "RSOrgEng": "MISSION LOCALE TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TECHNOWEST ",
            "RSOrgEng": "MISSION LOCALE TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "73769.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TECHNOWEST ",
            "RSOrgEng": "MISSION LOCALE TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TECHNOWEST ",
            "RSOrgEng": "MISSION LOCALE TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TECHNOWEST ",
            "RSOrgEng": "MISSION LOCALE TECHNOWEST ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TULLE CENTRE CORREZE ",
            "RSOrgEng": "MISSION LOCALE TULLE CENTRE CORREZE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "152940.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TULLE CENTRE CORREZE ",
            "RSOrgEng": "MISSION LOCALE TULLE CENTRE CORREZE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TULLE CENTRE CORREZE ",
            "RSOrgEng": "MISSION LOCALE TULLE CENTRE CORREZE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7795.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCALE TULLE CENTRE CORREZE ",
            "RSOrgEng": "MISSION LOCALE TULLE CENTRE CORREZE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "RSOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "160271.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "RSOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "RSOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "RSOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45154.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "RSOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "RSOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "29050.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "RSOrgEng": "MISSION LOCAL INSER SOCIA PROF JEUNE LIB",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6512.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MISS LOC ARR BRIVE INS PRO SOC JEUNES ",
            "RSOrgEng": "MISS LOC ARR BRIVE INS PRO SOC JEUNES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "247544.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MISS LOC ARR BRIVE INS PRO SOC JEUNES ",
            "RSOrgEng": "MISS LOC ARR BRIVE INS PRO SOC JEUNES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MISS LOC ARR BRIVE INS PRO SOC JEUNES ",
            "RSOrgEng": "MISS LOC ARR BRIVE INS PRO SOC JEUNES ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "15050.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MOCA ",
            "RSOrgEng": "MOCA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "1400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "MOCA ",
            "RSOrgEng": "MOCA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MOCA ",
            "RSOrgEng": "MOCA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "17000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "MOCA ",
            "RSOrgEng": "MOCA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MOCA ",
            "RSOrgEng": "MOCA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "36000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "MONGIN ",
            "RSOrgEng": "MONGIN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "31956.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MONGIN ",
            "RSOrgEng": "MONGIN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "81896.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MONSIEUR TSHIRT ",
            "RSOrgEng": "MONSIEUR TSHIRT ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "88000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "MONTAGE ET ASSEMBLAGE M\u00c9CANIQUE SAS ",
            "RSOrgEng": "MONTAGE ET ASSEMBLAGE M\u00c9CANIQUE SAS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "82852.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MONTUSSAN TRANSPORTS SERVICES ",
            "RSOrgEng": "MONTUSSAN TRANSPORTS SERVICES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "75791.77"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MONTUSSAN TRANSPORTS SERVICES ",
            "RSOrgEng": "MONTUSSAN TRANSPORTS SERVICES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "29500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MONTUSSAN TRANSPORTS SERVICES ",
            "RSOrgEng": "MONTUSSAN TRANSPORTS SERVICES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "MOONDA ",
            "RSOrgEng": "MOONDA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "116170.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MOTEURS LEROY SOMER ",
            "RSOrgEng": "MOTEURS LEROY SOMER ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "75942.66"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-04-03",
            "NatEng": "Subvention",
            "NomOrgEng": "MOURLAN ",
            "RSOrgEng": "MOURLAN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "139472.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "MOURLAN ",
            "RSOrgEng": "MOURLAN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "170000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "MS CYCLING ",
            "RSOrgEng": "MS CYCLING ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "MS CYCLING ",
            "RSOrgEng": "MS CYCLING ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "MUSIQUES METISSES ",
            "RSOrgEng": "MUSIQUES METISSES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "83300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "NANNI INDUSTRIES ",
            "RSOrgEng": "NANNI INDUSTRIES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "148500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "NANNI INDUSTRIES ",
            "RSOrgEng": "NANNI INDUSTRIES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "5514.94"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "NATURA PLUS ULTRA PET FOOD ",
            "RSOrgEng": "NATURA PLUS ULTRA PET FOOD ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "104969.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "RSOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2572.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "RSOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "RSOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "38488.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "RSOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2487.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "RSOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "RSOrgEng": "NATURE ENVIRONNEMENT 17 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27972.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "NAVAILLES ",
            "RSOrgEng": "NAVAILLES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "80843.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "NAVAL GROUP ",
            "RSOrgEng": "NAVAL GROUP ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "338000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "NAVAL GROUP ",
            "RSOrgEng": "NAVAL GROUP ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "16000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "NAVAL GROUP ",
            "RSOrgEng": "NAVAL GROUP ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "569197.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "NDC FOUNDRY ",
            "RSOrgEng": "NDC FOUNDRY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "422821.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "NEEL TRIMARANS ",
            "RSOrgEng": "NEEL TRIMARANS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "82827.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "NEEL TRIMARANS ",
            "RSOrgEng": "NEEL TRIMARANS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "153564.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "NEOEN STOCKAGE ",
            "RSOrgEng": "NEOEN STOCKAGE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "247500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "NEO GLS ",
            "RSOrgEng": "NEO GLS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "88190.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "NEO GLS ",
            "RSOrgEng": "NEO GLS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "147500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "NILAYA PRODUCTIONS ",
            "RSOrgEng": "NILAYA PRODUCTIONS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "NJUKO ",
            "RSOrgEng": "NJUKO ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "98208.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2010-05-31",
            "NatEng": "Subvention",
            "NomOrgEng": "NOALIS ",
            "RSOrgEng": "NOALIS ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "45074.63"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "NOALIS ",
            "RSOrgEng": "NOALIS ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "30431.04"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "NOALIS ",
            "RSOrgEng": "NOALIS ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "19500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "NOBATEK INEF 4 ",
            "RSOrgEng": "NOBATEK INEF 4 ",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "406350.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "NORD-OUEST FILMS ",
            "RSOrgEng": "NORD-OUEST FILMS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "84000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "NOUVELLE AQUITAINE AMORCAGE ",
            "RSOrgEng": "NOUVELLE AQUITAINE AMORCAGE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "NOUVELLE AQUITAINE AMORCAGE ",
            "RSOrgEng": "NOUVELLE AQUITAINE AMORCAGE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "120000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "NOUVELLE AQUITAINE CULTURE SCIENTIFIQU E TECHNIQUE ET INDUSTRIELLE",
            "RSOrgEng": "NOUVELLE AQUITAINE CULTURE SCIENTIFIQU E TECHNIQUE ET INDUSTRIELLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "374150.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "NOVAE ",
            "RSOrgEng": "NOVAE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "94919.8"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "NOVAE ",
            "RSOrgEng": "NOVAE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "14735.24"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "NOVANIMA ",
            "RSOrgEng": "NOVANIMA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "NOVANIMA ",
            "RSOrgEng": "NOVANIMA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "27500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "NOVANIMA ",
            "RSOrgEng": "NOVANIMA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "19000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "NOVANIMA ",
            "RSOrgEng": "NOVANIMA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "44900.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "NOVANIMA ",
            "RSOrgEng": "NOVANIMA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "25200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "NOVANIMA ",
            "RSOrgEng": "NOVANIMA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "125300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "NP MEDICAL ",
            "RSOrgEng": "NP MEDICAL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "NUTRISCIENCE ",
            "RSOrgEng": "NUTRISCIENCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "79799.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "OBBIA - OMNIUM BOIS BATIMENT INDUSTRIE ASSOCIES",
            "RSOrgEng": "OBBIA - OMNIUM BOIS BATIMENT INDUSTRIE ASSOCIES",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "75318.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-10-05",
            "NatEng": "Subvention",
            "NomOrgEng": "OBSERVATOIRE REGIONAL DE LA SANTE NOUV ELLE AQUITAINE",
            "RSOrgEng": "OBSERVATOIRE REGIONAL DE LA SANTE NOUV ELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "OBSERVATOIRE REGIONAL DE LA SANTE NOUV ELLE AQUITAINE",
            "RSOrgEng": "OBSERVATOIRE REGIONAL DE LA SANTE NOUV ELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "OBSERVATOIRE REGIONAL DE LA SANTE NOUV ELLE AQUITAINE",
            "RSOrgEng": "OBSERVATOIRE REGIONAL DE LA SANTE NOUV ELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "54000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OBSERVATOIRE REGIONAL DE LA SANTE NOUV ELLE AQUITAINE",
            "RSOrgEng": "OBSERVATOIRE REGIONAL DE LA SANTE NOUV ELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "OCAPIA ",
            "RSOrgEng": "OCAPIA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "114887.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "OCEAN DX ",
            "RSOrgEng": "OCEAN DX ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "102000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OC PROD ",
            "RSOrgEng": "OC PROD ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "96350.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "OC PROD ",
            "RSOrgEng": "OC PROD ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "173993.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "ODEYS ",
            "RSOrgEng": "ODEYS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ODEYS ",
            "RSOrgEng": "ODEYS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "107508.01"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ODEYS ",
            "RSOrgEng": "ODEYS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12013.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "ODEYS ",
            "RSOrgEng": "ODEYS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "244910.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OFFICE ARTISTIQUE DE LA REGION NOUVELL E AQUITAINE",
            "RSOrgEng": "OFFICE ARTISTIQUE DE LA REGION NOUVELL E AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47625.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "OFFICE ARTISTIQUE DE LA REGION NOUVELL E AQUITAINE",
            "RSOrgEng": "OFFICE ARTISTIQUE DE LA REGION NOUVELL E AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "484717.43"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "OFFICE ARTISTIQUE DE LA REGION NOUVELL E AQUITAINE",
            "RSOrgEng": "OFFICE ARTISTIQUE DE LA REGION NOUVELL E AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3099675.83"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "OFFICE DE TOURISME ET DES CONGRES DE BORDEAUX METROPOLE",
            "RSOrgEng": "OFFICE DE TOURISME ET DES CONGRES DE BORDEAUX METROPOLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "OFFICE DE TOURISME ET DES CONGRES DE BORDEAUX METROPOLE",
            "RSOrgEng": "OFFICE DE TOURISME ET DES CONGRES DE BORDEAUX METROPOLE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "36000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC DES 3 RIVIERES-L. JEAN CASSAIGNE LGT ET LP PRIVE JEAN CASSAIGNE",
            "RSOrgEng": "OGEC DES 3 RIVIERES-L. JEAN CASSAIGNE LGT ET LP PRIVE JEAN CASSAIGNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8225.52"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC DES 3 RIVIERES-L. JEAN CASSAIGNE LGT ET LP PRIVE JEAN CASSAIGNE",
            "RSOrgEng": "OGEC DES 3 RIVIERES-L. JEAN CASSAIGNE LGT ET LP PRIVE JEAN CASSAIGNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "59607.52"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC DES 3 RIVIERES-L. JEAN CASSAIGNE LGT ET LP PRIVE JEAN CASSAIGNE",
            "RSOrgEng": "OGEC DES 3 RIVIERES-L. JEAN CASSAIGNE LGT ET LP PRIVE JEAN CASSAIGNE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13270.02"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC NOTRE DAME DE LA COMPASSION LGT ET LP NOTRE DAME DE LA COMPASSION",
            "RSOrgEng": "OGEC NOTRE DAME DE LA COMPASSION LGT ET LP NOTRE DAME DE LA COMPASSION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8433.56"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC NOTRE DAME DE LA COMPASSION LGT ET LP NOTRE DAME DE LA COMPASSION",
            "RSOrgEng": "OGEC NOTRE DAME DE LA COMPASSION LGT ET LP NOTRE DAME DE LA COMPASSION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "114168.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC NOTRE DAME DE LA COMPASSION LGT ET LP NOTRE DAME DE LA COMPASSION",
            "RSOrgEng": "OGEC NOTRE DAME DE LA COMPASSION LGT ET LP NOTRE DAME DE LA COMPASSION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9436.77"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC NOTRE DAME DE LA COMPASSION LGT ET LP NOTRE DAME DE LA COMPASSION",
            "RSOrgEng": "OGEC NOTRE DAME DE LA COMPASSION LGT ET LP NOTRE DAME DE LA COMPASSION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7672.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC STE FAMILLE ST MICHEL LGT ET LP PRIVE STE FAMILLE SAINTONGE",
            "RSOrgEng": "OGEC STE FAMILLE ST MICHEL LGT ET LP PRIVE STE FAMILLE SAINTONGE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25428.83"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC STE FAMILLE ST MICHEL LGT ET LP PRIVE STE FAMILLE SAINTONGE",
            "RSOrgEng": "OGEC STE FAMILLE ST MICHEL LGT ET LP PRIVE STE FAMILLE SAINTONGE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11616.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC STE FAMILLE ST MICHEL LGT ET LP PRIVE STE FAMILLE SAINTONGE",
            "RSOrgEng": "OGEC STE FAMILLE ST MICHEL LGT ET LP PRIVE STE FAMILLE SAINTONGE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "187959.21"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC STE FAMILLE ST MICHEL LGT ET LP PRIVE STE FAMILLE SAINTONGE",
            "RSOrgEng": "OGEC STE FAMILLE ST MICHEL LGT ET LP PRIVE STE FAMILLE SAINTONGE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10173.16"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC STE MARTHE - ST FRONT LGT ET LP PRIVE STE MARTHE - ST FRONT",
            "RSOrgEng": "OGEC STE MARTHE - ST FRONT LGT ET LP PRIVE STE MARTHE - ST FRONT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8945.23"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC STE MARTHE - ST FRONT LGT ET LP PRIVE STE MARTHE - ST FRONT",
            "RSOrgEng": "OGEC STE MARTHE - ST FRONT LGT ET LP PRIVE STE MARTHE - ST FRONT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47087.68"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC STE MARTHE - ST FRONT LGT ET LP PRIVE STE MARTHE - ST FRONT",
            "RSOrgEng": "OGEC STE MARTHE - ST FRONT LGT ET LP PRIVE STE MARTHE - ST FRONT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9958.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC STE MARTHE - ST FRONT LGT ET LP PRIVE STE MARTHE - ST FRONT",
            "RSOrgEng": "OGEC STE MARTHE - ST FRONT LGT ET LP PRIVE STE MARTHE - ST FRONT",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10218.12"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-05-19",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC ST VINCENT DE PAUL LT ET LP PRIVE ST VINCENT DE PAUL",
            "RSOrgEng": "OGEC ST VINCENT DE PAUL LT ET LP PRIVE ST VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26035.77"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC ST VINCENT DE PAUL LT ET LP PRIVE ST VINCENT DE PAUL",
            "RSOrgEng": "OGEC ST VINCENT DE PAUL LT ET LP PRIVE ST VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "73755.54"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-07-11",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC ST VINCENT DE PAUL LT ET LP PRIVE ST VINCENT DE PAUL",
            "RSOrgEng": "OGEC ST VINCENT DE PAUL LT ET LP PRIVE ST VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13881.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "OGEC ST VINCENT DE PAUL LT ET LP PRIVE ST VINCENT DE PAUL",
            "RSOrgEng": "OGEC ST VINCENT DE PAUL LT ET LP PRIVE ST VINCENT DE PAUL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8083.84"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "OLIKROM ",
            "RSOrgEng": "OLIKROM ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "OMA S.A.S. ",
            "RSOrgEng": "OMA S.A.S. ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "117800.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "OPCO MOBILITES ",
            "RSOrgEng": "OPCO MOBILITES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60270.32"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OPCO MOBILITES ",
            "RSOrgEng": "OPCO MOBILITES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "124200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "OPCO SANTE ",
            "RSOrgEng": "OPCO SANTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "387709.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OPCO SANTE ",
            "RSOrgEng": "OPCO SANTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OPERATEUR DE COMPETENCES DES ENTREPRIS ES DE PROXIMITE",
            "RSOrgEng": "OPERATEUR DE COMPETENCES DES ENTREPRIS ES DE PROXIMITE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "94395.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "RSOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "63501.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "RSOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "111276.45"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "RSOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "225000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "RSOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "145000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "RSOrgEng": "OPERATEUR DE COMPETENCES INTERINDUSTRI EL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "125000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "OPTIM CARE ",
            "RSOrgEng": "OPTIM CARE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "ORCHESTRE DE CHAMBRE NOUVELLE AQUITAINE",
            "RSOrgEng": "ORCHESTRE DE CHAMBRE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "ORCHESTRE DE CHAMBRE NOUVELLE AQUITAINE",
            "RSOrgEng": "ORCHESTRE DE CHAMBRE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "240000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "ORCHESTRE DE CHAMBRE NOUVELLE AQUITAINE",
            "RSOrgEng": "ORCHESTRE DE CHAMBRE NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "532000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "RSOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "27600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "RSOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "133823.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "RSOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6878.28"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "RSOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "RSOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "101929.8"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "RSOrgEng": "OSONS, ICI ET MAINTENANT (OIM) ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13274.87"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "OUATECO ",
            "RSOrgEng": "OUATECO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "225000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "OUEST TOOL MAINTENANCE ",
            "RSOrgEng": "OUEST TOOL MAINTENANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "122186.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "OUIDROP ",
            "RSOrgEng": "OUIDROP ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "OXYMETAL ",
            "RSOrgEng": "OXYMETAL ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "PACCOR FRANCE SAS ",
            "RSOrgEng": "PACCOR FRANCE SAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "153634.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "PACKITOO ",
            "RSOrgEng": "PACKITOO ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "85000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "PALMICLEAN ",
            "RSOrgEng": "PALMICLEAN ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "146441.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "PANNEAUX DE CORREZE ",
            "RSOrgEng": "PANNEAUX DE CORREZE ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "186060.08"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "PAPETERIE SAINT MICHEL - GROUPE THIOLL ET",
            "RSOrgEng": "PAPETERIE SAINT MICHEL - GROUPE THIOLL ET",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "361505.51"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "
.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "POLE ENSEIG SUP DE LA MUSIQUE ET LA DA NSE DE BORDEAUX AQUITAINE-CEFEDEM",
            "RSOrgEng": "POLE ENSEIG SUP DE LA MUSIQUE ET LA DA NSE DE BORDEAUX AQUITAINE-CEFEDEM",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "260000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "POLE ENVIRONNEMENT DU LIMOUSIN ",
            "RSOrgEng": "POLE ENVIRONNEMENT DU LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28142.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "POLE ENVIRONNEMENT DU LIMOUSIN ",
            "RSOrgEng": "POLE ENVIRONNEMENT DU LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "78017.81"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "POLE EUROPEEN DE LA CERAMIQUE ",
            "RSOrgEng": "POLE EUROPEEN DE LA CERAMIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "POLE EUROPEEN DE LA CERAMIQUE ",
            "RSOrgEng": "POLE EUROPEEN DE LA CERAMIQUE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "45950.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "POLYNEUROS ",
            "RSOrgEng": "POLYNEUROS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "160000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "POLYPROCESS ",
            "RSOrgEng": "POLYPROCESS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "225368.13"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "POLYRISE ",
            "RSOrgEng": "POLYRISE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "POLYRISE ",
            "RSOrgEng": "POLYRISE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "221759.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-12-12",
            "NatEng": "Subvention",
            "NomOrgEng": "POUR L INSTANT ",
            "RSOrgEng": "POUR L INSTANT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "POUR L INSTANT ",
            "RSOrgEng": "POUR L INSTANT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "POUR L INSTANT ",
            "RSOrgEng": "POUR L INSTANT ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "56000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "PRANA RECHERCHE ET D\u00c9VELOPPEMENT ",
            "RSOrgEng": "PRANA RECHERCHE ET D\u00c9VELOPPEMENT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "17209.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "PRANA RECHERCHE ET D\u00c9VELOPPEMENT ",
            "RSOrgEng": "PRANA RECHERCHE ET D\u00c9VELOPPEMENT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "73754.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "PREVOST SA ",
            "RSOrgEng": "PREVOST SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "38505.82"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "PREVOST SA ",
            "RSOrgEng": "PREVOST SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "42673.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "PRIM LAND ",
            "RSOrgEng": "PRIM LAND ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-02",
            "NatEng": "Subvention",
            "NomOrgEng": "PRODITEC ",
            "RSOrgEng": "PRODITEC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "108000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "PRODITEC ",
            "RSOrgEng": "PRODITEC ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "57600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-10-22",
            "NatEng": "Subvention",
            "NomOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "RSOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "34691.74"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "RSOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "RSOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "RSOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "RSOrgEng": "PROFESSION SPORT CORREZE LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "26000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "PROTIFLY ",
            "RSOrgEng": "PROTIFLY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "71942.74"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "PROTIFLY ",
            "RSOrgEng": "PROTIFLY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "135266.68"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "PROTIFLY ",
            "RSOrgEng": "PROTIFLY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "28603.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "PROXIMUM 365 ",
            "RSOrgEng": "PROXIMUM 365 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "158132.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "PROXIMUM 365 ",
            "RSOrgEng": "PROXIMUM 365 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "125000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "PULLMANS LANDAIS ",
            "RSOrgEng": "PULLMANS LANDAIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "13914.86"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "PULLMANS LANDAIS ",
            "RSOrgEng": "PULLMANS LANDAIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "104441.42"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "PULLMANS LANDAIS ",
            "RSOrgEng": "PULLMANS LANDAIS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "55509.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "PYRAGENA ",
            "RSOrgEng": "PYRAGENA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "22048.34"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "PYRAGENA ",
            "RSOrgEng": "PYRAGENA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28938.28"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "PYRAGENA ",
            "RSOrgEng": "PYRAGENA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "44915.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "PYRAMIDE PRODUCTION ",
            "RSOrgEng": "PYRAMIDE PRODUCTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "2800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "PYRAMIDE PRODUCTION ",
            "RSOrgEng": "PYRAMIDE PRODUCTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "19000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "PYRAMIDE PRODUCTION ",
            "RSOrgEng": "PYRAMIDE PRODUCTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "35700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "PYRAMIDE PRODUCTION ",
            "RSOrgEng": "PYRAMIDE PRODUCTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "22400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "PYR\u00c9N\u00c9ES CONCEPTIONS ",
            "RSOrgEng": "PYR\u00c9N\u00c9ES CONCEPTIONS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "65310.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "PYR\u00c9N\u00c9ES CONCEPTIONS ",
            "RSOrgEng": "PYR\u00c9N\u00c9ES CONCEPTIONS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "14271.04"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-26",
            "NatEng": "Subvention",
            "NomOrgEng": "PYRENEX ",
            "RSOrgEng": "PYRENEX ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "87923.87"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "QUALITE HUITRES MARENNES OLERON ",
            "RSOrgEng": "QUALITE HUITRES MARENNES OLERON ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "55630.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "QUALITE HUITRES MARENNES OLERON ",
            "RSOrgEng": "QUALITE HUITRES MARENNES OLERON ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "84586.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "QUARTIER ROUGE ",
            "RSOrgEng": "QUARTIER ROUGE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "QUARTIER ROUGE ",
            "RSOrgEng": "QUARTIER ROUGE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "QUARTIER ROUGE ",
            "RSOrgEng": "QUARTIER ROUGE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "QUARTIER ROUGE ",
            "RSOrgEng": "QUARTIER ROUGE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-20",
            "NatEng": "Subvention",
            "NomOrgEng": "QUARTIER ROUGE ",
            "RSOrgEng": "QUARTIER ROUGE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "79114.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "RAPIDES DU POITOU ",
            "RSOrgEng": "RAPIDES DU POITOU ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "287382.03"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "RAPIDES DU POITOU ",
            "RSOrgEng": "RAPIDES DU POITOU ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "345.76"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "RAPIDES DU POITOU ",
            "RSOrgEng": "RAPIDES DU POITOU ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "953.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "RAYONIER A.M. FRANCE INNOVATION ",
            "RSOrgEng": "RAYONIER A.M. FRANCE INNOVATION ",
            "NatJurOrgEng": "Groupement d'int\u00e9r\u00eat \u00e9conomique (GIE)",
            "MtOrgEng": "80427.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "RAYONIER A.M. TARTAS ",
            "RSOrgEng": "RAYONIER A.M. TARTAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "318089.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "RAYONIER A.M. TARTAS ",
            "RSOrgEng": "RAYONIER A.M. TARTAS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "446521.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "R&D VISION ",
            "RSOrgEng": "R&D VISION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "59700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "R&D VISION ",
            "RSOrgEng": "R&D VISION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "120286.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "RSOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "RSOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "RSOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5208.16"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "RSOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "29635.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "RSOrgEng": "RECREASCIENCES CTRE CULT SCI TECH IND LIMOGES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "126000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "RESCOLL ",
            "RSOrgEng": "RESCOLL ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "260000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "RESCOLL ",
            "RSOrgEng": "RESCOLL ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "390000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "RESCOLL ",
            "RSOrgEng": "RESCOLL ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "680025.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "RSOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "RSOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "RSOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "RSOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4758.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "RSOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "RSOrgEng": "R\u00c9SEAU ASSOCIATIF POUR LE D\u00c9VELOPPEMEN T ET LA SOLIDARIT\u00c9 INTERNATIONALE NOUV",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "76300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "RESEAU DES INDEPENDANTS DE LA MUSIQUE - RIM",
            "RSOrgEng": "RESEAU DES INDEPENDANTS DE LA MUSIQUE - RIM",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "RESEAU DES INDEPENDANTS DE LA MUSIQUE - RIM",
            "RSOrgEng": "RESEAU DES INDEPENDANTS DE LA MUSIQUE - RIM",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "144000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "RESEAU DES INDEPENDANTS DE LA MUSIQUE - RIM",
            "RSOrgEng": "RESEAU DES INDEPENDANTS DE LA MUSIQUE - RIM",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "343000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "RESEAU DES INDEPENDANTS DE LA MUSIQUE - RIM",
            "RSOrgEng": "RESEAU DES INDEPENDANTS DE LA MUSIQUE - RIM",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "RESEAU DU DISPOSITIF MEDICAL EN NOUVEL LE AQUITAINE",
            "RSOrgEng": "RESEAU DU DISPOSITIF MEDICAL EN NOUVEL LE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28704.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "RESEAU DU DISPOSITIF MEDICAL EN NOUVEL LE AQUITAINE",
            "RSOrgEng": "RESEAU DU DISPOSITIF MEDICAL EN NOUVEL LE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19440.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "RESEAU DU DISPOSITIF MEDICAL EN NOUVEL LE AQUITAINE",
            "RSOrgEng": "RESEAU DU DISPOSITIF MEDICAL EN NOUVEL LE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "44361.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "RSOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "53568.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "RSOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "43491.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "RSOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "811.09"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "RSOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "59400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "RSOrgEng": "RESO CUIR NOUVELLE - AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "93207.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "REVICO ENERGIES VERTES ",
            "RSOrgEng": "REVICO ENERGIES VERTES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "101200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "RHODIA OPERATIONS ",
            "RSOrgEng": "RHODIA OPERATIONS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "2750000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "RMA ",
            "RSOrgEng": "RMA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "197600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng":
",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "102832.59"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SCA UNICOQUE ",
            "RSOrgEng": "SCA UNICOQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "74235.41"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SCA UNICOQUE ",
            "RSOrgEng": "SCA UNICOQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "14680.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SCEA DE CABANA ",
            "RSOrgEng": "SCEA DE CABANA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 civile d'exploitation agricole",
            "MtOrgEng": "172000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SCEA DEMETER ",
            "RSOrgEng": "SCEA DEMETER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 civile d'exploitation agricole",
            "MtOrgEng": "112240.88"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SCEA DES CHAUX ",
            "RSOrgEng": "SCEA DES CHAUX ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 civile d'exploitation agricole",
            "MtOrgEng": "206430.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SCENE NATIONALE ANGOULEME THEATRE D ANGOULEME",
            "RSOrgEng": "SCENE NATIONALE ANGOULEME THEATRE D ANGOULEME",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "7800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SCENE NATIONALE ANGOULEME THEATRE D ANGOULEME",
            "RSOrgEng": "SCENE NATIONALE ANGOULEME THEATRE D ANGOULEME",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "37500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SCENE NATIONALE ANGOULEME THEATRE D ANGOULEME",
            "RSOrgEng": "SCENE NATIONALE ANGOULEME THEATRE D ANGOULEME",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "18200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SCENE NATIONALE ANGOULEME THEATRE D ANGOULEME",
            "RSOrgEng": "SCENE NATIONALE ANGOULEME THEATRE D ANGOULEME",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "87500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SCENES NOMADES ",
            "RSOrgEng": "SCENES NOMADES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "22563.75"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SCENES NOMADES ",
            "RSOrgEng": "SCENES NOMADES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "16500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SCENES NOMADES ",
            "RSOrgEng": "SCENES NOMADES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SCENES NOMADES ",
            "RSOrgEng": "SCENES NOMADES ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "65590.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "RSOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "30134.76"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "RSOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "39805.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "RSOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "53163.28"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "RSOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "RSOrgEng": "SCIC INTERSTICES SUD AQUITAINE ",
            "NatJurOrgEng": "Autre SARL coop\u00e9rative",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC PAU PYRENEES ",
            "RSOrgEng": "SCIC PAU PYRENEES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "31342.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC PAU PYRENEES ",
            "RSOrgEng": "SCIC PAU PYRENEES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "24000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC PAU PYRENEES ",
            "RSOrgEng": "SCIC PAU PYRENEES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIC PAU PYRENEES ",
            "RSOrgEng": "SCIC PAU PYRENEES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "26318.86"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIERIE DE SAINT YAGUEN ",
            "RSOrgEng": "SCIERIE DE SAINT YAGUEN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "13362.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SCIERIE DE SAINT YAGUEN ",
            "RSOrgEng": "SCIERIE DE SAINT YAGUEN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "80000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SEATURNS ",
            "RSOrgEng": "SEATURNS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "87500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SECTION PALOISE RUGBY PRO ",
            "RSOrgEng": "SECTION PALOISE RUGBY PRO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "39000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SECTION PALOISE RUGBY PRO ",
            "RSOrgEng": "SECTION PALOISE RUGBY PRO ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "91000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SELENIUM MEDICAL ",
            "RSOrgEng": "SELENIUM MEDICAL ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SELLSY ",
            "RSOrgEng": "SELLSY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "SEMAAAS AUTOCARS ET AUTOBUS AUNIS SAINTONGE",
            "RSOrgEng": "SEMAAAS AUTOCARS ET AUTOBUS AUNIS SAINTONGE",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "596603.82"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "SEMAAAS AUTOCARS ET AUTOBUS AUNIS SAINTONGE",
            "RSOrgEng": "SEMAAAS AUTOCARS ET AUTOBUS AUNIS SAINTONGE",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "8003.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "SEMAAAS AUTOCARS ET AUTOBUS AUNIS SAINTONGE",
            "RSOrgEng": "SEMAAAS AUTOCARS ET AUTOBUS AUNIS SAINTONGE",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "84807.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SEMER LE DOUTE ",
            "RSOrgEng": "SEMER LE DOUTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SEMER LE DOUTE ",
            "RSOrgEng": "SEMER LE DOUTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "67400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SEMER LE DOUTE ",
            "RSOrgEng": "SEMER LE DOUTE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "78000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SEM H\u00c9LIOPARC PAU PYR\u00c9N\u00c9ES ",
            "RSOrgEng": "SEM H\u00c9LIOPARC PAU PYR\u00c9N\u00c9ES ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "18000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-26",
            "NatEng": "Subvention",
            "NomOrgEng": "SEM H\u00c9LIOPARC PAU PYR\u00c9N\u00c9ES ",
            "RSOrgEng": "SEM H\u00c9LIOPARC PAU PYR\u00c9N\u00c9ES ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SEM H\u00c9LIOPARC PAU PYR\u00c9N\u00c9ES ",
            "RSOrgEng": "SEM H\u00c9LIOPARC PAU PYR\u00c9N\u00c9ES ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "42000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "SEM H\u00c9LIOPARC PAU PYR\u00c9N\u00c9ES ",
            "RSOrgEng": "SEM H\u00c9LIOPARC PAU PYR\u00c9N\u00c9ES ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SEMITOUR PERIGORD ",
            "RSOrgEng": "SEMITOUR PERIGORD ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "56250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SEMITOUR PERIGORD ",
            "RSOrgEng": "SEMITOUR PERIGORD ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-04-23",
            "NatEng": "Subvention",
            "NomOrgEng": "SEML ROUTE DES LASERS ",
            "RSOrgEng": "SEML ROUTE DES LASERS ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "3220.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SEML ROUTE DES LASERS ",
            "RSOrgEng": "SEML ROUTE DES LASERS ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "100543.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SEML ROUTE DES LASERS ",
            "RSOrgEng": "SEML ROUTE DES LASERS ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "19862.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "S.E. NEGOCE ",
            "RSOrgEng": "S.E. NEGOCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "3360.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "S.E. NEGOCE ",
            "RSOrgEng": "S.E. NEGOCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "72727.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SEOLIS ",
            "RSOrgEng": "SEOLIS ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 directoire",
            "MtOrgEng": "162175.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "SEPANLOG RESERVE NATURELLE DE LA MAZIERE",
            "RSOrgEng": "SEPANLOG RESERVE NATURELLE DE LA MAZIERE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19344.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SEPANLOG RESERVE NATURELLE DE LA MAZIERE",
            "RSOrgEng": "SEPANLOG RESERVE NATURELLE DE LA MAZIERE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SEPANLOG RESERVE NATURELLE DE LA MAZIERE",
            "RSOrgEng": "SEPANLOG RESERVE NATURELLE DE LA MAZIERE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "29281.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SEPROSYS ",
            "RSOrgEng": "SEPROSYS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "121316.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SERVICE DE MACHINES OUTILLAGE TECHNIQU E 47",
            "RSOrgEng": "SERVICE DE MACHINES OUTILLAGE TECHNIQU E 47",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "59198.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SERVICE DE MACHINES OUTILLAGE TECHNIQU E 47",
            "RSOrgEng": "SERVICE DE MACHINES OUTILLAGE TECHNIQU E 47",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "38381.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "SERVICE DE REMPLACEMENT NOUVELLE AQUITAINE",
            "RSOrgEng": "SERVICE DE REMPLACEMENT NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "19863.59"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SERVICE DE REMPLACEMENT NOUVELLE AQUITAINE",
            "RSOrgEng": "SERVICE DE REMPLACEMENT NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "34680.88"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SERVICE DE REMPLACEMENT NOUVELLE AQUITAINE",
            "RSOrgEng": "SERVICE DE REMPLACEMENT NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "SERVICES TERTIAIRES AUX ENTREPRISES DE S PYRENEES - STEP - C",
            "RSOrgEng": "SERVICES TERTIAIRES AUX ENTREPRISES DE S PYRENEES - STEP - C",
            "NatJurOrgEng": "SA d'attribution \u00e0 conseil d'administration",
            "MtOrgEng": "18083.84"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "SERVICES TERTIAIRES AUX ENTREPRISES DE S PYRENEES - STEP - C",
            "RSOrgEng": "SERVICES TERTIAIRES AUX ENTREPRISES DE S PYRENEES - STEP - C",
            "NatJurOrgEng": "SA d'attribution \u00e0 conseil d'administration",
            "MtOrgEng": "28868.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SERVICES TERTIAIRES AUX ENTREPRISES DE S PYRENEES - STEP - C",
            "RSOrgEng": "SERVICES TERTIAIRES AUX ENTREPRISES DE S PYRENEES - STEP - C",
            "NatJurOrgEng": "SA d'attribution \u00e0 conseil d'administration",
            "MtOrgEng": "42000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "RSOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "121465.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "RSOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "345.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "RSOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "552.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "RSOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "575.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "RSOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6028.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "RSOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10145.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "RSOrgEng": "SEVREUROPE MFR SEVREUROPE BRESSUIRE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "432.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SEW ET LAINE ",
            "RSOrgEng": "SEW ET LAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18153.46"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SEW ET LAINE ",
            "RSOrgEng": "SEW ET LAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5465.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SEW ET LAINE ",
            "RSOrgEng": "SEW ET LAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SEW ET LAINE ",
            "RSOrgEng": "SEW ET LAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "SEW ET LAINE ",
            "RSOrgEng": "SEW ET LAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28536.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SHARK ROBOTICS ",
            "RSOrgEng": "SHARK ROBOTICS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "225000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SHIRO GAMES ",
            "RSOrgEng": "SHIRO GAMES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SILEX ",
            "RSOrgEng": "SILEX ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SILEX ",
            "RSOrgEng": "SILEX ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SILTISS ",
            "RSOrgEng": "SILTISS ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "122231.31"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SIMAIR ",
            "RSOrgEng": "SIMAIR ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "535389.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SISTER PRODUCTIONS ",
            "RSOrgEng": "SISTER PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SISTER PRODUCTIONS ",
            "RSOrgEng": "SISTER PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SISTER PRODUCTIONS ",
            "RSOrgEng": "SISTER PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "2000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SISTER PRODUCTIONS ",
            "RSOrgEng": "SISTER PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "9000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SISTER PRODUCTIONS ",
            "RSOrgEng": "SISTER PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "51250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SISTER PRODUCTIONS ",
            "RSOrgEng": "SISTER PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SISTER PRODUCTIONS ",
            "RSOrgEng": "SISTER PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "30800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SISTER PRODUCTIONS ",
            "RSOrgEng": "SISTER PRODUCTIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "15400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SITE DE BEYNAC -MFR PERIGORD LIMOUSIN ",
            "RSOrgEng": "SITE DE BEYNAC -MFR PERIGORD LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "209833.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-05-28",
            "NatEng": "Subvention",
            "NomOrgEng": "SITE DE CUSSAC - MFR PERIGORD LIMOUSIN ",
            "RSOrgEng": "SITE DE CUSSAC - MFR PERIGORD LIMOUSIN ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "118913.45"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SNAPP ",
            "RSOrgEng": "SNAPP ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "82508.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2010-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "SNCF VOYAGEURS SA ",
            "RSOrgEng": "SNCF VOYAGEURS SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "0.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SNCF VOYAGEURS SA ",
            "RSOrgEng": "SNCF VOYAGEURS SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "1287852.73"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SNCF VOYAGEURS SA ",
            "RSOrgEng": "SNCF VOYAGEURS SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "5165935.65"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-12-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SNCF VOYAGEURS SA ",
            "RSOrgEng": "SNCF VOYAGEURS SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "13266454.54"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SOC COOP\u00c9RATIVE ELEVEURS MARCHE ",
            "RSOrgEng": "SOC COOP\u00c9RATIVE ELEVEURS MARCHE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 coop\u00e9rative agricole",
            "MtOrgEng": "327338.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SOC ETUDES EQUIP MODERNISATION INDUSTR IE",
            "RSOrgEng": "SOC ETUDES EQUIP MODERNISATION INDUSTR IE",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng":
0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE DES DISTILLERIES VINICOLES DU BLAYAIS",
            "RSOrgEng": "SOCIETE DES DISTILLERIES VINICOLES DU BLAYAIS",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "273398.41"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-30",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCI\u00c9T\u00c9 DES EAUX MIN\u00c9RALES D'ARCACHON ",
            "RSOrgEng": "SOCI\u00c9T\u00c9 DES EAUX MIN\u00c9RALES D'ARCACHON ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "330000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE D EXPLOITATION DES ABATTOIRS D E LA VALEYNIE",
            "RSOrgEng": "SOCIETE D EXPLOITATION DES ABATTOIRS D E LA VALEYNIE",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 directoire",
            "MtOrgEng": "144239.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE ETUDE REALISATION NUMERIQUE ",
            "RSOrgEng": "SOCIETE ETUDE REALISATION NUMERIQUE ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "37947.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE ETUDE REALISATION NUMERIQUE ",
            "RSOrgEng": "SOCIETE ETUDE REALISATION NUMERIQUE ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "45650.91"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE GARAZI ",
            "RSOrgEng": "SOCIETE GARAZI ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "76326.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE LAMECOL ",
            "RSOrgEng": "SOCIETE LAMECOL ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "78231.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE NOUVELLE DES ETABLISSEMENTS JE AN MAZIERE",
            "RSOrgEng": "SOCIETE NOUVELLE DES ETABLISSEMENTS JE AN MAZIERE",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "136903.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE NOUVELLE DES ETABLISSEMENTS JE AN MAZIERE",
            "RSOrgEng": "SOCIETE NOUVELLE DES ETABLISSEMENTS JE AN MAZIERE",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "23500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-26",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCI\u00c9T\u00c9 NOUVELLE MEGISSERIE COLOMBIER ",
            "RSOrgEng": "SOCI\u00c9T\u00c9 NOUVELLE MEGISSERIE COLOMBIER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "36305.25"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCI\u00c9T\u00c9 NOUVELLE MEGISSERIE COLOMBIER ",
            "RSOrgEng": "SOCI\u00c9T\u00c9 NOUVELLE MEGISSERIE COLOMBIER ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "41938.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE ROMOEUF ",
            "RSOrgEng": "SOCIETE ROMOEUF ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "98215.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2014-10-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE SEGUIN MOREAU ET COMPAGNIE ",
            "RSOrgEng": "SOCIETE SEGUIN MOREAU ET COMPAGNIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "22814.21"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE SEGUIN MOREAU ET COMPAGNIE ",
            "RSOrgEng": "SOCIETE SEGUIN MOREAU ET COMPAGNIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "42479.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE SEGUIN MOREAU ET COMPAGNIE ",
            "RSOrgEng": "SOCIETE SEGUIN MOREAU ET COMPAGNIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "31648.68"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-06-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCIETE VALMY DEFENSE 41 ",
            "RSOrgEng": "SOCIETE VALMY DEFENSE 41 ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "166878.31"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SOC INDUST LIMOUSIN APPLICAT BIOLOGIQ ",
            "RSOrgEng": "SOC INDUST LIMOUSIN APPLICAT BIOLOGIQ ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "19155.95"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "SOC INDUST LIMOUSIN APPLICAT BIOLOGIQ ",
            "RSOrgEng": "SOC INDUST LIMOUSIN APPLICAT BIOLOGIQ ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "527455.57"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SO COOPERATION ",
            "RSOrgEng": "SO COOPERATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SO COOPERATION ",
            "RSOrgEng": "SO COOPERATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SO COOPERATION ",
            "RSOrgEng": "SO COOPERATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "4500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SO COOPERATION ",
            "RSOrgEng": "SO COOPERATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SO COOPERATION ",
            "RSOrgEng": "SO COOPERATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5625.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SO COOPERATION ",
            "RSOrgEng": "SO COOPERATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "SO COOPERATION ",
            "RSOrgEng": "SO COOPERATION ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "42000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "SOC PUB LOCALE DE BRIVE ET AGGLO ",
            "RSOrgEng": "SOC PUB LOCALE DE BRIVE ET AGGLO ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "329321.16"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SOCRATE CONSEILS & FORMATIONS ",
            "RSOrgEng": "SOCRATE CONSEILS & FORMATIONS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "82345.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SODIUM CYCLES ",
            "RSOrgEng": "SODIUM CYCLES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "39000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SODIUM CYCLES ",
            "RSOrgEng": "SODIUM CYCLES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "85000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "SOGELEASE FRANCE ",
            "RSOrgEng": "SOGELEASE FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "16400.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "SOGELEASE FRANCE ",
            "RSOrgEng": "SOGELEASE FRANCE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "147600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SO HAM SUD-OUEST ",
            "RSOrgEng": "SO HAM SUD-OUEST ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "842679.48"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SOIREES LYRIQUES DE SANXAY ",
            "RSOrgEng": "SOIREES LYRIQUES DE SANXAY ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "30300.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SOIREES LYRIQUES DE SANXAY ",
            "RSOrgEng": "SOIREES LYRIQUES DE SANXAY ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "70700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SOLICIS ",
            "RSOrgEng": "SOLICIS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "60452.98"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SOLICIS ",
            "RSOrgEng": "SOLICIS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "104366.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SOLOGEMIN - SOC LOT ET GARONNAISE D EX PLOITATION DU MARCHE DINTERET NATIONAL",
            "RSOrgEng": "SOLOGEMIN - SOC LOT ET GARONNAISE D EX PLOITATION DU MARCHE DINTERET NATIONAL",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "47100.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SOLOGEMIN - SOC LOT ET GARONNAISE D EX PLOITATION DU MARCHE DINTERET NATIONAL",
            "RSOrgEng": "SOLOGEMIN - SOC LOT ET GARONNAISE D EX PLOITATION DU MARCHE DINTERET NATIONAL",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "57016.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SOLUTIONS POUR LA TRANSITION ECOLOGIQU E EN NOUVELLE AQUITAINE",
            "RSOrgEng": "SOLUTIONS POUR LA TRANSITION ECOLOGIQU E EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5995.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SOLUTIONS POUR LA TRANSITION ECOLOGIQU E EN NOUVELLE AQUITAINE",
            "RSOrgEng": "SOLUTIONS POUR LA TRANSITION ECOLOGIQU E EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "131910.29"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SOLUTIONS POUR LA TRANSITION ECOLOGIQU E EN NOUVELLE AQUITAINE",
            "RSOrgEng": "SOLUTIONS POUR LA TRANSITION ECOLOGIQU E EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "144258.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SOLUTIONS POUR LA TRANSITION ECOLOGIQU E EN NOUVELLE AQUITAINE",
            "RSOrgEng": "SOLUTIONS POUR LA TRANSITION ECOLOGIQU E EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "96700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-05-29",
            "NatEng": "Subvention",
            "NomOrgEng": "SOMAFER ",
            "RSOrgEng": "SOMAFER ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "10965.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SOMAFER ",
            "RSOrgEng": "SOMAFER ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "274157.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SOMAFER ",
            "RSOrgEng": "SOMAFER ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "7793.47"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "SORTILEGES PRODUCTIONS ",
            "RSOrgEng": "SORTILEGES PRODUCTIONS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "105000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SOYAUX ANGOULEME XV CHARENTE ",
            "RSOrgEng": "SOYAUX ANGOULEME XV CHARENTE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SOYAUX ANGOULEME XV CHARENTE ",
            "RSOrgEng": "SOYAUX ANGOULEME XV CHARENTE ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SPN RESEAU DES PROFESSIONNELS DU NUMERIQUE EN P C",
            "RSOrgEng": "SPN RESEAU DES PROFESSIONNELS DU NUMERIQUE EN P C",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14562.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SPN RESEAU DES PROFESSIONNELS DU NUMERIQUE EN P C",
            "RSOrgEng": "SPN RESEAU DES PROFESSIONNELS DU NUMERIQUE EN P C",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "86000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SPN RESEAU DES PROFESSIONNELS DU NUMERIQUE EN P C",
            "RSOrgEng": "SPN RESEAU DES PROFESSIONNELS DU NUMERIQUE EN P C",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14562.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SPN RESEAU DES PROFESSIONNELS DU NUMERIQUE EN P C",
            "RSOrgEng": "SPN RESEAU DES PROFESSIONNELS DU NUMERIQUE EN P C",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "131290.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SPORTING UNION AGENAIS - RUG BY ASSOCIATION",
            "RSOrgEng": "SPORTING UNION AGENAIS - RUG BY ASSOCIATION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "39000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SPORTING UNION AGENAIS - RUG BY ASSOCIATION",
            "RSOrgEng": "SPORTING UNION AGENAIS - RUG BY ASSOCIATION",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "91000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE BORDELAIS ",
            "RSOrgEng": "STADE BORDELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE BORDELAIS ",
            "RSOrgEng": "STADE BORDELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24601.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE BORDELAIS ",
            "RSOrgEng": "STADE BORDELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2675.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE BORDELAIS ",
            "RSOrgEng": "STADE BORDELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE BORDELAIS ",
            "RSOrgEng": "STADE BORDELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "41000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE BORDELAIS ",
            "RSOrgEng": "STADE BORDELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE BORDELAIS ",
            "RSOrgEng": "STADE BORDELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "21000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE BORDELAIS ",
            "RSOrgEng": "STADE BORDELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6745.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE MONTOIS OMNISPORTS SECTION RUGBY ",
            "RSOrgEng": "STADE MONTOIS OMNISPORTS SECTION RUGBY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE MONTOIS OMNISPORTS SECTION RUGBY ",
            "RSOrgEng": "STADE MONTOIS OMNISPORTS SECTION RUGBY ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE ROCHELAIS ",
            "RSOrgEng": "STADE ROCHELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE ROCHELAIS ",
            "RSOrgEng": "STADE ROCHELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "178000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "STADE ROCHELAIS ",
            "RSOrgEng": "STADE ROCHELAIS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "7000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "STAR LEASE ",
            "RSOrgEng": "STAR LEASE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "16600.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "STAR LEASE ",
            "RSOrgEng": "STAR LEASE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "149400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "STEICO CASTELJALOUX ",
            "RSOrgEng": "STEICO CASTELJALOUX ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "118712.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "STE INDUSTRIELLE DE MECANIQUE ",
            "RSOrgEng": "STE INDUSTRIELLE DE MECANIQUE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "85656.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "STELIA AEROSPACE COMPOSITES ",
            "RSOrgEng": "STELIA AEROSPACE COMPOSITES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "STE TRAVAUX ACROBATIQUES MOMTAGNARDS ",
            "RSOrgEng": "STE TRAVAUX ACROBATIQUES MOMTAGNARDS ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "159647.46"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-11-21",
            "NatEng": "Subvention",
            "NomOrgEng": "STIVENT INDUSTRIE ",
            "RSOrgEng": "STIVENT INDUSTRIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "STIVENT INDUSTRIE ",
            "RSOrgEng": "STIVENT INDUSTRIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "137408.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "STRADA ",
            "RSOrgEng": "STRADA ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "128322.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "STUDIO NYX ",
            "RSOrgEng": "STUDIO NYX ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "48484.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "STUDIO NYX ",
            "RSOrgEng": "STUDIO NYX ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "11356.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "STUDIO NYX ",
            "RSOrgEng": "STUDIO NYX ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "69492.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SUD OUEST ETALAGES ",
            "RSOrgEng": "SUD OUEST ETALAGES ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "149417.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "SUD OUEST SERVICE'S ",
            "RSOrgEng": "SUD OUEST SERVICE'S ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "100905.93"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "SUEZ ORGANIQUE ",
            "RSOrgEng": "SUEZ ORGANIQUE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "1254057.17"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFILM PACKAGING ",
            "RSOrgEng": "SURFILM PACKAGING ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "3115.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFILM PACKAGING ",
            "RSOrgEng": "SURFILM PACKAGING ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "94328.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "RSOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "RSOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "RSOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "RSOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "RSOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "24800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "RSOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "5600.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "RSOrgEng": "SURFRIDER FOUNDATION EUROPE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60715.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "SUR LE PONT - CENTRE NATIONAL DES ARTS DE LA RUE ET DE L ESPACE PUBLIC EN NO",
            "RSOrgEng": "SUR LE PONT - CENTRE NATIONAL DES ARTS DE LA RUE ET DE L ESPACE PUBLIC EN NO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "60000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SUR LE PONT - CENTRE NATIONAL DES ARTS DE LA RUE ET DE L ESPACE PUBLIC EN NO",
            "RSOrgEng": "SUR LE PONT - CENTRE NATIONAL DES ARTS DE LA RUE ET DE L ESPACE PUBLIC EN NO",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "140000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "SYADEM ",
            "RSOrgEng": "SYADEM ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "141577.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "SYNAPSE MEDICINE ",
            "RSOrgEng": "SYNAPSE MEDICINE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "92178.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SYND DEFENSE AOC POMMES LIMOUSIN ",
            "RSOrgEng": "SYND DEFENSE AOC POMMES LIMOUSIN ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "77025.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "SYNERGY ",
            "RSOrgEng": "SYNERGY ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "115942.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "SYSTEM ASSISTANCE MEDICALE SYST'AM",
            "RSOrgEng": "SYSTEM ASSISTANCE MEDICALE SYST'AM",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "SYSTEMES ET TELECOMMUNICATIONS SA ",
            "RSOrgEng": "SYSTEMES ET TELECOMMUNICATIONS SA ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "330000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "TAMAPLACE ",
            "RSOrgEng": "TAMAPLACE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "17304.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "TAMAPLACE ",
            "RSOrgEng": "TAMAPLACE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "221728.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "TAPIERO EXPLOITATION ",
            "RSOrgEng": "TAPIERO EXPLOITATION ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "138495.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "TAULOU ",
            "RSOrgEng": "TAULOU ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "88729.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "TAUZIET & CO ",
            "RSOrgEng": "TAUZIET & CO ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "140253.66"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNI PREFA ",
            "RSOrgEng": "TECHNI PREFA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "103143.81"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-09-25",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNIQUE BIOGAZ ",
            "RSOrgEng": "TECHNIQUE BIOGAZ ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "6977.27"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNIQUE BIOGAZ ",
            "RSOrgEng": "TECHNIQUE BIOGAZ ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "35934.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-02-22",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNIQUE BIOGAZ ",
            "RSOrgEng": "TECHNIQUE BIOGAZ ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "40807.3"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNOPOLE EUREKATECH ",
            "RSOrgEng": "TECHNOPOLE EUREKATECH ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2176.26"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNOPOLE EUREKATECH ",
            "RSOrgEng": "TECHNOPOLE EUREKATECH ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "91000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "RSOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "31500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "RSOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "9334.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "RSOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "75031.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "RSOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "11664.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "RSOrgEng": "TECHNOPOLE GRAND POITIERS ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "217000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "TEKNIAERO ",
            "RSOrgEng": "TEKNIAERO ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "TELERAD ",
            "RSOrgEng": "TELERAD ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "86742.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "TELERAD ",
            "RSOrgEng": "TELERAD ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "27600.15"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "TELERAD ",
            "RSOrgEng": "TELERAD ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "40000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "TENSYL ",
            "RSOrgEng": "TENSYL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "81864.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "TERREAL ",
            "RSOrgEng": "TERREAL ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "800623.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "RSOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "RSOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "333568.55"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "RSOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "RSOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "630000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "RSOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "52500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "RSOrgEng": "THEATRE AUDITORIUM POITIERS SCENE NATIONALE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "31966.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE DE L UNION CTRE DRAMAT LIMOUS ",
            "RSOrgEng": "THEATRE DE L UNION CTRE DRAMAT LIMOUS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "288633.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE DE L UNION CTRE DRAMAT LIMOUS ",
            "RSOrgEng": "THEATRE DE L UNION CTRE DRAMAT LIMOUS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "201600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE ECOLE D AQUITAINE ATREE ",
            "RSOrgEng": "THEATRE ECOLE D AQUITAINE ATREE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "47620.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "THEATRE ECOLE D AQUITAINE ATREE ",
            "RSOrgEng": "THEATRE ECOLE D AQUITAINE ATREE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "TH\u00c9\u00c2TRE NATIONAL DE BORDEAUX EN AQUITA INE",
            "RSOrgEng": "TH\u00c9\u00c2TRE NATIONAL DE BORDEAUX EN AQUITA INE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "127500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "TH\u00c9\u00c2TRE NATIONAL DE BORDEAUX EN AQUITA INE",
            "RSOrgEng": "TH\u00c9\u00c2TRE NATIONAL DE BORDEAUX EN AQUITA INE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "27683.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "TH\u00c9\u00c2TRE NATIONAL DE BORDEAUX EN AQUITA INE",
            "RSOrgEng": "TH\u00c9\u00c2TRE NATIONAL DE BORDEAUX EN AQUITA INE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "297500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "THS BACHE GABRIELSEN ",
            "RSOrgEng": "THS BACHE GABRIELSEN ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "THURET VOYAGES ",
            "RSOrgEng": "THURET VOYAGES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "71806.65"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "THURET VOYAGES ",
            "RSOrgEng": "THURET VOYAGES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "32603.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "TISSOT INDUSTRIE ",
            "RSOrgEng": "TISSOT INDUSTRIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "88460.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "TISSOT INDUSTRIE ",
            "RSOrgEng": "TISSOT INDUSTRIE ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "12660.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "TONNELLERIE DOREAU ",
            "RSOrgEng": "TONNELLERIE DOREAU ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "90449.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "TOUCH SENSITY ",
            "RSOrgEng": "TOUCH SENSITY ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-10-22",
            "NatEng": "Subvention",
            "NomOrgEng": "TOUR DU LIMOUSIN ORGANISATION ",
            "RSOrgEng": "TOUR DU LIMOUSIN ORGANISATION ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "13080.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "TOUR DU LIMOUSIN ORGANISATION ",
            "RSOrgEng": "TOUR DU LIMOUSIN ORGANISATION ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "TOUR DU LIMOUSIN ORGANISATION ",
            "RSOrgEng": "TOUR DU LIMOUSIN ORGANISATION ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "155000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "TRAIMECA PYRO ",
            "RSOrgEng": "TRAIMECA PYRO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "78271.2"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2016-10-10",
            "NatEng": "Subvention",
            "NomOrgEng": "TRAITEMENT COMPOSITES POUDRES PROCESS ",
            "RSOrgEng": "TRAITEMENT COMPOSITES POUDRES PROCESS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "58358.7"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-04-03",
            "NatEng": "Subvention",
            "NomOrgEng": "TRAITEMENT COMPOSITES POUDRES PROCESS ",
            "RSOrgEng": "TRAITEMENT COMPOSITES POUDRES PROCESS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "79759.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "TRAITEMENT COMPOSITES POUDRES PROCESS ",
            "RSOrgEng": "TRAITEMENT COMPOSITES POUDRES PROCESS ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "100043.49"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "TRANSDEV POITOU-CHARENTES CITRAM CHARENTE",
            "RSOrgEng": "TRANSDEV POITOU-CHARENTES CITRAM CHARENTE",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "248534.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "TRANSDEV POITOU-CHARENTES CITRAM CHARENTE",
            "RSOrgEng": "TRANSDEV POITOU-CHARENTES CITRAM CHARENTE",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "30811.74"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "TRANSDEV POITOU-CHARENTES CITRAM CHARENTE",
            "RSOrgEng": "TRANSDEV POITOU-CHARENTES CITRAM CHARENTE",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "140899.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "TRANS-LANDES ",
            "RSOrgEng": "TRANS-LANDES ",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "13505.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "TRANS-LANDES ",
            "RSOrgEng": "TRANS-LANDES ",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "298776.41"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "TRANS-LANDES ",
            "RSOrgEng": "TRANS-LANDES ",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "248248.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "TRANS-LANDES ",
            "RSOrgEng": "TRANS-LANDES ",
            "NatJurOrgEng": "Autre personne morale de droit priv\u00e9",
            "MtOrgEng": "109588.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-29",
            "NatEng": "Subvention",
            "NomOrgEng": "TRANSPOD FRANCE ",
            "RSOrgEng": "TRANSPOD FRANCE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "400000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "TRAN
.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "RSOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "RSOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "13580.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "RSOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2100.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-06-15",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "RSOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "RSOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "61500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "RSOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "RSOrgEng": "UNION REGIONALE POUR L HABITAT DES JEU NES EN NOUVELLE AQUITAINE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE SOLIHA NOUVELLE AQUITA INE",
            "RSOrgEng": "UNION REGIONALE SOLIHA NOUVELLE AQUITA INE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE SOLIHA NOUVELLE AQUITA INE",
            "RSOrgEng": "UNION REGIONALE SOLIHA NOUVELLE AQUITA INE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "102000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE SOLIHA NOUVELLE AQUITA INE",
            "RSOrgEng": "UNION REGIONALE SOLIHA NOUVELLE AQUITA INE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "8880.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGIONALE SOLIHA NOUVELLE AQUITA INE",
            "RSOrgEng": "UNION REGIONALE SOLIHA NOUVELLE AQUITA INE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGION FOYERS RURAUX POITOU CHARENTES",
            "RSOrgEng": "UNION REGION FOYERS RURAUX POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGION FOYERS RURAUX POITOU CHARENTES",
            "RSOrgEng": "UNION REGION FOYERS RURAUX POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "30000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION REGION FOYERS RURAUX POITOU CHARENTES",
            "RSOrgEng": "UNION REGION FOYERS RURAUX POITOU CHARENTES",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "72800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "RSOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "RSOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "17500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "RSOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "2500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "RSOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3446.14"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "RSOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "35700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "RSOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "RSOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "14000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-12-18",
            "NatEng": "Subvention",
            "NomOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "RSOrgEng": "UNION R\u00c9G NOUVELLE-AQUITAINE F\u00c9DER CTR ES SOCIO CULTUREL",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "25600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "UNITEC ",
            "RSOrgEng": "UNITEC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "111670.21"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "UNITEC ",
            "RSOrgEng": "UNITEC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "18000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-09",
            "NatEng": "Subvention",
            "NomOrgEng": "UNITEC ",
            "RSOrgEng": "UNITEC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "520000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "UNITEC ",
            "RSOrgEng": "UNITEC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "985500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-20",
            "NatEng": "Subvention",
            "NomOrgEng": "UNITEC ",
            "RSOrgEng": "UNITEC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "325000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "UNITEC ",
            "RSOrgEng": "UNITEC ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "197984.72"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "UPCP METIVE MAISON DES CULTURES DE PAYS",
            "RSOrgEng": "UPCP METIVE MAISON DES CULTURES DE PAYS",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "55800.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "UPCP METIVE MAISON DES CULTURES DE PAYS",
            "RSOrgEng": "UPCP METIVE MAISON DES CULTURES DE PAYS",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "UPCP METIVE MAISON DES CULTURES DE PAYS",
            "RSOrgEng": "UPCP METIVE MAISON DES CULTURES DE PAYS",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "130200.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "UPRODUCTION ",
            "RSOrgEng": "UPRODUCTION ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "UPRODUCTION ",
            "RSOrgEng": "UPRODUCTION ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "6750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "UPRODUCTION ",
            "RSOrgEng": "UPRODUCTION ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "18000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "UPRODUCTION ",
            "RSOrgEng": "UPRODUCTION ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "11250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-05-24",
            "NatEng": "Subvention",
            "NomOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "RSOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "RSOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "12000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "RSOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "3077.9"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "RSOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "28000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-30",
            "NatEng": "Subvention",
            "NomOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "RSOrgEng": "U.R.C.A.U.E NOUVELLE-AQUITAINE ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "158846.34"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "USINE VEGETALE 209 ",
            "RSOrgEng": "USINE VEGETALE 209 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "32000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "USINE VEGETALE 209 ",
            "RSOrgEng": "USINE VEGETALE 209 ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "54635.85"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "VALBIOTIS ",
            "RSOrgEng": "VALBIOTIS ",
            "NatJurOrgEng": "SA \u00e0 directoire (s.a.i.)",
            "MtOrgEng": "161059.8"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2015-11-26",
            "NatEng": "Subvention",
            "NomOrgEng": "VARLIN PONT NEUF ",
            "RSOrgEng": "VARLIN PONT NEUF ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "19850.02"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-07-10",
            "NatEng": "Subvention",
            "NomOrgEng": "VARLIN PONT NEUF ",
            "RSOrgEng": "VARLIN PONT NEUF ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "36381.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-04-01",
            "NatEng": "Subvention",
            "NomOrgEng": "VARLIN PONT NEUF ",
            "RSOrgEng": "VARLIN PONT NEUF ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "11595.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "VARLIN PONT NEUF ",
            "RSOrgEng": "VARLIN PONT NEUF ",
            "NatJurOrgEng": "ASSOCIATION (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "15000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "VDLV ",
            "RSOrgEng": "VDLV ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "150000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "VERMANDE ",
            "RSOrgEng": "VERMANDE ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "92056.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-10-08",
            "NatEng": "Subvention",
            "NomOrgEng": "VERTICAL PRODUCTION ",
            "RSOrgEng": "VERTICAL PRODUCTION ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "21000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "VERTICAL PRODUCTION ",
            "RSOrgEng": "VERTICAL PRODUCTION ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "17500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "VERTICAL PRODUCTION ",
            "RSOrgEng": "VERTICAL PRODUCTION ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "43500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "VERTICAL PRODUCTION ",
            "RSOrgEng": "VERTICAL PRODUCTION ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "26250.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "VERTICAL PRODUCTION ",
            "RSOrgEng": "VERTICAL PRODUCTION ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "28700.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "VERTICAL PRODUCTION ",
            "RSOrgEng": "VERTICAL PRODUCTION ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "12600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "VERTIGE INTERNATIONAL ",
            "RSOrgEng": "VERTIGE INTERNATIONAL ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "192014.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "VILLESSOT ",
            "RSOrgEng": "VILLESSOT ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "102457.79"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "VILLESSOT ",
            "RSOrgEng": "VILLESSOT ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "6761.74"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "VILLESSOT ",
            "RSOrgEng": "VILLESSOT ",
            "NatJurOrgEng": "SOCIETE (PERS. MORALE /DROIT PRIVE)",
            "MtOrgEng": "44069.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "VINEXPO BORDEAUX ",
            "RSOrgEng": "VINEXPO BORDEAUX ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "75000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-11-17",
            "NatEng": "Subvention",
            "NomOrgEng": "VIRTUALYS ",
            "RSOrgEng": "VIRTUALYS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "59712.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "VIRTUALYS ",
            "RSOrgEng": "VIRTUALYS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "96484.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "VITIROVER ",
            "RSOrgEng": "VITIROVER ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "125711.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "VOLTAERO ",
            "RSOrgEng": "VOLTAERO ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "238122.34"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES GOUJEAU ",
            "RSOrgEng": "VOYAGES GOUJEAU ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "370133.15"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES GOUJEAU ",
            "RSOrgEng": "VOYAGES GOUJEAU ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "5405.5"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES GOUJEAU ",
            "RSOrgEng": "VOYAGES GOUJEAU ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "86140.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES LAULHE ",
            "RSOrgEng": "VOYAGES LAULHE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "64208.58"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES LAULHE ",
            "RSOrgEng": "VOYAGES LAULHE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "2704.49"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES LAULHE ",
            "RSOrgEng": "VOYAGES LAULHE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "10961.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES LIMOUSIN PERIGORD OSICARS",
            "RSOrgEng": "VOYAGES LIMOUSIN PERIGORD OSICARS",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "48207.4"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES LIMOUSIN PERIGORD OSICARS",
            "RSOrgEng": "VOYAGES LIMOUSIN PERIGORD OSICARS",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "43940.11"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES LIMOUSIN PERIGORD OSICARS",
            "RSOrgEng": "VOYAGES LIMOUSIN PERIGORD OSICARS",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "39191.1"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES TOUYAROT ",
            "RSOrgEng": "VOYAGES TOUYAROT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "16925.89"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES TOUYAROT ",
            "RSOrgEng": "VOYAGES TOUYAROT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "51192.38"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "VOYAGES TOUYAROT ",
            "RSOrgEng": "VOYAGES TOUYAROT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "12005.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "VRAIVRAI FILMS ",
            "RSOrgEng": "VRAIVRAI FILMS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "7500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-11-16",
            "NatEng": "Subvention",
            "NomOrgEng": "VRAIVRAI FILMS ",
            "RSOrgEng": "VRAIVRAI FILMS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "6750.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "VRAIVRAI FILMS ",
            "RSOrgEng": "VRAIVRAI FILMS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "10500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "VRAIVRAI FILMS ",
            "RSOrgEng": "VRAIVRAI FILMS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "37500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "VRAIVRAI FILMS ",
            "RSOrgEng": "VRAIVRAI FILMS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "19000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "VRAIVRAI FILMS ",
            "RSOrgEng": "VRAIVRAI FILMS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "15400.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-07-17",
            "NatEng": "Subvention",
            "NomOrgEng": "VRAIVRAI FILMS ",
            "RSOrgEng": "VRAIVRAI FILMS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "17500.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "VRAIVRAI FILMS ",
            "RSOrgEng": "VRAIVRAI FILMS ",
            "NatJurOrgEng": "SARL unipersonnelle",
            "MtOrgEng": "12600.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2017-03-13",
            "NatEng": "Subvention",
            "NomOrgEng": "VRIET AUTOCARS ",
            "RSOrgEng": "VRIET AUTOCARS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "59271.69"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-02-05",
            "NatEng": "Subvention",
            "NomOrgEng": "VRIET AUTOCARS ",
            "RSOrgEng": "VRIET AUTOCARS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "10819.41"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-11-23",
            "NatEng": "Subvention",
            "NomOrgEng": "VRIET AUTOCARS ",
            "RSOrgEng": "VRIET AUTOCARS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e (sans autre indication)",
            "MtOrgEng": "25387.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-16",
            "NatEng": "Subvention",
            "NomOrgEng": "WAVE BUMPER ",
            "RSOrgEng": "WAVE BUMPER ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "160000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-06-17",
            "NatEng": "Subvention",
            "NomOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "RSOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "50000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "RSOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "22000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-01-30",
            "NatEng": "Subvention",
            "NomOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "RSOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "45114.96"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-04-06",
            "NatEng": "Subvention",
            "NomOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "RSOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "13395.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-05-15",
            "NatEng": "Subvention",
            "NomOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "RSOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "6000.0"
        },
        {
            "CodNatEng": "04",
            "NatEng": "Subvention",
            "NomOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "RSOrgEng": "WEB ASSOCIATION BERGERAC WAB",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration",
            "MtOrgEng": "35553.94"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-10-07",
            "NatEng": "Subvention",
            "NomOrgEng": "WORLDCAST SYSTEMS ",
            "RSOrgEng": "WORLDCAST SYSTEMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "97319.89"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-02-10",
            "NatEng": "Subvention",
            "NomOrgEng": "WORLDCAST SYSTEMS ",
            "RSOrgEng": "WORLDCAST SYSTEMS ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "102369.6"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2018-07-09",
            "NatEng": "Subvention",
            "NomOrgEng": "XILAM ANIMATION ",
            "RSOrgEng": "XILAM ANIMATION ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "90000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-02-15",
            "NatEng": "Subvention",
            "NomOrgEng": "XILAM ANIMATION ",
            "RSOrgEng": "XILAM ANIMATION ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "20000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-03-09",
            "NatEng": "Subvention",
            "NomOrgEng": "XILAM ANIMATION ",
            "RSOrgEng": "XILAM ANIMATION ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "70000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-07-08",
            "NatEng": "Subvention",
            "NomOrgEng": "YNOVEA ",
            "RSOrgEng": "YNOVEA ",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "102370.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2020-10-19",
            "NatEng": "Subvention",
            "NomOrgEng": "YSOPIA BIOSCIENCES ",
            "RSOrgEng": "YSOPIA BIOSCIENCES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration (s.a.i.)",
            "MtOrgEng": "400000.0"
        },
        {
            "CodNatEng": "04",
            "DtEng": "2019-11-18",
            "NatEng": "Subvention",
            "NomOrgEng": "ZE ENERGIES VIENNE ",
            "RSOrgEng": "ZE ENERGIES VIENNE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "132250.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib\u00e9ration n\u00b0 2006-2248 du 16/01/2006",
            "NomOrgEng": "A'LIENOR",
            "RSOrgEng": "A'LIENOR",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par action simplifi\u00e9e",
            "MtOrgEng": "121320000"
        },
        {
            "CodNatEng": "01",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2015.868.CP du 01/06/2015",
            "NomOrgEng": "SOCIETE KEOLIS GASCOGNE",
            "RSOrgEng": "SOCIETE KEOLIS GASCOGNE",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "4329534.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2015.868.CP du 01/06/2015",
            "NomOrgEng": "SOCIETE CITRAM PYRENEES ",
            "RSOrgEng": "SOCIETE CITRAM PYRENEES ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "3704292.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2015.868.CP du 01/06/2015",
            "NomOrgEng": "SOCIETE AUTOCARS PASCAL",
            "RSOrgEng": "SOCIETE AUTOCARS PASCAL",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "2102054.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "n\u00b0 CP 15/07/0514 du 09/07/2015",
            "NomOrgEng": "CFTA CENTRE-OUEST",
            "RSOrgEng": "CFTA CENTRE-OUEST",
            "NatJurOrgEng": "SASU",
            "MtOrgEng": "3655035.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "n\u00b0 CP 15/07/0514 du 09/07/2015",
            "NomOrgEng": "THURET VOYAGES",
            "RSOrgEng": "THURET VOYAGES",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "1629751.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "n\u00b0 CP 15/07/0514 du 09/07/2015",
            "NomOrgEng": "FAURE CORREZE AUTOCARS",
            "RSOrgEng": "FAURE CORREZE AUTOCARS",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "3422784.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "n\u00b0 CP 15/07/0514 du 09/07/2015",
            "NomOrgEng": "EUROP VOYAGES 23",
            "RSOrgEng": "EUROP VOYAGES 23",
            "NatJurOrgEng": "SARL Unipersonnelle",
            "MtOrgEng": "1974745.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP d\u00e9partementale n\u00b014 du 06/07/2012",
            "NomOrgEng": "CITRAM CHARENTE",
            "RSOrgEng": "CITRAM CHARENTE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "7056543.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP d\u00e9partementale n\u00b014 du 06/07/2012",
            "NomOrgEng": "THORIN-VRIET",
            "RSOrgEng": "THORIN-VRIET",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "2104308.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2018.1054.CP du 28/05/2018",
            "NomOrgEng": "TRANSDEV",
            "RSOrgEng": "TRANDEV",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "25718037"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2018.1054.CP du 28/05/2018",
            "NomOrgEng": "KEOLIS LITTORAL",
            "RSOrgEng": "KEOLIS LITTORAL",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en Nom Collectif",
            "MtOrgEng": "47607495"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2018.1054.CP du 28/05/2028",
            "NomOrgEng": "KEOLIS/AUTOCARS METERERAU",
            "RSOrgEng": "KEOLIS/AUTOCARS METERERAU",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en Nom Collectif",
            "MtOrgEng": "32898249"
        },
        {
            "CodNatEng": "01",
            "NatEng": "d\u00e9lib D\u00e9part CD2015-07/03/16 CD2015-07/0/17 CD2015-05/1/3-15/1/53 ",
            "NomOrgEng": "EUROP VOYAGES 23",
            "RSOrgEng": "EUROP VOYAGES 23",
            "NatJurOrgEng": "SARL Unipersonnelle",
            "MtOrgEng": "7552887.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "d\u00e9lib D\u00e9part CD2015-07/03/16 CD2015-07/0/17 CD2015-05/1/3-15/1/53 ",
            "NomOrgEng": "GAUDON",
            "RSOrgEng": "GAUDON",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "703580.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "d\u00e9lib D\u00e9part CD2015-07/03/16 CD2015-07/0/17 CD2015-05/1/3-15/1/53 ",
            "NomOrgEng": "SARL TRANSPORT ET VOYAGES",
            "RSOrgEng": "SARL TRANSPORT ET VOYAGES",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "845429.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "d\u00e9lib D\u00e9part CD2015-07/03/16 CD2015-07/0/17 CD2015-05/1/3-15/1/53 ",
            "NomOrgEng": "THURET VOYAGES",
            "RSOrgEng": "THURET VOYAGES",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "4632093.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2020.681.CP du 06/04/2020",
            "NomOrgEng": "CFTA CENTRE-OUEST",
            "RSOrgEng": "CFTA CENTRE-OUEST",
            "NatJurOrgEng": "SASU",
            "MtOrgEng": "34787800"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2020.680.CP du 06/04/2020",
            "NomOrgEng": "CITRAM AQUITAINE",
            "RSOrgEng": "CITRAM AQUITAINE",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "212000000"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2020.680.CP du 06/04/2020",
            "NomOrgEng": "GROUPEMENT CITRAM AQUITAINE / PREVOST",
            "RSOrgEng": "PREVOST",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration ",
            "MtOrgEng": "18200000"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2020.680.CP du 06/04/2020",
            "NomOrgEng": "AQUITAINE SERVICES TRANSPORTS GIRONDE",
            "RSOrgEng": "AQUITAINE SERVICES TRANSPORTS GIRONDE",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "21500000"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2020.680.CP du 06/04/2020",
            "NomOrgEng": "LES PULLMANS LANDAIS",
            "RSOrgEng": "LES PULLMANS LANDAIS",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e",
            "MtOrgEng": "20800000"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2020.680.CP du 06/04/2020",
            "NomOrgEng": "KEOLIS GIRONDE",
            "RSOrgEng": "KEOLIS GIRONDE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e",
            "MtOrgEng": "15600000"
        },
        {
            "CodNatEng": "01",
            "NatEng": "2014-230-CP du 14/02/2014",
            "NomOrgEng": "CARTRANS GIRONDE SERVICES",
            "RSOrgEng": "CARTRANS GIRONDE SERVICES",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 \u00e0 responsabilit\u00e9 limit\u00e9e \u00e0 associ\u00e9 unique ",
            "MtOrgEng": "45553.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "C0503 du 04/05/2015",
            "NomOrgEng": "CITRAM AQUITAINE - TIDEO",
            "RSOrgEng": "CITRAM AQUITAINE - TIDEO",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "3509428.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP 2012/06/21-05-001",
            "NomOrgEng": "ATCRB TRANSDEV SO",
            "RSOrgEng": "ATCRB TRANSDEV SO",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "937633.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP n\u00b02013/05/24-05-004",
            "NomOrgEng": "BASQUE BONDISSANT",
            "RSOrgEng": "BASQUE BONDISSANT",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "735302.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP n\u00b02013/05/24-05-005",
            "NomOrgEng": "HIRUAK BAT",
            "RSOrgEng": "HIRUAK BAT",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "731698.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP n\u00b02013/05/24-05-006",
            "NomOrgEng": "AUTOCARS SOULETINS",
            "RSOrgEng": "AUTOCARS SOULETINS",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "752255.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP n\u00b02013/05/24-05-007",
            "NomOrgEng": "AUTOCARS BIDEGAIN",
            "RSOrgEng": "AUTOCARS BIDEGAIN",
            "NatJurOrgEng": "Entreprise en nom propre",
            "MtOrgEng": "577751.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP n\u00b02013/05/24-05-008",
            "NomOrgEng": "TPR",
            "RSOrgEng": "TPR",
            "NatJurOrgEng": "S.A.R.L.",
            "MtOrgEng": "3231360.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP n\u00b02013/05/24-05-009 et 010",
            "NomOrgEng": "SOCIETE CITRAM PYRENEES",
            "RSOrgEng": "SOCIETE CITRAM PYRENEES",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "5201000.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP d\u00e9partementale 2015CP153 du 07/05/2015",
            "NomOrgEng": "TRANSPORTS MARTIN",
            "RSOrgEng": "TRANSPORTS MARTIN",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "2796652.0"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP d\u00e9partementale 2015CP153 du 07/05/2015",
            "NomOrgEng": "RAPIDES DU POITOU",
            "RSOrgEng": "RAPIDES DU POITOU",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "11166803"
        },
        {
            "CodNatEng": "01",
            "NatEng": "CP d\u00e9partementale 2015CP153 du 07/05/2015",
            "NomOrgEng": "TRANSDEV",
            "RSOrgEng": "TRANSDEV",
            "NatJurOrgEng": "SAS, Soci\u00e9t\u00e9 par Actions Simplifi\u00e9e",
            "MtOrgEng": "13275055"
        },
        {
            "CodNatEng": "02",
            "NatEng": "SP 2017.1109.SP du 26/06/2017",
            "NomOrgEng": "TRANS-LANDES",
            "RSOrgEng": "TRANS-LANDES",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "125100.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9rations n\u00b0 1607 du 17/06/2002, n\u00b0 245 20/03/2006 et n\u00b0 2364 du 27/11/2006 ",
            "NomOrgEng": "IRDI MIDI PYRENEES ",
            "RSOrgEng": "IRDI MIDI PYRENEES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "2986274.7"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b01625 du 27/09/1999",
            "NomOrgEng": "SOCRI",
            "RSOrgEng": "SOCRI",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "27.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 1227 du 19/06/2000",
            "NomOrgEng": "CAISSE EPARGNE AQUITAINE NORD",
            "RSOrgEng": "CAISSE EPARGNE AQUITAINE NORD",
            "NatJurOrgEng": "SA \u00e0 directoire",
            "MtOrgEng": "381112.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 1974 du 22/10/1984 - BP 1999",
            "NomOrgEng": "CACG / COMPAGNIE D'AMENAGEMENT DES COTEAUX DE GASCOGNE ",
            "RSOrgEng": "CACG / COMPAGNIE D'AMENAGEMENT DES COTEAUX DE GASCOGNE ",
            "NatJurOrgEng": "SA",
            "MtOrgEng": "762245.09"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9rations n\u00b01172 de 1999, n\u00b0 0313 de 2002 - n\u00b0 1607 de 2002 et n\u00b0 2609 de 2002",
            "NomOrgEng": "GALIA VENTURE",
            "RSOrgEng": "GALIA VENTURE",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "2043900.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 523 du 28/07/1986",
            "NomOrgEng": "SEM GIRONDE DEVELOPPEMENT",
            "RSOrgEng": "SEM GIRONDE DEVELOPPEMENT",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte",
            "MtOrgEng": "45734.71"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9rations n\u00b0 2549 du 18-19/12/1997 et n\u00b0 2320 du 13/12/1999",
            "NomOrgEng": "AQUITAINE CREATION INVESTISSEMENT ",
            "RSOrgEng": "AQUITAINE CREATION INVESTISSEMENT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "1946164.15"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9rations n\u00b0 75 du 16/02/2004, n\u00b0 2257 du 16/10/2006 et n\u00b0 2384 du 29/11/2010",
            "NomOrgEng": "SEML ROUTE DES LASERS",
            "RSOrgEng": "SEML ROUTE DES LASERS",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte",
            "MtOrgEng": "2287000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2287 du 18/12/1995",
            "NomOrgEng": "EXPANSO HOLDING",
            "RSOrgEng": "EXPANSO HOLDING",
            "NatJurOrgEng": "SA nationale \u00e0 directoire",
            "MtOrgEng": "919077.01"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 1172 du 05/07/1999",
            "NomOrgEng": "SOCIETE FINANCIERE AQUITAINE DE PARTICIPATION",
            "RSOrgEng": "SOCIETE FINANCIERE AQUITAINE DE PARTICIPATION",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "304898.03"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 814 du 25/11/1985",
            "NomOrgEng": "S.E.M. 47",
            "RSOrgEng": "S.E.M. 47",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng":
.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2015.2168 du 2/11/2011",
            "NomOrgEng": "DIRECTION REGIONALE DE LA CAISSE DES DEPOTS ET CONSIGNATIONS (d\u00e9positaire des fonds)",
            "RSOrgEng": "DIRECTION REGIONALE DE LA CAISSE DES DEPOTS ET CONSIGNATIONS (d\u00e9positaire des fonds)",
            "NatJurOrgEng": "Autre personne morale de droit administratif",
            "MtOrgEng": "2000000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2012.12 du 6/02/2012",
            "NomOrgEng": "IRDI MIDI PYRENEES ",
            "RSOrgEng": "IRDI MIDI PYRENEES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "168125.1"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2012.1942 du 26/11/2012",
            "NomOrgEng": "IRDI MIDI PYRENEES ",
            "RSOrgEng": "IRDI MIDI PYRENEES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "87701.29"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2012.1079 du 25/06/2012",
            "NomOrgEng": "SPL LASCAUX - L'EXPOSITION INTERNATIONALE",
            "RSOrgEng": "SPL LASCAUX - L'EXPOSITION INTERNATIONALE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 anonyme",
            "MtOrgEng": "100000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9rations n\u00b0 2011.2215 du 14/11/2011 et n\u00b0 2012.1112 du 9/07/2012",
            "NomOrgEng": "IRDINOV",
            "RSOrgEng": "IRDINOV",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e ",
            "MtOrgEng": "-226776.69"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2013.1820 du 25/11/13 ",
            "NomOrgEng": "AQUITAINE CREATION INVESTISSEMENT ",
            "RSOrgEng": "AQUITAINE CREATION INVESTISSEMENT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "5499936.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2013.1824 du 25/11/2013",
            "NomOrgEng": "IRDI MIDI PYRENEES ",
            "RSOrgEng": "IRDI MIDI PYRENEES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "599986.4"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2014.922 du 07/07/2014",
            "NomOrgEng": "SEM GIRONDE DEVELOPPEMENT ",
            "RSOrgEng": "SEM GIRONDE DEVELOPPEMENT ",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte",
            "MtOrgEng": "86304.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2015.1821 du 2/11/2015",
            "NomOrgEng": "IRDI MIDI PYRENEES ",
            "RSOrgEng": "IRDI MIDI PYRENEES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "349895.64"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2015.771 du 01/01/2015",
            "NomOrgEng": "SEML",
            "RSOrgEng": "SEML",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte",
            "MtOrgEng": "1142900.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2015.2100 du 02/11/2015",
            "NomOrgEng": "SEM LOCALE BIARRITZ OCEAN",
            "RSOrgEng": "SEM LOCALE BIARRITZ OCEAN",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration",
            "MtOrgEng": "400000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "31/12/1983",
            "NomOrgEng": "SOCIETE D'EQUIPEMENT DU LIMOUSIN",
            "RSOrgEng": "SOCIETE D'EQUIPEMENT DU LIMOUSIN",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "146351.06"
        },
        {
            "CodNatEng": "02",
            "NatEng": "31/12/1985",
            "NomOrgEng": "SAFER MARCHE LIMOUSIN",
            "RSOrgEng": "SAFER MARCHE LIMOUSIN",
            "NatJurOrgEng": "SA d'Am\u00e9nagement foncier et d'Equipement rural",
            "MtOrgEng": "496848.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "31/12/1992",
            "NomOrgEng": "SEM MAISON DU LIMOUSIN",
            "RSOrgEng": "SEM MAISON DU LIMOUSIN",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "51000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "31/12/2000 et 31/12/2009",
            "NomOrgEng": "FELLETIN ENERGIE",
            "RSOrgEng": "FELLETIN ENERGIE",
            "NatJurOrgEng": "SA d'\u00e9conomie mixte \u00e0 conseil d'administration ",
            "MtOrgEng": "12933.68"
        },
        {
            "CodNatEng": "02",
            "NatEng": "31/12/1991",
            "NomOrgEng": "LIMOGES CSP SASP",
            "RSOrgEng": "LIMOGES CSP SASP",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "437528.68"
        },
        {
            "CodNatEng": "02",
            "NatEng": "31/12/2006",
            "NomOrgEng": "DOM AULIM ENTR SOCIALE HABITAT",
            "RSOrgEng": "DOM AULIM ENTR SOCIALE HABITAT",
            "NatJurOrgEng": "SA de HLM \u00e0 conseil d'administration ",
            "MtOrgEng": "0.1"
        },
        {
            "CodNatEng": "02",
            "NatEng": "31/12/1989",
            "NomOrgEng": "LIMOUSIN PARTICIPATION",
            "RSOrgEng": "LIMOUSIN PARTICIPATION",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng":
.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9cision 2013CP0217 du 12/07/2013 et d\u00e9lib\u00e9ration 2013CR026 du 12/04/2013",
            "NomOrgEng": "SAEML DU BOIS DE LA MOTHE CHANDENIER",
            "RSOrgEng": "SAEML DU BOIS DE LA MOTHE CHANDENIER",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "5000000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2013CR059 du 18/10/2013",
            "NomOrgEng": "FABRIQUE R\u00c9GIONALE DU BOCAGE",
            "RSOrgEng": "FABRIQUE R\u00c9GIONALE DU BOCAGE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "650000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9cision 2014CP0158 du 11/07/2014",
            "NomOrgEng": "LES ATELIERS DU BOCAGE",
            "RSOrgEng": "LES ATELIERS DU BOCAGE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Coop\u00e9rative \u00e0 Int\u00e9r\u00eat Collectif",
            "MtOrgEng": "53250.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2015CR047 du 26/06/2015",
            "NomOrgEng": "MAT\u00c9RIAUX POITOU-CHARENTES",
            "RSOrgEng": "MAT\u00c9RIAUX POITOU-CHARENTES",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Coop\u00e9rative \u00e0 Int\u00e9r\u00eat Collectif",
            "MtOrgEng": "1000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9cision 12CP003 du 16/01/2012 et d\u00e9lib\u00e9ration 12CR009 du 23/03/2012",
            "NomOrgEng": "POITOU-CHARENTES AUTO-PARTAGE (LIQUIDATION JUDICIAIRE)",
            "RSOrgEng": "POITOU-CHARENTES AUTO-PARTAGE (LIQUIDATION JUDICIAIRE)",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "63692.09"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 10CR051 du 12/12/2011, d\u00e9cision 2015CP0148 du 10/07/2015",
            "NomOrgEng": "MANGEONS BIO ENSEMBLE",
            "RSOrgEng": "MANGEONS BIO ENSEMBLE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "23000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2015CR008 du 20/02/2015 + 2017.2482.CP du 17/11/2017",
            "NomOrgEng": "ARTEE ",
            "RSOrgEng": "ARTEE ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "2850000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2017.1445 du 10/07/17",
            "NomOrgEng": "TRANSLANDE - TRANSPORT DEPARTEMENT LANDES MIXTE",
            "RSOrgEng": "TRANSLANDE - TRANSPORT DEPARTEMENT LANDES MIXTE",
            "NatJurOrgEng": "D\u00e9partement",
            "MtOrgEng": "125100.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib n\u00b0 1346 du 11/07/2005",
            "NomOrgEng": "ACE MANAGEMENT / AEROFUND",
            "RSOrgEng": "ACE MANAGEMENT / AEROFUND",
            "NatJurOrgEng": "SA nationale \u00e0 directoire ",
            "MtOrgEng": "200000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9rations 2017.761.CP 15/05/2017, 2019.1077.CP du 08/07/2019",
            "NomOrgEng": "AELIS FARMA",
            "RSOrgEng": "AELIS FARMA",
            "NatJurOrgEng": "SAS, soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "1400002.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2016.2534 du 21/11/2016",
            "NomOrgEng": "NOBATEK INEF 4",
            "RSOrgEng": "NOBATEK INEF 4",
            "NatJurOrgEng": "Autre SA coop\u00e9rative \u00e0 conseil d'administration ",
            "MtOrgEng": "300000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2016.2444.CP du 21/11/2016",
            "NomOrgEng": "SEM ROUTE LASERS",
            "RSOrgEng": "SEM ROUTE LASERS",
            "NatJurOrgEng": "D\u00e9partement",
            "MtOrgEng": "2172460.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2018.41.CP du 05/02/2018",
            "NomOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS",
            "RSOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "1000000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9rations 2017.1154.CP du 10/07/2017, 2018.609.CP du 23/04/2018",
            "NomOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - NACI 1",
            "RSOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - NACI 1",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "16500000"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9rations 2018.41.CP du 05/02/2018, 2018.1231.CP du 09/07/2018",
            "NomOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - Globale Space Venture",
            "RSOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - Globale Space Venture",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "2400000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2018.608.CP du 23/04/18",
            "NomOrgEng": "AQUITI GESTION ",
            "RSOrgEng": "AQUITI GESTION ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par Actions Simplifi\u00e9es \u00e0 associ\u00e9 Unique (SASU)",
            "MtOrgEng": "300000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2019.335.CP du 01/04/2019",
            "NomOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - AELIS INNOVATION",
            "RSOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - AELIS INNOVATION",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "1440000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2019.335.CP du 01/04/2019",
            "NomOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - IRDINOV 2",
            "RSOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - IRDINOV 2",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "1400000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2019.45.CP du 15/02/2019",
            "NomOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - Newfund NAEH (Nouvelle-Aquitaine Euskal Herria)",
            "RSOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - Newfund NAEH (Nouvelle-Aquitaine Euskal Herria)",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "305000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2019.334.CP du 01/04/2019",
            "NomOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - BRIENNE III",
            "RSOrgEng": "NOUVELLE-AQUITAINE PARTICIPATIONS - BRIENNE III",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "1720000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2019.1077.CP du 08/07/2019",
            "NomOrgEng": "FL WH HOLDCO-Flying Whales",
            "RSOrgEng": "FL WH HOLDCO-Flying Whales",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e ",
            "MtOrgEng": "7752539.47"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib\u00e9ration 2019.2038.CP du 16/11/2019",
            "NomOrgEng": "SEML DU RIEUCOURT CENTER PARCS LOT-ET-GARONNE",
            "RSOrgEng": "SEML DU RIEUCOURT CENTER PARCS LOT-ET-GARONNE",
            "NatJurOrgEng": "SEML",
            "MtOrgEng": "10446000"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib n\u00b0 2020.55 du 10/02/20 et 2019.333 du 01/04/19",
            "NomOrgEng": "IRDI MIDI PYRENEES ",
            "RSOrgEng": "IRDI MIDI PYRENEES ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "1062397.35"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2020.513. du 09/03/2020",
            "NomOrgEng": "ESTER / ELECTRICITE SOLAIRE DES TERRITOIRES POITOU-CHARENTES",
            "RSOrgEng": "ESTER / ELECTRICITE SOLAIRE DES TERRITOIRES POITOU-CHARENTES",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "745100.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2020.1078.CP du 15/06/20",
            "NomOrgEng": "DOMOFRANCE",
            "RSOrgEng": "DOMOFRANCE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "0.1"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2020.1942.CP du 23/11/20",
            "NomOrgEng": "SNAP SOCIETE NOUVELLE AQUITAINE PARTICIPATIONS",
            "RSOrgEng": "SNAP SOCIETE NOUVELLE AQUITAINE PARTICIPATIONS",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "6500000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2020.1542.CP du 16/10/20",
            "NomOrgEng": "SNAP - VITIREV Innovation",
            "RSOrgEng": "SNAP - VITIREV Innovation",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "1000000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2020.1542.CP du 16/10/20",
            "NomOrgEng": "SNAP - VITIREV TERRADEV",
            "RSOrgEng": "SNAP - VITIREV TERRADEV",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "1000000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2020.1941.CP du 23/11/20",
            "NomOrgEng": "SNAP - NACO",
            "RSOrgEng": "SNAP - NACO",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "8000000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2020.1782.CP du 16/10/20",
            "NomOrgEng": "TERRA ENERGIES",
            "RSOrgEng": "TERRA ENERGIES",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "2000000.0"
        },
        {
            "CodNatEng": "02",
            "NatEng": "D\u00e9lib 2020.1541.CP du 16/10/20",
            "NomOrgEng": "SNAP - IMPACT TERRITORIAL",
            "RSOrgEng": "SNAP - IMPACT TERRITORIAL",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle",
            "MtOrgEng": "300000.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib\u00e9ration A.4 du 26/06/1992",
            "NomOrgEng": "SOFINDI",
            "RSOrgEng": "SOFINDI",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "38659.5"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9cision CP377 du 22/05/2000",
            "NomOrgEng": "SOCI\u00c9T\u00c9 LOCALE D'EPARGNE",
            "RSOrgEng": "SOCI\u00c9T\u00c9 LOCALE D'EPARGNE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Coop\u00e9rative",
            "MtOrgEng": "262236.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9cision 05CP0073 du 14/03/2005",
            "NomOrgEng": "SAFER",
            "RSOrgEng": "SAFER",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "64000.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9cision CP244 du 16/04/2000",
            "NomOrgEng": "SOFARIS",
            "RSOrgEng": "SOFARIS",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "22.26"
        },
        {
            "CodNatEng": "99",
            "NatEng": "Valorisation paierie 2004",
            "NomOrgEng": "PARTS SOCIALES STATION REGIONALE DE PATHOLOGIE CAPRINE VALORISATION PAIERIE",
            "RSOrgEng": "PARTS SOCIALES STATION REGIONALE DE PATHOLOGIE CAPRINE VALORISATION PAIERIE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "7.62"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2521 du 23/11/2009",
            "NomOrgEng": "HERRIKOA",
            "RSOrgEng": "HERRIKOA",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 en commandite par actions ",
            "MtOrgEng": "265585.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2220 du 24/10/2005",
            "NomOrgEng": " AQUITAINE CREATION INVESTISSEMENT ",
            "RSOrgEng": " AQUITAINE CREATION INVESTISSEMENT ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "1276464.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2017.1154 du 10/07/2017",
            "NomOrgEng": "AELIS",
            "RSOrgEng": "AELIS",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e",
            "MtOrgEng": "-27760.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 1346 du 11/07/2005",
            "NomOrgEng": "ACE MANAGEMENT",
            "RSOrgEng": "ACE MANAGEMENT",
            "NatJurOrgEng": "SA nationale \u00e0 directoire ",
            "MtOrgEng": "100959.92"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9rations n\u00b0 246 du 20/03/2006 et d\u00e9lib\u00e9ration n\u00b0 555 du 7/04/2008 n\u00b0 2012.777 du 21/05/2012",
            "NomOrgEng": "SOCRI II PARTS + ICSO 2 PRIVATE EQUITY",
            "RSOrgEng": "SOCRI II PARTS + ICSO 2 PRIVATE EQUITY",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle ",
            "MtOrgEng": "-1066065.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib n\u00b0 555 du 7/04/2008 ",
            "NomOrgEng": "ICSO 2 PRIVATE EQUITY ",
            "RSOrgEng": "ICSO 2 PRIVATE EQUITY ",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 par actions simplifi\u00e9e \u00e0 associ\u00e9 unique ou soci\u00e9t\u00e9 par actions simplifi\u00e9e unipersonnelle ",
            "MtOrgEng": "-963370.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 358 du 23/03/2009",
            "NomOrgEng": "ACE MANAGEMENT",
            "RSOrgEng": "ACE MANAGEMENT",
            "NatJurOrgEng": "SA nationale \u00e0 directoire ",
            "MtOrgEng": "483641.02"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 2204 du 14/11/2011",
            "NomOrgEng": "ATALAYA",
            "RSOrgEng": "ATALAYA",
            "NatJurOrgEng": "SA nationale \u00e0 directoire ",
            "MtOrgEng": "-0.43"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9rations n\u00b0 1878 du 6/10/2008 et n\u00b0 2012.14 du 6/02/2012",
            "NomOrgEng": "NEWFUND MANAGEMENT ",
            "RSOrgEng": "NEWFUND MANAGEMENT ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "117278.95"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b01805 du 25/11/2013",
            "NomOrgEng": "ACE MANAGEMENT",
            "RSOrgEng": "ACE MANAGEMENT",
            "NatJurOrgEng": "SA nationale \u00e0 directoire ",
            "MtOrgEng": "378364.48"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e9lib\u00e9ration n\u00b0 1028 du 6/07/2015",
            "NomOrgEng": "NEWFUND MANAGEMENT ",
            "RSOrgEng": "NEWFUND MANAGEMENT ",
            "NatJurOrgEng": "SA \u00e0 conseil d'administration",
            "MtOrgEng": "161464.21"
        },
        {
            "CodNatEng": "99",
            "NatEng": "d\u00e
",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "1000000.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib 2018-1685.CP du 08/10/18",
            "NomOrgEng": "SIAGI - FOND REGION PETITE ENTREPRISE",
            "RSOrgEng": "SIAGI - FOND REGION PETITE ENTREPRISE",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 professionnelle \u00e0 capital variable",
            "MtOrgEng": "2000000.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib 2018-1697.CP du 08/10/18",
            "NomOrgEng": "ALTER'NA - FOND EUROPEEN INVESTISSEMENTS",
            "RSOrgEng": "ALTER'NA - FOND EUROPEEN INVESTISSEMENTS",
            "NatJurOrgEng": "Etablissement public \u00e9tranger",
            "MtOrgEng": "22500000"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib 2019-2007.CP du 18/11/19",
            "NomOrgEng": "SOLIHA ",
            "RSOrgEng": "SOLIHA ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "104560.06"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib 2018-1697.CP du 08/10/18",
            "NomOrgEng": "FEI FOND EUROPEEN D'INVESTISSEMENT - Alter'NA",
            "RSOrgEng": "FEI FOND EUROPEEN D'INVESTISSEMENT - Alter'NA",
            "MtOrgEng": "7500000.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib 2020.1169.CPP 17/07/20",
            "NomOrgEng": "Association de pr\u00e9figuration TARMAQ",
            "RSOrgEng": "Association de pr\u00e9figuration TARMAQ",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "170000.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib 200.1198.CP du 17/07/20",
            "NomOrgEng": "Centre Technologique Nouvelle-Aquitaine Composites & Mat\u00e9riaux Avanc\u00e9s CANOE",
            "RSOrgEng": "Centre Technologique Nouvelle-Aquitaine Composites & Mat\u00e9riaux Avanc\u00e9s CANOE",
            "NatJurOrgEng": "Association d\u00e9clar\u00e9e",
            "MtOrgEng": "1000000.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib 2017.1685.CP du 09/10/2017",
            "NomOrgEng": "BPIFRANCE REGIONS",
            "RSOrgEng": "BPIFRANCE REGIONS",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 Anonyme",
            "MtOrgEng": "3000000.0"
        },
        {
            "CodNatEng": "99",
            "NatEng": "D\u00e9lib 2009.974 + 2012.939 + 2014.1072 + 2017.1466",
            "NomOrgEng": "SIAGI - FOND GARANTIE TEMPETE FORET",
            "RSOrgEng": "SIAGI - FOND GARANTIE TEMPETE FORET",
            "NatJurOrgEng": "Soci\u00e9t\u00e9 professionnelle \u00e0 capital variable",
            "MtOrgEng": "150000.0"
        }
    ],
    "DATA_ORGANISME_GROUP": [
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - AEROPORT BIARRITZ PAYS BASQUE",
            "DtAdhGroup": "2019-05-24",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "632500.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - AEROPORT BRIVE SOUILLAC ",
            "DtAdhGroup": "2019-05-24",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "1107845.5"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - AEROPORT LIMOGES BELLEGARDE ",
            "DtAdhGroup": "2017-07-07",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "3105952.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - CHARENTE NUMERIQUE ",
            "DtAdhGroup": "2016-11-21",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "299305.14"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - CITE INTERNATIONNAL TAPISSERIE ART TISSE ",
            "DtAdhGroup": "2010-09-16",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "334306.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - CONSERVATOIRE BOTANIQUE SUD ATLANTIQUE",
            "DtAdhGroup": "2005-12-19",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "182712.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - DEP EQUIPEMENT COMMUNES LANDES ",
            "DtAdhGroup": "2013-11-25",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "338400.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - DORSAL R\u00c9ALISATION ",
            "DtAdhGroup": "2003-12-10",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "563488.37"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - EPIDOR - ETAB PUBLIC INTERDEP DE LA DORDOGNE",
            "DtAdhGroup": "2020-05-15",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "149623.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - ETUDES AMENAGEMENT GARONNE SMEAG",
            "DtAdhGroup": "1989-06-05",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "155364.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - FORUM DES MARAIS ATLANTIQUES",
            "DtAdhGroup": "2014-12-12",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "93149.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - INSTITUTION ADOUR ",
            "DtAdhGroup": "2019-10-21",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "14000.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - LE LAC DE VASSIVIERE ",
            "DtAdhGroup": "1984-11-09",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "1200360.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - LOT ET GARONNE NUM\u00c9RIQUE ",
            "DtAdhGroup": "2013-10-07",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "125000.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - NOUVELLE AQUITAINE MOBILITES ",
            "DtAdhGroup": "2018-03-26",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "850000.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE - PARC NATUREL R\u00c9GIONAL DES LANDES DE GASCOGNE",
            "DtAdhGroup": "1993-04-30",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "1224077.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE AIR DORDOGNE - SMAD ",
            "DtAdhGroup": "2015-11-02",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "476525.47"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE D AMENAGEMENT ET DE GESTION DU PARC NATUREL REGIONAL PNR MEDO",
            "DtAdhGroup": "2019-12-16",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "525000.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DE GESTION DES MILIEUX NATURELS",
            "DtAdhGroup": "2003-05-28",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "218975.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DE LA GRANDE DUNE DU PILAT",
            "DtAdhGroup": "2007-12-26",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "22000.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DE L'A\u00c9ROPORT DE PAU-PYR\u00c9NEES",
            "DtAdhGroup": "2006-03-20",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "222000.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DES A\u00c9ROPORTS DE LA ROCHELLE - ILE DE R\u00c9 ET ROCHEFORT-CHARENTE",
            "DtAdhGroup": "2018-12-16",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "668137.04"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DEVELOP DURABLE ESTUAIRE DE LA GIRONDE",
            "DtAdhGroup": "2002-09-30",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "110000.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DU HAUT B\u00c9ARN ",
            "DtAdhGroup": "1994-05-17",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "186605.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DU PARC NATUREL REGIONAL DE MILLEVACHES EN LIMOUSIN",
            "DtAdhGroup": "2019-12-16",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "698488.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DU PARC NATUREL REGIONAL DU MARAIS POITEVIN",
            "DtAdhGroup": "2017-04-03",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "291994.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DU PARC NATUREL REGIONAL PERIGORD LIMOUSIN",
            "DtAdhGroup": "2019-12-16",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "564416.16"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE DU P\u00d4LE IMAGE MAG\u00c9LIS ",
            "DtAdhGroup": "2014-07-11",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "600000.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE ETABLISSEMENT PUBLIC LOIRE",
            "DtAdhGroup": "2015-12-02",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "29497.0"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE PERIGORD NUMERIQUE ",
            "DtAdhGroup": "2013-11-25",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "425034.59"
        },
        {
            "CodNatOrgGroup": "02",
            "NomOrgGroup": "SYNDICAT MIXTE POUR L AMENAGEMENT DU FLEUVE CHARENTE ET DE SES AFFLUENTS",
            "DtAdhGroup": "2019-10-21",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "150000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "ABBAYE DE SAINT SAVIN SUR GARTEMPE ET VALLEE DES FRESQUES",
            "DtAdhGroup": "2017-12-18",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "200000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "CANC\u00c9ROP\u00d4LE GRAND SUD OUEST ",
            "DtAdhGroup": "2009-02-16",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "120000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "CENTRE INTERNATIONNAL DE RECHERCHE ET DOCUMENTATION OCCITANES - INSTITUT OCC",
            "DtAdhGroup": "2015-04-20",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "215000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "CIBDI CITE INTERNATIONALE DE LA BANDE DESSINEE ET DE L IMAGE",
            "DtAdhGroup": "2015-04-24",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "383542.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "ECOLE EUROPEENNE SUPERIEURE DE L IMAGE EESI",
            "DtAdhGroup": "2015-01-23",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "872470.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "EPCC L EMPREINTE ",
            "DtAdhGroup": "2018-03-26",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "300000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "ETABLISSEMENT PUBLIC DE COOPERATION CULTURELLE DU SUD-AQUITAIN",
            "DtAdhGroup": "2018-10-08",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "192000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "ETS PUB TERRITORIAL BASSIN DE VIENNE ",
            "DtAdhGroup": "2007-03-22",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "210646.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "GECT EUROR\u00c9GION AQUITAINE - EUSKADI ",
            "DtAdhGroup": "2010-12-20",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "550000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "GIP AMENAGEMENT DU TERRITOIRE ET GESTION DES RISQUES - GIP ATGERI",
            "DtAdhGroup": "2009-11-23",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "134302.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "GIP CAFES CULTURES ",
            "DtAdhGroup": "2015-09-14",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "50000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "GIP EUSKARA - OFFICE PUBLIC LANGUE BASQUE",
            "DtAdhGroup": "2004-06-28",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "860000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "GIP INTERREG DEVEL MASSIF CENTRAL CONSEIL REGIONAL AUVERGNE",
            "DtAdhGroup": "2019-11-18",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "52725.44"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "GIP LITTORAL AQUITAIN ",
            "DtAdhGroup": "2006-04-11",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "98900.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "OFFICE PUBLIC DE LA LANGUE OCCITANE - OFICI PUBLIC DE LA LENGA OCCITANA",
            "DtAdhGroup": "2015-11-02",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "1123800.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "PAYS ET QUARTIERS DE NOUVELLE-AQUITAIN E",
            "DtAdhGroup": "2002-01-01",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "311000.0"
        },
        {
            "CodNatOrgGroup": "09",
            "NomOrgGroup": "P\u00d4LE INTERNATIONAL DE LA PR\u00c9HISTOIRE ",
            "DtAdhGroup": "2009-11-23",
            "CodModFinanc": "Contribution statutaire",
            "MtFinancOrgGroup": "420500.0"
        }
    ]
    }

# %%
dict_annexes["DATA_CONSOLIDATION"][0]
# Out:
# {'CodTypBudAgreg': '01',
#  'CodInvFonc': 'I',
#  'CodRD': 'R',
#  'MtCredOuv': '2707828117.54',
#  'MtRealMandatTitre': '2136641678.22',
#  'RAR': '0',
#  'SiretBudAnnexe': '20005375900011'}

# %%
CONCOURS_FIELDS
# Out:
# ['SIRET_etablissement',
#  'Champ_Editeur',
#  'CodArticle',
#  'CodInvFonc',
#  'CodNatJurBenefCA',
#  'DenomOuNumSubv',
#  'LibOrgaBenef',
#  'LibPrestaNat',
#  'MtSubv',
#  'ObjSubv',
#  'PopCommune',
#  'Siret']

# %%
temp_doc =  copy.deepcopy(doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS'])

for field in CONCOURS_FIELDS:
    if field in temp_doc:
            if "@V" in temp_doc[field]:
                temp_doc[field] = temp_doc[field]['@V']
    temp_doc["SIRET_etablissement"] = doc["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["IdColl"]["@V"]

# %%
temp_doc
# Out:
# {'CodArticle': '65821',
#  'CodInvFonc': 'F',
#  'CodNatJurBenefCA': 'U1',
#  'LibOrgaBenef': 'Budget Annexe de la Restauration Administrative',
#  'MtSubv': '446786.0',
#  'DenomOuNumSubv': 'BP 2020 - Subvention au Budget de la Restauration Administrative',
#  'ObjSubv': "Subvention d'Equilibre",
#  'SIRET_etablissement': '20005340300057'}

# %%
generate_dict_annexe_concours(doc)
# Out:
# SIRET_etablissement
# Champ_Editeur
# CodArticle
# CodInvFonc
# CodNatJurBenefCA
# DenomOuNumSubv
# LibOrgaBenef
# LibPrestaNat
# MtSubv
# ObjSubv
# PopCommune
# Siret
# [{'CodArticle': '65821',
#   'CodInvFonc': 'F',
#   'CodNatJurBenefCA': 'U1',
#   'LibOrgaBenef': 'Budget Annexe de la Restauration Administrative',
#   'MtSubv': '446786.0',
#   'DenomOuNumSubv': 'BP 2020 - Subvention au Budget de la Restauration Administrative',
#   'ObjSubv': "Subvention d'Equilibre",
#   'SIRET_etablissement': '20005340300057'}]

# %%
export_data = temp_doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS']

with open("./M71_2020_csv/99_BU-033-200053759-20210727-CA_2020_BP_1-BF-1-1_1.csv", "w") as csv_file:
    dict_writer = csv.DictWriter(csv_file, fieldnames=BUDGET_FIELDS)
    dict_writer.writeheader()
    dict_writer.writerows(export_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10204/1257005103.py in <module>
# ----> 1 export_data = temp_doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]['CONCOURS']
#       2
#       3 with open("./M71_2020_csv/99_BU-033-200053759-20210727-CA_2020_BP_1-BF-1-1_1.csv", "w") as csv_file:
#       4     dict_writer = csv.DictWriter(csv_file, fieldnames=BUDGET_FIELDS)
#       5     dict_writer.writeheader()
#
# TypeError: list indices must be integers or slices, not str

# %%
def create_filename(doc_xml):
    dict_nature_decision = {
                            "01": "Budget_primitif",
                            "02" : "Decision_modificative",
                            "03" : "Budgetsupplementaire",
                            "09" : "Compte_administratif"
                           }
    bloc_budget = doc_xml["DocumentBudgetaire"]["Budget"]["BlocBudget"] 
    filename = bloc_budget["Exer"]["@V"] + "_" 
    
    filename += dict_nature_decision[bloc_budget["NatDec"]["@V"]] + "_" 
    #filename += bloc_budget["DteDec"]["@V"] + "_"
    if "NumDec" in bloc_budget:
        filename += bloc_budget["NumDec"]["@V"] + "_"
    filename += doc_xml["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["LibelleColl"]["@V"]
    
    return filename

# %%
create_filename(doc)
# Out:
# '2020_Compte_administratif_REGION NOUVELLE-AQUITAINE'

# %%
doc_xml

with open("./M71_2020_csv/99_BU-033-200053759-20210727-CA_2020_BP_1-BF-1-1_1.csv", "w") as csv_file:
    dict_writer = csv.DictWriter(csv_file, fieldnames=BUDGET_FIELDS)
    dict_writer.writeheader()
    data = generate_dict_annexe_concours(doc_xml)
    dict_writer.writerows(data)

# %%
import glob
import pathlib

# %%
Path.joinpath(PATH_SRC, i).exists()
# Out:
# True

# %%
[pathlib.Path(f).stem for f in glob.glob('./M71_2020_csv/annexes/concours/*')]
# Out:
# ['2020_Compte_administratif_Conseil Régional de Normandie',
#  '2020_Compte_administratif_CONSEIL REGIONAL DE LA GUADELOUPE',
#  '2020_Compte_administratif_Région Auvergne Rhône-Alpes',
#  '2020_Compte_administratif_Région de Bretagne',
#  '2020_Budget_primitif_CONSEIL REGIONAL DE LA GUADELOUPE',
#  '2020_Compte_administratif_Région Grand Est',
#  '2020_Compte_administratif_REGION CENTRE VAL DE LOIRE',
#  '2020_Compte_administratif_REGION NOUVELLE-AQUITAINE',
#  '2020_Compte_administratif_ REGION ILE DE FRANCE',
#  '2020_Decision_modificative_2_Région Grand Est',
#  '2020_Budget_primitif_Conseil Régional de Normandie',
#  '2020_Compte_administratif_HAUTS DE FRANCE',
#  '2020_Compte_administratif_REGION BOURGOGNE-FRANCHE-COMTE']

# %%
len(os.listdir(PATH_SRC))
# Out:
# 54

# %%
start_time = datetime.now()
import os
from pathlib import Path, PurePath

PATH = Path.cwd()
PATH_SRC = Path.joinpath(PATH, 'M71_2020')

for i in os.listdir(PATH_SRC):
    directory = Path.joinpath(PATH_SRC, i)
    with open(directory, encoding='latin-1') as fd:
        doc = xmltodict.parse(fd.read(), dict_constructor=dict)
        if "DATA_CONCOURS" in doc["DocumentBudgetaire"]["Budget"]["Annexes"]:
            filename = create_filename(doc) + ".csv"
            print(filename)
            with open("./M71_2020_csv/annexes/concours/"+ filename, "w") as csv_file:
                dict_writer = csv.DictWriter(csv_file, fieldnames=CONCOURS_FIELDS)
                dict_writer.writeheader()
                data = generate_dict_annexe_concours(doc)
                dict_writer.writerows(data)                


end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# 2020_Compte_administratif_REGION BOURGOGNE-FRANCHE-COMTE.csv
# 2020_Compte_administratif_ REGION ILE DE FRANCE.csv
# 2020_Compte_administratif_HAUTS DE FRANCE.csv
# 2020_Compte_administratif_Région de Bretagne.csv
# 2020_Compte_administratif_Région Grand Est.csv
# 2020_Budget_primitif_CONSEIL REGIONAL DE LA GUADELOUPE.csv
# 2020_Compte_administratif_REGION CENTRE VAL DE LOIRE.csv
# 2020_Compte_administratif_REGION NOUVELLE-AQUITAINE.csv
# 2020_Compte_administratif_CONSEIL REGIONAL DE LA GUADELOUPE.csv
# 2020_Compte_administratif_Région de Bretagne.csv
# 2020_Budget_primitif_Conseil Régional de Normandie.csv
# 2020_Budget_primitif_CONSEIL REGIONAL DE LA GUADELOUPE.csv
# 2020_Compte_administratif_ REGION ILE DE FRANCE.csv
# 2020_Compte_administratif_Conseil Régional de Normandie.csv
# 2020_Compte_administratif_Région Auvergne Rhône-Alpes.csv
# Duration: 0:00:25.327550

# %% [markdown]
# # Parcours des fichiers du dossier

# %%
import os
from pathlib import Path, PurePath

# %%
PATH = Path.cwd()
PATH_SRC = Path.joinpath(PATH, 'M71_2020')
PATH_DATA = Path.joinpath(PATH, 'data')

# %%
with open("./M71_2020/99_BU-033-200053759-20210727-CA_2020_BP_1-BF-1-1_1.XML", encoding='latin-1') as fd:
    doc = xmltodict.parse(fd.read(), dict_constructor=dict)
# Ordered dict to simple dict
doc#= json.loads(json.dumps(doc))

# %%
for i in os.listdir(PATH_SRC):
    directory = Path.joinpath(PATH_SRC, i)
    with open(directory, encoding='latin-1') as fd:
        doc = xmltodict.parse(fd.read())
        # Ordered dict to simple dict
        doc = json.loads(json.dumps(doc))
        for key in doc["DocumentBudgetaire"]["Budget"]["Annexes"].keys():
            if key not in annexes:
                annexes.add(key)
            
        #if "DATA_DETTE" in doc["DocumentBudgetaire"]["Budget"]["Annexes"].keys():
        #    print(i)

# %%
annexes

# %%
root = dom.getroot()[6]
for budg in root.findall('{http://www.minefi.gouv.fr/cp/demat/docbudgetaire}LigneBudget'):
    for element in budg:
        print(element.tag, element.attrib)

# %%
print(root)
print(dom)

# %%
dom = ET.parse("./M71_2020/99_BU-033-200053759-20210727-CA_2020_BP_1-BF-1-1_1.XML")
root = dom.getroot()
for child in root:
    print(child.tag, child.attrib)

# %% [markdown]
# # Parsing schemas on odm website

# %%
import requests

# %%
session = requests.Session()
session.proxies.update(proxies)

# %%
#dom = ET.parse("http://odm-budgetaire.org/doc-schema/doc-schema.html")
#root = dom.getroot()
r = session.get("https://odm-budgetaire.org/doc-schema/doc-schema.html", proxies=proxies, verify=False)
# Out:
# /home/rbevenot/miniconda3/envs/dataprep/lib/python3.9/site-packages/urllib3/connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'orion.dsic.minint.fr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ## parsing schemas on schema zip

# %%
import os
from pathlib import Path, PurePath

# %%
PATH = Path.cwd()
PATH_SCHEMA = Path.joinpath(PATH, 'schema','schema_doc_budg_V100','SchemaDocBudg')
PATH_SCHEMA
# Out:
# PosixPath('/home/rbevenot/projets/dataprep-ab/schema/schema_doc_budg_V100/SchemaDocBudg')

# %%
class_annexe_path = Path.joinpath(PATH_SCHEMA,'Class_Annexes.xsd')

with open(class_annexe_path, encoding='latin-1') as fd:
    doc = xmltodict.parse(fd.read(), dict_constructor=dict)
doc['xs:schema']['xs:include'][0]
# Out:
# {'@schemaLocation': 'CommunAnnexe.xsd'}

# %%
list_fichier_annexe = []
for annexe in doc['xs:schema']['xs:include']:
    list_fichier_annexe.append(annexe['@schemaLocation'])

# %%
list_fichier_annexe
# Out:
# ['Class_Emprunt.xsd',
#  'Class_Tresorerie.xsd',
#  'Class_Charges.xsd',
#  'Class_Tiers.xsd',
#  'Class_CreditBail.xsd',
#  'Class_PPP.xsd',
#  'Class_AutresEngagements.xsd',
#  'Class_Concours.xsd',
#  'Class_RecettesAffectees.xsd',
#  'Class_Formation.xsd',
#  'Class_Fiscalite.xsd',
#  'Class_Consolidation.xsd',
#  'Class_OrganismeEng.xsd',
#  'Class_OrganismeGroup.xsd',
#  'Class_Patrimoine.xsd',
#  'Class_Personnel.xsd',
#  'Class_Dettes.xsd',
#  'Class_Ventilation.xsd',
#  'Class_ContratCouv.xsd',
#  'Class_AmortissementMethode.xsd',
#  'Class_Provision.xsd',
#  'Class_APCP.xsd',
#  'Class_EtabService.xsd',
#  'Class_Sommaire.xsd',
#  'Class_Pret.xsd',
#  'Class_ContratCouvReference.xsd',
#  'Class_PersonnelSolde.xsd',
#  'Class_Service_Ferroviaire_Bud.xsd',
#  'Class_Service_Ferroviaire_Patrim.xsd',
#  'Class_Service_Ferroviaire_Ter.xsd',
#  'Class_Fonds_Comm_Hebergement.xsd',
#  'Class_Fonds_Europeens.xsd',
#  'Class_Fonds_Europeens_Programmation.xsd',
# ...

# %%
doc['xs:schema']['xs:complexType']['xs:sequence']['xs:element']
# Out:
# [{'@name': 'DATA_EMPRUNT',
#   '@type': 'TEmprunts',
#   '@minOccurs': '0',
#   '@maxOccurs': '1',
#   'xs:annotation': {'xs:documentation': {'z:libelle': 'Emprunts',
#     'z:description': '<html>Bloc "technique" permettant de stocker les informations concernant les emprunts.<br/>\nCes informations sont visibles dans la partie IV du document budgÃ©taires dans les Ã©tats suivants :<br/>\n  <ul><li>RÃ©partition par prÃªteur</li>\n      <li>RÃ©partition des emprunts par type de taux</li>\n      <li>RÃ©partition par nature de dettes</li>\n      <li>RÃ©partition de l\'encours (typologie)</li></ul></html>'},
#    'xs:appinfo': {'z:path-to-element': 'DATA_EMPRUNT/EMPRUNT'}}},
#  {'@name': 'DATA_TRESORERIE',
#   '@type': 'TTresoreries',
#   '@minOccurs': '0',
#   '@maxOccurs': '1',
#   'xs:annotation': {'xs:documentation': 'CrÃ©dits de trÃ©sorerie',
#    'xs:appinfo': {'z:path-to-element': 'DATA_TRESORERIE/TRESORERIE'}}},
#  {'@name': 'DATA_CHARGE',
#   '@type': 'TCharges',
# ...

# %%
# Parcours de la classe annexe
dict_annexes = {}
for annexe in doc['xs:schema']['xs:complexType']['xs:sequence']['xs:element']:
    dict_annexes[annexe["@type"]] = {
                        "name" : annexe["@name"],
                        "documentation" : annexe["xs:annotation"]["xs:documentation"],
                        "arborescence" : [annexe["xs:annotation"]['xs:appinfo']['z:path-to-element'].split('/')]}
    #dict_annexes.append(dict_temp)
#[0]['xs:annotation']['xs:documentation']

# %%
dict_annexes
# Out:
# {'TEmprunts': {'name': 'DATA_EMPRUNT',
#   'documentation': {'z:libelle': 'Emprunts',
#    'z:description': '<html>Bloc "technique" permettant de stocker les informations concernant les emprunts.<br/>\nCes informations sont visibles dans la partie IV du document budgÃ©taires dans les Ã©tats suivants :<br/>\n  <ul><li>RÃ©partition par prÃªteur</li>\n      <li>RÃ©partition des emprunts par type de taux</li>\n      <li>RÃ©partition par nature de dettes</li>\n      <li>RÃ©partition de l\'encours (typologie)</li></ul></html>'},
#   'arborescence': [['DATA_EMPRUNT', 'EMPRUNT']]},
#  'TTresoreries': {'name': 'DATA_TRESORERIE',
#   'documentation': 'CrÃ©dits de trÃ©sorerie',
#   'arborescence': [['DATA_TRESORERIE', 'TRESORERIE']]},
#  'TCharges': {'name': 'DATA_CHARGE',
#   'documentation': 'Charges transfÃ©rÃ©es',
#   'arborescence': [['DATA_CHARGE', 'CHARGE']]},
#  'TOpeComptesTiers': {'name': 'DATA_TIERS',
#   'documentation': 'OpÃ©rations pour compte de tiers',
# ...

# %%
list_fichier_annexe
# Out:
# ['CommunAnnexe.xsd',
#  'Class_Emprunt.xsd',
#  'Class_Tresorerie.xsd',
#  'Class_Charges.xsd',
#  'Class_Tiers.xsd',
#  'Class_CreditBail.xsd',
#  'Class_PPP.xsd',
#  'Class_AutresEngagements.xsd',
#  'Class_Concours.xsd',
#  'Class_RecettesAffectees.xsd',
#  'Class_Formation.xsd',
#  'Class_Fiscalite.xsd',
#  'Class_Consolidation.xsd',
#  'Class_OrganismeEng.xsd',
#  'Class_OrganismeGroup.xsd',
#  'Class_Patrimoine.xsd',
#  'Class_Personnel.xsd',
#  'Class_Dettes.xsd',
#  'Class_Ventilation.xsd',
#  'Class_ContratCouv.xsd',
#  'Class_AmortissementMethode.xsd',
#  'Class_Provision.xsd',
#  'Class_APCP.xsd',
#  'Class_Signatures.xsd',
#  'Class_EtabService.xsd',
#  'Class_Sommaire.xsd',
#  'Class_Pret.xsd',
#  'Class_ContratCouvReference.xsd',
#  'Class_PersonnelSolde.xsd',
#  'Class_Service_Ferroviaire_Bud.xsd',
#  'Class_Service_Ferroviaire_Patrim.xsd',
#  'Class_Service_Ferroviaire_Ter.xsd',
#  'Class_Fonds_Comm_Hebergement.xsd',
#  'Class_Fonds_Europeens.xsd',
# ...

# %%
#Parcours des fichiers de classe
####list_fichier_annexe.remove('CommunAnnexe.xsd')

for fichier_classe in list_fichier_annexe:
    class_path = Path.joinpath(PATH_SCHEMA, fichier_classe)
    print(fichier_classe)
    with open(class_path, encoding='latin-1') as fd:
        doc = xmltodict.parse(fd.read(), dict_constructor=dict)

    list_balises = []
    for i in doc['xs:schema']['xs:complexType'][1:][0]['xs:sequence']['xs:element']:
        list_balises.append(i['@name'])
    dict_annexes[doc['xs:schema']['xs:complexType'][0]['@name']]["liste_balises"] = list_balises
# Out:
# Class_Emprunt.xsd
# Class_Tresorerie.xsd
# Class_Charges.xsd
# Class_Tiers.xsd
# Class_CreditBail.xsd
# Class_PPP.xsd
# Class_AutresEngagements.xsd
# Class_Concours.xsd
# Class_RecettesAffectees.xsd
# Class_Formation.xsd
# Class_Fiscalite.xsd
# Class_Consolidation.xsd
# Class_OrganismeEng.xsd
# Class_OrganismeGroup.xsd
# Class_Patrimoine.xsd
# Class_Personnel.xsd
# Class_Dettes.xsd
# Class_Ventilation.xsd
# Class_ContratCouv.xsd
# Class_AmortissementMethode.xsd
# Class_Provision.xsd
# Class_APCP.xsd
# Class_EtabService.xsd
# Class_Sommaire.xsd
# Class_Pret.xsd
# Class_ContratCouvReference.xsd
# Class_PersonnelSolde.xsd
# Class_Service_Ferroviaire_Bud.xsd
# Class_Service_Ferroviaire_Patrim.xsd
# Class_Service_Ferroviaire_Ter.xsd
# Class_Fonds_Comm_Hebergement.xsd
# Class_Fonds_Europeens.xsd
# Class_Fonds_Europeens_Programmation.xsd
# Class_Fonds_Aides_Eco.xsd
# Class_Formation_Pro_Jeunes.xsd
# Class_MembresASA.xsd
# Class_FluxCroises.xsd

# %%
#del dict_annexes['TSignatures']
del dict_annexes['TSignataires']

# %%
for i in dict_annexes:
    print(i)
    print(dict_annexes[i]["liste_balises"])
# Out:
# TEmprunts
# ...

# %%
import psycopg2
from psycopg2.extras import RealDictCursor

# %%
while(True):
    try:
        time.sleep(2)
        conn = psycopg2.connect(host='localhost', dbname="actes_budgetaire",
        user='postgres', password="", 
        port='5432')
        cursor = conn.cursor()
        print("Successful")
        break
    except Exception as error:
        print("Error database connection")
        print("Error : ", error)
        time.sleep(2)
# Out:
# Successful

# %%
cursor
# Out:
# <cursor object at 0x7f9e9402f7c0; closed: 0>

# %%
doc["DocumentBudgetaire"]["Budget"]["Annexes"]["DATA_CONCOURS"]["CONCOURS"]
# Out:
# [{'CodInvFonc': {'@V': 'F'},
#   'CodNatJurBenefCA': {'@V': 'P2'},
#   'LibOrgaBenef': {'@V': 'SAEML VALAGRO'},
#   'MtSubv': {'@V': '0.0'},
#   'LibPrestaNat': {'@V': "Affectation d'un ensemble immobilier à Poitiers à titre gratuit"}},
#  {'CodInvFonc': {'@V': 'F'},
#   'CodNatJurBenefCA': {'@V': 'U1'},
#   'LibOrgaBenef': {'@V': 'LYCÉE M.VALOIS (16)'},
#   'MtSubv': {'@V': '0.0'},
#   'LibPrestaNat': {'@V': "Affectation d'un véhicule électrique MIA (BX-613-QG) (valeur d'origine 12 843,84 €)"}},
#  {'CodInvFonc': {'@V': 'F'},
#   'CodNatJurBenefCA': {'@V': 'U1'},
#   'LibOrgaBenef': {'@V': "LYCÉE DE L'ATLANTIQUE (17)"},
#   'MtSubv': {'@V': '0.0'},
#   'LibPrestaNat': {'@V': "Affectation d'un véhicule électrique MIA (BX-352-QJ) (valeur d'origine 12 843,84 €)"}},
#  {'CodInvFonc': {'@V': 'F'},
#   'CodNatJurBenefCA': {'@V': 'U1'},
#   'LibOrgaBenef': {'@V': 'LYCÉE BELLEVUE (17)'},
#   'MtSubv': {'@V': '0.0'},
# ...

# %%
data = doc["DocumentBudgetaire"]["Budget"]["DATA_CONCOURS"]

for idx, row in enumerate(data):
        for field in BUDGET_FIELDS:
            if field in row:
                if "@V" in row[field]:
                    doc["DocumentBudgetaire"]["Budget"]["LigneBudget"][idx][field] = row[field]['@V']
            doc["DocumentBudgetaire"]["Budget"]["LigneBudget"][idx]["SIRET"] = doc["DocumentBudgetaire"]["EnTeteDocBudgetaire"]["IdColl"]["@V"]

# %%
var catalogData = {
    "booksByIsbn": {
        "978-1779501127": {
            "isbn": "978-1779501127",
            "title": "Watchmen",
            "publicationYear": 1987,
            "authorIds": ["alan-moore", "dave-gibbons"],
            "bookItems": [
                {
                    "id": "book-item-1",
                    "libId": "nyc-central-lib",
                    "isLent": true
                },
                {
                    "id": "book-item-2",
                    "libId": "nyc-central-lib",
                    "isLent": false
                }
            ]
        }
    },
    "authorsById": {
        "alan-moore": {
            "name": "Alan Moore",
            "bookIsbns": ["978-1779501127"]
        },
        "dave-gibbons": {
            "name": "Dave Gibbons",
            "bookIsbns": ["978-1779501127"]
        }
    }
}

# %%
class Catalog {
    static authorNames(catalogData, book) {
        var authorIds = _.get(book, "authorIds");
        var names = _.map(authorIds, function(authorId) { 
            return _.get(catalogData, ["authorsById", authorId, "name"]);
        });
        return names;
    }

    static bookInfo(catalogData, book) {
        var bookInfo =  {
            "title": _.get(book, "title"),
            "isbn": _.get(book, "isbn"),
            "authorNames": Catalog.authorNames(catalogData, book)
        }; //
        return bookInfo;
    }

    static searchBooksByTitle(catalogData, query) {
        var allBooks = _.get(catalogData, "booksByIsbn");
        var matchingBooks = _.filter(allBooks, function(book) { //
            return _.get(book, "title").includes(query);
        });
        var bookInfos = _.map(matchingBooks, function(book) { 
            return Catalog.bookInfo(catalogData, book);
        });
        return bookInfos;
    }
}

class Library {
    static searchBooksByTitleJSON(libraryData, query) {
        var catalogData = _.get(libraryData, "catalog");
        var results = Catalog.searchBooksByTitle(catalogData, query);
        var resultsJSON = JSON.stringify(results); //
        return resultsJSON;
    }
}
